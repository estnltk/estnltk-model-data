# %%
# Suppress deprecation warnings
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)


import pandas as pd
pd.set_option('display.max_colwidth', 0)


# Update the path with the actual path to your folder
import sys
library_path = 'my_repo/v31_apriori'
sys.path.append(library_path)

from V31Apriori import V31
import json
from estnltk import Text
import os
import re

# %%
SQLITEFILE = "v31data.db"

# %%
v31 = V31(
    SQLITEFILE,
    form_treshold_percent = 20,
    form_treshold_count = 5,
    apriori_min_support=0.05,
    apriori_treshold_delta = 0.03,
    apriori_treshold_percent=50,
    datarows_treshold=100000
    )

# %%
# reading verb pattern files:

df_len1 = pd.read_csv('data/verb_patterns_len1.csv')
df_len2 = pd.read_csv('data/verb_patterns_len2.csv')

# %%
df_len1
# Out:
#       Unnamed: 0             word government_with_case word_1      word_2  \
# 0     0           aasima           p                    p      NaN
# 1     1           aasima           g kallal             g      kallal.adp
# 2     2           abielluma        kom                  kom    NaN
# 3     3           abikätt ulatama  all                  all    NaN
# 4     4           abstraheeruma    el                   el     NaN
# ...  ..                     ...    ..                   ..     ...
# 2533  2533        ümmardama        p                    p      NaN
# 2534  2534        üritama          p teha               p      teha.v
# 2535  2535        ütlema           all                  all    NaN
# 2536  2536        ütlema           g kohta              g      kohta.adp
# 2537  2537        žongleerima      kom                  kom    NaN
#
#      word_3
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ...   ...
# 2533  NaN
# 2534  NaN
# 2535  NaN
# 2536  NaN
# 2537  NaN
#
# [2538 rows x 6 columns]

# %%
df_len2
# Out:
#     Unnamed: 0           word      government_with_case member1_wrd1  \
# 0   0           abistama       p + in                    p
# 1   1           aitama         ad + p teha               ad
# 2   2           ette heitma    all + p                   all
# 3   3           informeerima   p + el                    p
# 4   4           jagama         p + kom                   p
# 5   5           keelama        ad + p teha               ad
# 6   6           kleepima       all + g peale             all
# 7   7           kohtlema       p + kuidas                p
# 8   8           kokku leppima  kom + in                  kom
# 9   9           käskima        ad + p teha               ad
# 10  10          küsima         abl + p                   abl
# 11  11          küsima         g käest + p               g
# 12  12          laskma         ad + p teha               ad
# 13  13          lubama         ad + p teha               ad
# 14  14          läbi rääkima   kom + g suhtes            kom
# 15  15          nappima        ad + tr                   ad
# 16  16          paluma         ad + p teha               ad
# 17  17          pidama         p + tr                    p
# 18  18          piisama        all + el                  all
# 19  19          soovima        all + p                   all
# 20  20          soovitama      ad + p teha               ad
# 21  21          sundima        p + p tegema              p
# 22  22          takistama      ad + p teha               ad
# 23  23          teavitama      p + el                    p
# 24  24          tooma          all + kom                 all
# 25  25          tooma          abl + all                 abl
# 26  26          tulema         ad + p teha               ad
# 27  27          tunduma        nom + es                  nom
# 28  28          täiendama      p + kom                   p
# 29  29          tõlkima        nom keelest + nom keelde  nom
# 30  30          vedama         all + kom                 all
# 31  31          viima          abl + all                 abl
# 32  32          võimaldama     ad + p teha               ad
#
#    member1_wrd2 member2_wrd1 member2_wrd2
# 0   NaN          in           NaN
# 1   NaN          p            teha.v
# 2   NaN          p            NaN
# 3   NaN          el           NaN
# 4   NaN          kom          NaN
# 5   NaN          p            teha.v
# 6   NaN          g            peale.adp
# 7   NaN          kuidas.?     NaN
# 8   NaN          in           NaN
# 9   NaN          p            teha.v
# 10  NaN          p            NaN
# 11  käest.adp    g            NaN
# 12  NaN          p            teha.v
# 13  NaN          p            teha.v
# 14  NaN          g            suhtes.adp
# 15  NaN          tr           NaN
# 16  NaN          p            teha.v
# 17  NaN          tr           NaN
# 18  NaN          el           NaN
# 19  NaN          p            NaN
# 20  NaN          p            teha.v
# 21  NaN          p            tegema.v
# 22  NaN          p            teha.v
# 23  NaN          el           NaN
# 24  NaN          kom          NaN
# 25  NaN          all          NaN
# 26  NaN          p            teha.v
# 27  NaN          es           NaN
# 28  NaN          kom          NaN
# 29  keelest.?    nom          keelde.?
# 30  NaN          kom          NaN
# 31  NaN          all          NaN
# 32  NaN          p            teha.v

# %%
df_len1 = df_len1.fillna('')
df_len2 = df_len2.fillna('')

# %%
# getting transactions of each (unique) verb, transactions will be saved in json files

unique_1 = list(df_len1['word'].unique())
unique_2 = list(df_len2['word'].unique())

# %%
len(unique_1)
# Out:
# 1855

# %%
len(unique_2)
# Out:
# 31

# %%
unique = sorted(list(set(unique_1+unique_2)))

# %%
len(unique)
# Out:
# 1868

# %%
# kui ühe transaktsiooni wall time on u 3 minutit, siis 1868 transaktsiooni tegemine võib võtta aega 90 tunni ringis
# esialgu proovin 10 verbiga, jättes välja sellised, kus compound pikkus > 2 (nt 'altari ette viima')

# %%
unique_10 = [unique[i] for i in range(10) if len(unique[i].split()) < 3]

# %%
unique_10
# Out:
# ['aasima',
#  'abielluma',
#  'abikätt ulatama',
#  'abistama',
#  'abstraheeruma',
#  'adresseerima',
#  'aevastama',
#  'agiteerima',
#  'ahistama',
#  'ahvima']

# %%
# %%time

v = 'vastu võtma koos'
verb_compound = [] # TODO: küsida üle, mida teha, kui verbil on compound osad (1 või enam)
verb = ''
splitted = v.split()
if len(splitted) > 1:
    for i in range(len(splitted)):
        if 'V' in Text(splitted[i]).tag_layer('morph_analysis').morvastu, koosph_analysis.partofspeech[0]:
            verb = splitted[i]
        else:
            verb_compound.append(splitted[i])
transactions = v31.get_transactions(verb=verb, verb_compound=', '.join(verb_compound))
raw_transactions = v31._raw_transactions
# Out:
# CPU times: total: 25.5 s
# Wall time: 3min 16s

# %%
display(raw_transactions)
# Out:
# {}

# %%
# %%time

v = 'alla hüppama'
verb_compound = [] # kui compound osi rohkem kui 1, siis eraldatakse komaga
verb = ''
splitted = v.split()
if len(splitted) > 1:
    for i in range(len(splitted)):
        if 'V' in Text(splitted[i]).tag_layer('morph_analysis').morph_analysis.partofspeech[0]:
            verb = splitted[i]
        else:
            verb_compound.append(splitted[i])
transactions = v31.get_transactions(verb=verb, verb_compound=','.join(verb_compound))
raw_transactions = v31._raw_transactions
# Out:
# CPU times: total: 23 s
# Wall time: 3min 8s

# %%
display(raw_transactions)
# Out:
# {16176: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'hädas',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,pl',
#    'frequent_form': 'poisid',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'lakaluugist',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'ill',
#    'feats': 'com,ill,pl',
#    'frequent_form': 'kasvuhooneklaasidesse',
#    'obl_case': '',
#    'loc': 8}],
#  20021: [{'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'deltaplaaniga',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kaljult',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,aux,impf,indic,ps,ps3,sg',
#    'frequent_form': 'muutis',
#    'obl_case': '',
#    'loc': 8}],
#  167405: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'pärast',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 3}],
#  272134: [{'deprel': 'OBL',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'aasta',
#    'obl_case': ' tagasi',
#    'loc': 1},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'toksikomaan',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'kodu',
#    'obl_case': '',
#    'loc': 13},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 15}],
#  617918: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'nõmmel',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'korterist',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'eile',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'gen,prop,sg',
#    'frequent_form': 'ljudmilla',
#    'obl_case': '',
#    'loc': 15}],
#  617922: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ma',
#    'obl_case': '',
#    'loc': 21},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 23}],
#  695269: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,prop,sg',
#    'frequent_form': 'viktor',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 11}],
#  715031: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'varahommikul',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,prop,sg',
#    'frequent_form': 'oll',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'ühiselamukorteri',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 11}],
#  715643: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,pl',
#    'frequent_form': 'langevarjurid',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'lennukilt',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'inf,mod',
#    'frequent_form': 'maanduda',
#    'obl_case': '',
#    'loc': 9}],
#  738166: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'ott',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,prop,sg',
#    'frequent_form': 'lasnamäel',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'gen,prop,sg',
#    'frequent_form': 'läänemere',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'majas',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'ööl',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': ' vastu',
#    'loc': 15}],
#  747752: [{'deprel': 'NSUBJ',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'inimest',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'korterist',
#    'obl_case': '',
#    'loc': 5}],
#  753176: [{'deprel': 'OBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'mõlemad',
#    'obl_case': '',
#    'loc': 10}],
#  784352: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,prop,sg',
#    'frequent_form': 'ene',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'lausa',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'kaldast',
#    'obl_case': '',
#    'loc': 5}],
#  847136: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,prop,sg',
#    'frequent_form': 'linnap',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  897305: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,prop,sg',
#    'frequent_form': 'lasnamäel',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'esmaspäeval',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,prop,sg',
#    'frequent_form': 'galina',
#    'obl_case': '',
#    'loc': 9}],
#  909685: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'sillalt',
#    'obl_case': '',
#    'loc': 9}],
#  1043271: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'tänaval',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'varahommikul',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 9}],
#  1076764: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,prop,sg',
#    'frequent_form': 'põlvamaal',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'külas',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'laupäeval',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'noormees',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'jõe',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kõrgelt',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kaldalt',
#    'obl_case': '',
#    'loc': 11}],
#  1099352: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 7}],
#  1099353: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,prop,sg',
#    'frequent_form': 'nikolai',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 13}],
#  1122624: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tartus',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'neljapäeva',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'öösel',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'noormees',
#    'obl_case': '',
#    'loc': 9}],
#  1220612: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'pühapäeval',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 11}],
#  1281164: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'keegi',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'af,indic,main,pl,pres,ps,ps3',
#    'frequent_form': 'on',
#    'obl_case': '',
#    'loc': 9}],
#  1292858: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'neljapäeval',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 6}],
#  1527353: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'siis',
#    'obl_case': '',
#    'loc': 17},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'langevarjuga',
#    'obl_case': '',
#    'loc': 18}],
#  1527373: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'aastal',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'ameeriklane',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'loodeosa',
#    'obl_case': ' kohal',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'lennukist',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'rahaga',
#    'obl_case': '',
#    'loc': 16}],
#  1599437: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'noormees',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'katuselt',
#    'obl_case': '',
#    'loc': 3}],
#  1599438: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'tänaval',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'laupäeval',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'katuselt',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'noormees',
#    'obl_case': '',
#    'loc': 10}],
#  1747503: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'paanikas',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'kellatornist',
#    'obl_case': '',
#    'loc': 12}],
#  1766110: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'gen,prop,sg',
#    'frequent_form': 'manila',
#    'obl_case': ' kohal',
#    'loc': 22},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'langevarjuga',
#    'obl_case': '',
#    'loc': 24}],
#  1766854: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'seejärel',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'langevarjuga',
#    'obl_case': '',
#    'loc': 13},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'eeslinna',
#    'obl_case': ' kohal',
#    'loc': 16}],
#  1766870: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'eeslinna',
#    'obl_case': ' kohal',
#    'loc': 23}],
#  1837004: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'lsd-uimas',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'tüdruk',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'müüritipust',
#    'obl_case': '',
#    'loc': 13}],
#  1933917: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'varas',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'ehmatusest',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,aux,impf,indic,ps,ps3,sg',
#    'frequent_form': 'tuli',
#    'obl_case': '',
#    'loc': 17}],
#  1937872: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'aux,inf',
#    'frequent_form': 'saada',
#    'obl_case': '',
#    'loc': 17}],
#  1941273: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'sealt',
#    'obl_case': '',
#    'loc': 18},
#   {'deprel': 'OBL',
#    'case': 'ill',
#    'feats': 'com,ill,pl',
#    'frequent_form': 'veekeeristesse',
#    'obl_case': '',
#    'loc': 22}],
#  1975651: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'gen,prop,sg',
#    'frequent_form': 'california',
#    'obl_case': ' kohal',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'väikelennukist',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'hollandlanna',
#    'obl_case': '',
#    'loc': 6}],
#  1978462: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'gen,prop,sg',
#    'frequent_form': 'california',
#    'obl_case': ' kohal',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'väikelennukist',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'hollandlanna',
#    'obl_case': '',
#    'loc': 6}],
#  2063956: [{'deprel': 'NSUBJ',
#    'case': '',
#    'feats': 'nominal',
#    'frequent_form': 'di',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'köis',
#    'obl_case': '',
#    'loc': 15}],
#  2075300: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'nüüd',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'af,indic,main,pres,ps,ps3,sg',
#    'frequent_form': 'on',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'ema',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 10}],
#  2244252: [{'deprel': 'NSUBJ',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'inimest',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'purjuspäi',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'joast',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'pimedas',
#    'obl_case': '',
#    'loc': 7}],
#  2310950: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'hotellist',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'tulekahju',
#    'obl_case': ' puhul',
#    'loc': 6}],
#  2330336: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 15},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'nädala',
#    'obl_case': ' algul',
#    'loc': 16},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'tornist',
#    'obl_case': '',
#    'loc': 22}],
#  2330352: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'tornist',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'koidikul',
#    'obl_case': '',
#    'loc': 14}],
#  2427499: [{'deprel': 'ADVMOD',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'ise',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 9}],
#  2471430: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 25}],
#  2559916: [{'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'pundiga',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'katuselt',
#    'obl_case': '',
#    'loc': 6}],
#  2609923: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'aastal',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ta',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'võiduhetkel',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'tribüünilt',
#    'obl_case': '',
#    'loc': 6}],
#  2813022: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'nad',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'katuselt',
#    'obl_case': '',
#    'loc': 10}],
#  3093508: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kuurikatuselt',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'aux,neg',
#    'frequent_form': 'ei',
#    'obl_case': '',
#    'loc': 12}],
#  3094694: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'seejärel',
#    'obl_case': '',
#    'loc': 18},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,pl',
#    'frequent_form': 'silme',
#    'obl_case': ' ees',
#    'loc': 23},
#   {'deprel': 'ADVMOD',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'ise',
#    'obl_case': '',
#    'loc': 26}],
#  3097377: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 2}],
#  3097384: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'laps',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'ADVMOD',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ise',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'korteri',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,impf,indic,mod,ps,ps3,sg',
#    'frequent_form': 'kartis',
#    'obl_case': '',
#    'loc': 11}],
#  3112020: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'fotokunstnik',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'õhtul',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 14}],
#  3112022: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'tipptegija',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,pl',
#    'frequent_form': 'sõnul',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'õhtul',
#    'obl_case': '',
#    'loc': 14},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'kella',
#    'obl_case': '',
#    'loc': 15},
#   {'deprel': 'OBL',
#    'case': 'part',
#    'feats': 'com,part,pl',
#    'frequent_form': 'paiku',
#    'obl_case': '',
#    'loc': 17},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,prop,sg',
#    'frequent_form': 'lasnamäel',
#    'obl_case': '',
#    'loc': 18},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'teel',
#    'obl_case': '',
#    'loc': 20},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 23}],
#  3115867: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'gen,prop,sg',
#    'frequent_form': 'marie',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 11}],
#  3131214: [{'deprel': 'ADVCL',
#    'case': 'nom',
#    'feats': 'nom,pl,pos',
#    'frequent_form': 'õnnestunud',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ta',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 11}],
#  3148127: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'sillalt',
#    'obl_case': '',
#    'loc': 14}],
#  3162996: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ta',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kohe',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'aux,neg',
#    'frequent_form': 'ei',
#    'obl_case': '',
#    'loc': 5}],
#  3164533: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'versiooni',
#    'obl_case': ' kohaselt',
#    'loc': 3},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 13}],
#  3245621: [{'deprel': 'NSUBJ',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'pealvaatajat',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'tr',
#    'feats': 'com,sg,tr',
#    'frequent_form': 'päästmiseks',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'järsakust',
#    'obl_case': '',
#    'loc': 11}],
#  3269918: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'poeg',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'pesalt',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'hirmuga',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,aux,indic,pres,ps,ps3,sg',
#    'frequent_form': 'piilub',
#    'obl_case': '',
#    'loc': 20}],
#  3428947: [{'deprel': 'AUX',
#    'case': '',
#    'feats': 'aux,neg',
#    'frequent_form': 'ei',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'af,imper,main,pres,ps,ps2,sg',
#    'frequent_form': 'ole',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'lennukist',
#    'obl_case': '',
#    'loc': 11}],
#  3438159: [{'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,impf,indic,mod,pl,ps,ps1',
#    'frequent_form': 'nägime',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'tr',
#    'feats': 'com,sg,tr',
#    'frequent_form': 'vältimiseks',
#    'obl_case': '',
#    'loc': 14},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'kaldast',
#    'obl_case': '',
#    'loc': 15}],
#  3450850: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'kabineti',
#    'obl_case': '',
#    'loc': 16},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 17}],
#  3450858: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 14}],
#  3450860: [{'deprel': 'OBJ',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'viga',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 4}],
#  3569708: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'noormees',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'kolmapäeval',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'raadiomasti',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'platvormilt',
#    'obl_case': '',
#    'loc': 6}],
#  3569710: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,pl',
#    'frequent_form': 'sõnul',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kõrguselt',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'masti',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'platvormilt',
#    'obl_case': '',
#    'loc': 10}],
#  3590542: [{'deprel': 'OBL',
#    'case': 'tr',
#    'feats': 'com,sg,tr',
#    'frequent_form': 'päästmiseks',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,pl',
#    'frequent_form': 'pealtvaatajad',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'kõrgusest',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'järsakust',
#    'obl_case': '',
#    'loc': 8}],
#  3654507: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kiiresti',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 3}],
#  3683490: [{'deprel': 'OBL',
#    'case': 'ill',
#    'feats': 'com,ill,sg',
#    'frequent_form': 'haiglasse',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 8}],
#  3696602: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kiiresti',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 3}],
#  3735947: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'kella',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'ajal',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'sõle',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,prop,sg',
#    'frequent_form': 'jevgeni',
#    'obl_case': '',
#    'loc': 13}],
#  3941184: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'kirstu',
#    'obl_case': ' otsast',
#    'loc': 16}],
#  3976224: [{'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,aux,impf,indic,ps,ps3,sg',
#    'frequent_form': 'sai',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ta',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'õnnest',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'palmi',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'otsast',
#    'obl_case': '',
#    'loc': 12}],
#  3981177: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'pärastlöunal',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,prop,sg',
#    'frequent_form': 'harjumaal',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'pangalt',
#    'obl_case': '',
#    'loc': 11}],
#  3981179: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'sönul',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'eestlane',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'pangalt',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'laupäeval',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'OBL',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'kella',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBL',
#    'case': 'part',
#    'feats': 'com,part,pl',
#    'frequent_form': 'paiku',
#    'obl_case': '',
#    'loc': 14}],
#  4090915: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'comp,nom,pl',
#    'frequent_form': 'nooremad',
#    'obl_case': '',
#    'loc': 14},
#   {'deprel': 'ADVMOD',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ise',
#    'obl_case': '',
#    'loc': 16}],
#  4129507: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'ometi',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'aux,neg',
#    'frequent_form': 'ei',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'nad',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kunagi',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'vabatahtlikult',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'astangust',
#    'obl_case': '',
#    'loc': 8}],
#  4233194: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'ööl',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'ilmselt',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'põgenemisel',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'naine',
#    'obl_case': '',
#    'loc': 12}],
#  4347410: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,pl',
#    'frequent_form': 'andmetel',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ta',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 15}],
#  4484018: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'peadirektor',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': '10-korruse',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 9}],
#  4595077: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tartus',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'varahommikul',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'joobes',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kaarsillalt',
#    'obl_case': '',
#    'loc': 7}],
#  4596634: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'mansardkorruse',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 7}],
#  4634109: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'katuselt',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'indic,main,neg,pres,ps',
#    'frequent_form': 'anna',
#    'obl_case': '',
#    'loc': 10}],
#  4641380: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'õhtul',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'maja',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 8}],
#  4641386: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'elumaja',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'af,impf,indic,main,ps,ps3,sg',
#    'frequent_form': 'oli',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 11}],
#  4656206: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,pl',
#    'frequent_form': 'inimesed',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'kartuses',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,pl',
#    'frequent_form': 'rõdudelt',
#    'obl_case': '',
#    'loc': 12}],
#  4694453: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'alžeerlanna',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'vaatamist',
#    'obl_case': ' pärast',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'šoki',
#    'obl_case': ' tõttu',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'korteri',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 13}],
#  4759636: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'juht',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,pl',
#    'frequent_form': 'jõupingutustest',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'posti',
#    'obl_case': ' hoolimata',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'otsast',
#    'obl_case': '',
#    'loc': 11}],
#  4783459: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'pardalviibinu',
#    'obl_case': '',
#    'loc': 23},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'langevarjuga',
#    'obl_case': '',
#    'loc': 25}],
#  5049136: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  5049144: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'poiss',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'af,impf,indic,mod,ps,ps3,sg',
#    'frequent_form': 'oli',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 14}],
#  5232777: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ta',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 14}],
#  5304617: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'ise',
#    'obl_case': '',
#    'loc': 10}],
#  5361280: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kõrguselt',
#    'obl_case': '',
#    'loc': 28},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'langevarjuga',
#    'obl_case': '',
#    'loc': 29},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'presidendiraamatukogu',
#    'obl_case': ' kohal',
#    'loc': 31}],
#  5368643: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'kandidaat',
#    'obl_case': '',
#    'loc': 23},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'kõrbes',
#    'obl_case': '',
#    'loc': 25},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'üksi',
#    'obl_case': '',
#    'loc': 26},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'lennukist',
#    'obl_case': '',
#    'loc': 27}],
#  5532226: [{'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,impf,indic,main,ps,ps3,sg',
#    'frequent_form': 'hakkas',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'lavalt',
#    'obl_case': '',
#    'loc': 12}],
#  5667172: [{'deprel': 'OBL',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'kell',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'haiglas',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korruselt',
#    'obl_case': '',
#    'loc': 13},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'patsient',
#    'obl_case': '',
#    'loc': 15}],
#  5815205: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'laupäeval',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'joast',
#    'obl_case': '',
#    'loc': 3}],
#  5815207: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'joast',
#    'obl_case': '',
#    'loc': 6}],
#  5815209: [{'deprel': 'AUX',
#    'case': '',
#    'feats': 'main,neg,pres,ps,quot',
#    'frequent_form': 'olevat',
#    'obl_case': '',
#    'loc': 21},
#   {'deprel': 'NSUBJ',
#    'case': 'adit',
#    'feats': 'adit,com,sg',
#    'frequent_form': 'marti',
#    'obl_case': '',
#    'loc': 26},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'joast',
#    'obl_case': '',
#    'loc': 33}],
#  5835635: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'muinasjutus',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kaljult',
#    'obl_case': '',
#    'loc': 6}],
#  5850918: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'siis',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kaljult',
#    'obl_case': '',
#    'loc': 12}],
#  5885698: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'tänaval',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'poiss',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 8}],
#  5890436: [{'deprel': 'OBL',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'aastat',
#    'obl_case': ' tagasi',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tallinnas',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'ehituskraana',
#    'obl_case': ' otsast',
#    'loc': 6}],
#  5982102: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'sealt',
#    'obl_case': '',
#    'loc': 14},
#   {'deprel': 'OBL',
#    'case': 'ill',
#    'feats': 'com,ill,sg',
#    'frequent_form': 'pudelisse',
#    'obl_case': '',
#    'loc': 17}],
#  6061518: [{'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,impf,indic,mod,ps,ps2,sg',
#    'frequent_form': 'jõudsid',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'NSUBJ',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'meest',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 14}],
#  6070519: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'kaskadöör',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'adit',
#    'feats': 'adit,com,sg',
#    'frequent_form': 'hullusärki',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'es',
#    'feats': 'es,pos,sg',
#    'frequent_form': 'seotuna',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'tõstukilt',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kõrguselt',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,sg',
#    'frequent_form': 'nööriga',
#    'obl_case': '',
#    'loc': 11}],
#  6092606: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'kooliõpetaja',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'kom',
#    'feats': 'com,kom,pl',
#    'frequent_form': 'aktsiatega',
#    'obl_case': ' koos',
#    'loc': 17},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 21}],
#  6284514: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'egiptuses',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'NSUBJ',
#    'case': 'part',
#    'feats': 'com,part,sg',
#    'frequent_form': 'inimest',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'paanikas',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 6}],
#  6315724: [{'deprel': 'ADVCL',
#    'case': 'nom',
#    'feats': 'nom,pos,sg',
#    'frequent_form': 'eluohtlik',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,pl',
#    'frequent_form': 'lapsed',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,pl',
#    'frequent_form': 'akendest',
#    'obl_case': '',
#    'loc': 13}],
#  6341793: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 3}],
#  6341794: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,pl',
#    'frequent_form': 'andmetel',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'af,impf,indic,main,ps,ps3,sg',
#    'frequent_form': 'oli',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mees',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'maja',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 13}],
#  6372865: [{'deprel': 'OBL',
#    'case': 'es',
#    'feats': 'es,pl,pos',
#    'frequent_form': 'väikestena',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'muudkui',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 6}],
#  6398151: [{'deprel': 'XCOMP',
#    'case': 'tr',
#    'feats': 'com,sg,tr',
# ...
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'vanglas',
#    'obl_case': '',
#    'loc': 15}],
#  25800262: [{'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,indic,mod,pres,ps,ps2,sg',
#    'frequent_form': 'armastad',
#    'obl_case': '',
#    'loc': 13},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 16}],
#  26185948: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'in,prop,sg',
#    'frequent_form': 'tartus',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'esmaspäeval',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'tänaval',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'naine',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 11}],
#  26404109: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'OBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'korteri',
#    'obl_case': '',
#    'loc': 12},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 13}],
#  26404110: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,prop,sg',
#    'frequent_form': 'raigo',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'kell',
#    'obl_case': '',
#    'loc': 6}],
#  26452604: [{'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'lsd-uimas',
#    'obl_case': '',
#    'loc': 10},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'tüdruk',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'müüritipust',
#    'obl_case': '',
#    'loc': 12}],
#  26595008: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'toolilt',
#    'obl_case': '',
#    'loc': 13}],
#  27167106: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ma',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kuskilt',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'siis',
#    'obl_case': '',
#    'loc': 6}],
#  27167118: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'sa',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kuskilt',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'korrusest',
#    'obl_case': '',
#    'loc': 9},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'siis',
#    'obl_case': '',
#    'loc': 11},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'tõenäosus',
#    'obl_case': '',
#    'loc': 12}],
#  27168136: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'keegi',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'sillalt',
#    'obl_case': '',
#    'loc': 9}],
#  27168215: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'pilvelõhkujalt',
#    'obl_case': '',
#    'loc': 9}],
#  27169233: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'mitte',
#    'obl_case': '',
#    'loc': 13},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'aux,indic,neg,pres,ps',
#    'frequent_form': 'ära',
#    'obl_case': '',
#    'loc': 14},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'katuselt',
#    'obl_case': '',
#    'loc': 16}],
#  27170442: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,pl',
#    'frequent_form': 'meil',
#    'obl_case': '',
#    'loc': 20},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'pohh',
#    'obl_case': '',
#    'loc': 23},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'ju',
#    'obl_case': '',
#    'loc': 24},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kas',
#    'obl_case': '',
#    'loc': 25},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'mats',
#    'obl_case': '',
#    'loc': 27},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kuskil',
#    'obl_case': '',
#    'loc': 28},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kaljult',
#    'obl_case': '',
#    'loc': 30}],
#  27207896: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ma',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'katuselt',
#    'obl_case': '',
#    'loc': 6}],
#  27225712: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'pea',
#    'obl_case': ' ees',
#    'loc': 35},
#   {'deprel': 'OBL',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'rehv',
#    'obl_case': '',
#    'loc': 37},
#   {'deprel': 'OBL',
#    'case': 'in',
#    'feats': 'com,in,sg',
#    'frequent_form': 'kaelas',
#    'obl_case': '',
#    'loc': 38},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'täispuhutult',
#    'obl_case': '',
#    'loc': 39},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'korralt',
#    'obl_case': '',
#    'loc': 41}],
#  27347445: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'siis',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'gen,prop,sg',
#    'frequent_form': 'lissu',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'kummuti',
#    'obl_case': ' pealt',
#    'loc': 4}],
#  27473070: [{'deprel': 'ADVCL',
#    'case': '',
#    'feats': 'af,aux,impf,indic,ps,ps3,sg',
#    'frequent_form': 'lahkus',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'lihtsalt',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 11}],
#  28089657: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'pointer',
#    'obl_case': '',
#    'loc': 14},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'pidevalt',
#    'obl_case': '',
#    'loc': 16},
#   {'deprel': 'OBL',
#    'case': 'part',
#    'feats': 'com,part,pl',
#    'frequent_form': 'vaskusse',
#    'obl_case': '',
#    'loc': 18},
#   {'deprel': 'OBL',
#    'case': 'adit',
#    'feats': 'adit,com,sg',
#    'frequent_form': 'nurka',
#    'obl_case': '',
#    'loc': 19}],
#  28090206: [{'deprel': 'CSUBJ',
#    'case': '',
#    'feats': 'aux,inf',
#    'frequent_form': 'liigutada',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'aux,neg',
#    'frequent_form': 'ei',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'AUX',
#    'case': '',
#    'feats': 'indic,main,neg,pres,ps',
#    'frequent_form': 'saa',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'ill',
#    'feats': 'ill,pos,sg',
#    'frequent_form': 'vasakusse',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'adit',
#    'feats': 'adit,com,sg',
#    'frequent_form': 'nurka',
#    'obl_case': '',
#    'loc': 10}],
#  28177480: [{'deprel': 'OBL',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'pohhui',
#    'obl_case': '',
#    'loc': 2},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ma',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  28202390: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 2}],
#  29114949: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'siis',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29157452: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29157453: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29158964: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29158965: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29159938: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'himaalajast',
#    'obl_case': '',
#    'loc': 4}],
#  29199885: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 6}],
#  29308974: [{'deprel': 'OBL',
#    'case': 'ad',
#    'feats': 'ad,com,sg',
#    'frequent_form': 'korral',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'sa',
#    'obl_case': '',
#    'loc': 7}],
#  29328715: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'kuskilt',
#    'obl_case': '',
#    'loc': 5},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'simsa',
#    'obl_case': '',
#    'loc': 6}],
#  29375984: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kaljult',
#    'obl_case': '',
#    'loc': 6}],
#  29390220: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'sa',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': 'abes',
#    'feats': 'abes,com,sg',
#    'frequent_form': 'langevarjuta',
#    'obl_case': ' ilma',
#    'loc': 6},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'lennukist',
#    'obl_case': '',
#    'loc': 7}],
#  29498622: [{'deprel': 'AUX',
#    'case': '',
#    'feats': 'aux,neg',
#    'frequent_form': 'ei',
#    'obl_case': '',
#    'loc': 7}],
#  29566887: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'bionicboyy_eemal',
#    'obl_case': '',
#    'loc': 1},
#   {'deprel': 'NSUBJ',
#    'case': '',
#    'feats': 'nominal',
#    'frequent_form': 'ok',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ma',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'XCOMP',
#    'case': 'ill',
#    'feats': 'aux,ill,ps,sup',
#    'frequent_form': 'magama',
#    'obl_case': '',
#    'loc': 6},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'ka',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'ADVMOD',
#    'case': '',
#    'feats': 'post',
#    'frequent_form': 'enne',
#    'obl_case': '',
#    'loc': 8},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 10}],
#  29585270: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'com,nom,sg',
#    'frequent_form': 'blondiin',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'kaljult',
#    'obl_case': '',
#    'loc': 7}],
#  29590331: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'ma',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'rõdult',
#    'obl_case': '',
#    'loc': 5}],
#  29619436: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 4}],
#  29619471: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 4}],
#  29643332: [{'deprel': 'ADVMOD',
#    'case': '',
#    'feats': '',
#    'frequent_form': 'siis',
#    'obl_case': '',
#    'loc': 4}],
#  29658900: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 18}],
#  29778815: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29778816: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29778870: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29778871: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29778873: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'trilala-trulala',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  29778876: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 7},
#   {'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,sg',
#    'frequent_form': 'sa',
#    'obl_case': '',
#    'loc': 8}],
#  29802440: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 10}],
#  29837076: [{'deprel': 'NSUBJ',
#    'case': 'nom',
#    'feats': 'nom,pl',
#    'frequent_form': 'kes',
#    'obl_case': '',
#    'loc': 5}],
#  29845034: [{'deprel': 'OBL',
#    'case': 'abl',
#    'feats': 'abl,com,sg',
#    'frequent_form': 'katuselt',
#    'obl_case': '',
#    'loc': 4},
#   {'deprel': 'OBL',
#    'case': '',
#    'feats': 'nominal',
#    'frequent_form': 've',
#    'obl_case': '',
#    'loc': 6}],
#  30000646: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 14}],
#  30009887: [{'deprel': 'NSUBJ',
#    'case': 'gen',
#    'feats': 'com,gen,sg',
#    'frequent_form': 'nuki',
#    'obl_case': '',
#    'loc': 3},
#   {'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 5}],
#  30026715: [{'deprel': 'OBL',
#    'case': 'el',
#    'feats': 'com,el,sg',
#    'frequent_form': 'aknast',
#    'obl_case': '',
#    'loc': 11}]}

# %%
# %%time

for v in unique_10:
    verb_compound = '' # kui compound osi rohkem kui 1, siis eraldatakse komaga
    verb = ''
    splitted = v.split()
    if len(splitted) > 1:
        for i in range(len(splitted)):
            if 'V' in Text(splitted[i]).tag_layer('morph_analysis').morph_analysis.partofspeech[0]:
                verb = splitted[i]
            else:
                verb_compound = splitted[i]
    else:
        verb = v
    transactions = v31.get_transactions(verb=verb, verb_compound=verb_compound)
    raw_transactions = v31._raw_transactions
    splitted_joined = '_'.join(splitted)
    with open(f'transactions/raw_trans_{splitted_joined}.json', 'w') as f: 
        json.dump(raw_transactions, f)
# Out:
# CPU times: total: 4min 6s
# Wall time: 33min

# %%
# mustrite otsing ja esinemissageduste leidmine

path = 'transactions/'

len1_grouped = df_len1.groupby('word') # grouping both dataframes by verbs
len2_grouped = df_len2.groupby('word')

case_mapping = {'nom': 'nom',  # nimetav
                'g': 'gen',  # omastav
                'p': 'part',  # osastav
                'adt': 'adit',  # lyh sisse
                'ill': 'ill',  # sisse
                'in': 'in',  # sees
                'el': 'el',  # seest
                'all': 'all',  # alale
                'ad': 'ad',  # alal
                'abl': 'abl',  # alalt
                'tr': 'tr',  # saav
                'ter': 'term',  # rajav
                'es': 'es',  # olev
                'ab': 'abes',  # ilma
                'kom': 'kom'}  # kaasa

for filename in os.listdir(path):
    raw_transactions = ''
    verb = ' '.join(re.sub(r'raw_trans_(\D+).json', r'\1', filename).split('_'))
    
    with open(os.path.join(path, filename)) as f:
        raw_transactions = json.load(f)
    
    result = dict()
    for name, group in len1_grouped:
        if name == verb:
            pattern_freq_list = []
            
            for idx, row in group.iterrows():
                freq = 0
                pattern_members = [row['word_1'].split('.'), row['word_2'].split('.'), row['word_3'].split('.')]
                
                if '?' in pattern_members[0] or '?' in pattern_members[1] or '?' in pattern_members[2]:
                    continue # esialgu ignoreeritakse sõnu, mis pole ei kääne, verb ega kaassõna
                    
                meaning = []
                pattern = []
                examples = []
                
                for member in pattern_members:
                    if len(member) == 1:
                        if member[0] == '':
                            continue
                        else:
                            meaning.append('case')
                            pattern.append(member[0])
                    else:
                        if member[1] == 'v':
                            meaning.append('verb')
                            pattern.append(member[0])
                        else:
                            meaning.append('adp')
                            pattern.append(member[0])
                
                for key, kids in raw_transactions.items():
                    found_pattern = [False]*len(pattern)
                    freq_forms = []
                    
                    for i in range(len(pattern)):
                        for kid in kids:
                            if kid['deprel'] == 'OBL' and meaning[i] == 'case':
                                if kid['case'] == case_mapping[pattern[i]]:
                                    found_pattern[i] = True
                                    freq_forms.append(kid['frequent_form'])
                            elif meaning[i] == 'verb':
                                if 'sup' in kid['feats'].split(',') or 'inf' in kid['feats'].split(','):
                                    found_pattern[i] = True
                                    freq_forms.append(kid['frequent_form'])
                            else:
                                if kid['obl_case'] == pattern[i]:
                                    found_pattern[i] = True
                                    freq_forms.append(kid['obl_case'])
                    if all(found_pattern):
                        freq+=1
                        examples.append(freq_forms)
                        
                pattern_freq_list.append([' '.join(pattern), [' '.join(e) for e in examples][:3], freq]) # pattern, frequent forms, frequency
                
            result[verb] = pattern_freq_list
            

    print(result)
# Out:
# {'aasima': [['p', ['aastat', 'karja', 'lihvimist'], 3], ['g kallal', [], 0]]}
# {'abielluma': [['kom', ['temaga', 'mehega', 'meestega'], 1607]]}
# {'abikätt ulatama': [['all', [], 0]]}
# {}
# {'abstraheeruma': [['el', ['tegelikkusest', 'arvamusartiklist', 'nimest'], 3]]}
# {'adresseerima': [['p', ['seda'], 1], ['all', ['abistajatele', 'haridusministrile', 'persoonile'], 83]]}
# {'aevastama': [['g peale', [], 0]]}
# {'agiteerima': [['p', ['päeva üldkoosolekut', 'laulu', 'aega'], 7]]}
# {'ahistama': [['p', ['aastakümneid', 'lahkuminekut', 'aastat'], 31]]}
# {'ahvima': [['p', [], 0]]}

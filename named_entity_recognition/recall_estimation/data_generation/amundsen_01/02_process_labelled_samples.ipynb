# %% [markdown]
# # Workflow for processing manual labellings
#
# This workflow takes the output file that can be obtained by exporting to JSON in Labelstudio and does some basic analysis on it.

# %% [markdown]
# ## I. Consistency with th benchmark setup
#
# * Check that LabelStudio files are properly named
# * Check that LabelStudio files are properly labelled

# %%
import json

filename = 'labelled_data/substringtagger_labels/koond_1000_levinumad_labelled.json'

#check it can be opened and json loaded
with open(filename,'r',encoding='UTF-8') as f:
    data = json.load(f)

# %%
for task in data:
    #we have one annotation per text in this setup
    assert len(task['annotations']) == 1
    #check that the task has been annotated by someone
    assert task['annotations'][0]['completed_by'] > 0
    #check that yes or no has been chosen
    assert task['annotations'][0]['result'][-1]['value']['choices'][0] in ['yes','no']

# %% [markdown]
# ## II. File export
#
# * Export files to right ouptut format to be used in the benchmark.
# * Do some basic analysis of lables and labelling time to detect something really odd
# * Try to detect biased labelling where labeller has chosen easy/non-typical subset to label.

# %% [markdown]
# ### Working with files from labelstudio
#
# This step takes the files from labelstudio and extracts those texts where the annotator chose "yes" and therefore are in the recall set.

# %%
import json

with open('labelled_data/substringtagger_labels/koond_1000_levinumad_labelled.json','r',encoding='UTF-8') as f:
    data = json.load(f)

# %%
recall_set = []

for txt in data:
    if txt['annotations'][0]['result'][-1]['value']['choices'][0] == 'yes':
        #recall set contains of the raw sentence and the tagged span
        recall_set.append([txt['data']['text'],txt['annotations'][0]['result'][0]['value']])

# %%
recall_set
# Out:
# [['Kutsume kõiki huvilisi 17. mail kell 11 Hurmi järve äärde külavisiooni talgutele !',
#   {'start': 46, 'end': 51, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['14. dets. 1936. a. Peipsi järvelt 7 kalurit...milline relvastus meie piirivalvuritel , kas on kordonites kuulipildujaid , kuidas on ülemuste nimed ja aukraadid .',
#   {'start': 26, 'end': 33, 'text': 'järvelt', 'labels': ['v172_geo_terms']}],
#  ['Ta teenis Aegna saarel ning mängis sõjaväe orkestris .',
#   {'start': 16, 'end': 22, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['“ Ja just siia Lagedile , Pirita jõe ja Leivajõe vahelisele saarele . ”',
#   {'start': 33, 'end': 36, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Opa , Ilsnä , Ipiku , Mäemõisa , Karkla , Kirbla , Koiva , Koivaliina , Kuivaste , Kuramaa , Kööna , Alamõisa , Vana-Liivimaa , Lemsalu , Loodi , Lutsi , Luke , Väike-Salatsi , Nausküla , Pedeli jõgi , Pedetsi jõgi , Reikküla järv , Räisaku , Ruhja jõgi , Salatsi , Salatsi jõgi , Uue-Salatsi , Säde jõgi , Sältnä , Talli , Tiikre , Tõrsa jõgi , Vaidva jõgi , Läti Valga , Vana-Laitsna e Laitsna , Vastse-Laitsna , Vana-Salatsi , Võnnu , Läti Liivimaa',
#   {'start': 210, 'end': 214, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['vastavalt määruse ( EMÜ ) nr 1601/92 artiklile 2 reguleeritakse kõnealuse korra alusel vajadust eespoolmainitud määruse lisas loetletud toodete järele , mis on mõeldud Kanaari saartel vahetult inimtoiduks tarbimiseks ning töötlemiseks ja pakendamiseks ; kõnealuseid vajadusi hinnatakse igal aastal prognoositava tarnebilansi alusel , mille võib aasta jooksul saarte vajaduste muutumist arvesse võttes üle vaadata ; töötleva ja pakenditööstuse vajaduste hindamiseks võib kohalikule turule viidavate või tavapärasel viisil ülejäänud ühendusse veetavate toodete osas koostada eraldi prognoositava tarnebilansi .',
#   {'start': 176, 'end': 183, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['nõukogu määruses ( EMÜ ) nr 1601/92 ,  6  muudetud komisjoni määrusega ( EMÜ ) nr 3714/92 ,  7  määratakse kindlaks kohalik tootmistoetus inimtoiduks ettenähtud kartulite Kanaari saartel tootmise jaoks ; toetuse summat tuleks kohandada eespool nimetatud sätete kohaselt ;',
#   {'start': 179, 'end': 186, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Väljas oli vali pakane , nii et isegi Paldiski meri oli jääs .',
#   {'start': 47, 'end': 51, 'text': 'meri', 'labels': ['v172_geo_terms']}],
#  ['Tervelt kolmekümne ühel kontserdil , millest enamik tasuta ning osa jõudis maainimesele päris koju - Kärusse , Koeru , Prangli saarele .',
#   {'start': 127, 'end': 134, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Teisipäevaks oli Pärnu jõgi suvise tasemega võrreldes 3 meetrit ja 65 sentimeetrit tõusnud , kirjutas Pärnu Postimees .',
#   {'start': 23, 'end': 27, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['Kas ka Peipsi-Pihkva järv on territoriaalvesi või ei ole ?',
#   {'start': 21, 'end': 25, 'text': 'järv', 'labels': ['v172_geo_terms']}],
#  ["0011 Prantsusmaa : Atlandi ookeani ja Põhjamere rannikualad 0012 Prantsusmaa : Vahemere rannikualad 0041 Saksamaa : Põhjamere rannikualad 0042 Saksamaa : Läänemere rannikualad 0043 Saksamaa : Reini jõgi 0061 Ühendkuningriik 0062 Mani saar 0063 Kanalisaared 0111 Hispaania : põhjapoolne Atlandi ookeani rannikualad 0112 Hispaania : Vahemere rannikualad ja Atlandi ookeani lõunapoolsed rannikualad 0301 Rootsi : Läänemere rannikualad 0302 Rootsi : Põhjamere rannikualad 0521 Türgi : Musta mere rannikualad 0522 Türgi : Vahemere rannikualad 0751 Venemaa : Musta mere rannikualad 0752 Venemaa : Läänemere rannikualad 0753 Venemaa : Aasia rannikualad 2041 Maroko : Vahemere rannikualad 2042 Maroko : Lääne-Aafrika rannikualad 2201 Egiptus : Vahemere rannikualad 2202 Egiptus : Punase mere rannikualad 6241 Iisrael : Vahemere rannikualad 6242 Iisrael : Punase mere rannikualad 6321 Saudi Araabia : Punase mere rannikualad 6322 Saudi Araabia : Pärsia lahe rannikualad 4001 Ameerika Ühendriigid : Atlandi ookeani põhjapoolsed rannikualad 4002 Ameerika Ühendriigid : Atlandi ookeani lõunapoolsed rannikualad 4003 Ameerika Ühendriigid : Mehhiko laht 4004 Ameerika Ühendriigid : Vaikse ookeani lõunapoolsed rannikualad 4005 Ameerika Ühendriigid : Vaikse ookeani põhjapoolsed rannikualad 4006 Ameerika Ühendriigid : Suur järvistu 4007 Puerto Rico 4041 Kanada : Atlandi ookeani rannikualad 4042 Kanada : Suur järvistu , St Lawrence'i ülemjooks 4043 Kanada : läänerannik 4801 Colombia : põhjarannik 4802 Colombia : läänerannik lisakoodid 9991 Avamererajatised 9992 Liit- ja mujal määratlemata alad",
#   {'start': 899, 'end': 903, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Enim ülemääraseid toitaineid kannab Haapsalu lahte Taebla jõgi .',
#   {'start': 58, 'end': 62, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['Piirissaare vald ei ole mitte ainuke saarekene Peipsi järve sees , Praagas on ka omad probleemid .',
#   {'start': 54, 'end': 59, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Palmipuudepühal meisterdati Tarbekunstimuuseumi töötoas Tiina Piisangu juhendamisel munatopse materjalist , mille kunstnik oli Pirita jõe kallastelt korjanud .',
#   {'start': 134, 'end': 137, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Vilsandi saarel on juba loomade vähesuse tõttu karjatamisega probleeme .',
#   {'start': 9, 'end': 15, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Soome klubivuti valitseja Valkeakoski Haka piirdus Fääri saartel Torshavniga heideldes 1 : 1 viigiga .',
#   {'start': 57, 'end': 64, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Puksiir kaotas tühja pargase ära 29. novembril Ruhnu saare all , kust see kandus tormituultega Saaremaa rannikule ja jooksis Sõrves Vintri küla all madalikule kinni , kirjutas Meie Maa .',
#   {'start': 53, 'end': 58, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Manhattani saare , kus kaubanduskeskus asus , avastas 17. sajandil Henry Hudson 11. septembril .',
#   {'start': 11, 'end': 16, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['70ndatel maaparandajate süvendatud kanalis voolab Emajõe poole Pori jõgi .',
#   {'start': 68, 'end': 72, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['Futureman meenutab nii oma välimuselt kui muusikale pühendumiselt mõnd Lõunamere saarte šamaani , kes on emigreerunud rahvaste ja kultuuride paabelisse Ameerikas .',
#   {'start': 81, 'end': 87, 'text': 'saarte', 'labels': ['v172_geo_terms']}],
#  ['NÕUKOGU MÄÄRUS ( EÜ ) nr 2549/2000 , millega kehtestatakse Iiri mere ( ICES VIIa rajoon ) tursavarude taastamise täiendavad tehnilised meetmed 17. november 2000',
#   {'start': 64, 'end': 68, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['USA armee kinnitas eile , et kolmapäeval Bagdadi lähedal Eufrati jõest leitud surnu oli üks kolmest kadunud USA sõdurist .',
#   {'start': 65, 'end': 70, 'text': 'jõest', 'labels': ['v172_geo_terms']}],
#  ['Kui näiteks uurida atlasest Maui saart , võib vaadata videoklippe surfamisest , sukeldumisest või rannas ujuvatest kirevatest kaladest .',
#   {'start': 33, 'end': 38, 'text': 'saart', 'labels': ['v172_geo_terms']}],
#  ['Pädev asutus korraldab tarnepiirangute süsteemi nii , et oleks võimalik artikli 10 lõikes 1 osutatud koguste tarnimine Kanaari saartele .',
#   {'start': 127,
#    'end': 135,
#    'text': 'saartele',
#    'labels': ['v172_geo_terms']}],
#  ['Sertifikaaditaotluse ja sertifikaadi lahtrisse 24 tehakse märge “ Kanaari saartel kasutatav sertifikaat ” .',
#   {'start': 74, 'end': 81, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Eesti meremehed sõitsid ju ka Balti merest välja ja pidid tõenäoliselt olema niisuguste asjadega kursis .',
#   {'start': 36, 'end': 42, 'text': 'merest', 'labels': ['v172_geo_terms']}],
#  ['Avaldusest loen välja , et Narva jõgi oli juba 5000 aastat tagasi demokraatia piiriks .',
#   {'start': 33, 'end': 37, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['Tema armee piiras Leningradi ja tegi Hitlerile 1943. aasta sügisel ettepaneku taanduda plaanipäraselt , ära vedades kõik oma laod ja varud Narva jõe , Peipsi järve , Pihkva Velikaja jõe joonele ning võtta seal püsikaitse sisse ja kaitsta Baltikumi .',
#   {'start': 158, 'end': 163, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['6. augustil jõustus Eesti ja Venemaa vaheline kokkulepe laevaliiklusest Peipsi , Lämmi- ja Pihkva järve vesikonnas .',
#   {'start': 98, 'end': 103, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Egeuse mere lõunaosas Karpat-hose saare kohal põrkasid eile kokku Kreeka ja Türgi hävitaja , teatas Kreeka kaitseministeerium .',
#   {'start': 7, 'end': 11, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Kariibi meres asuva Haiti saare elanikud jäädvustasid videolindile taevas lennanud kaks objekti , mis nende sõnul võisid UFOd olla .',
#   {'start': 8, 'end': 13, 'text': 'meres', 'labels': ['v172_geo_terms']}],
#  ['Merivälja tee läheb Pirita jõe silla ja Randvere tee vahel remonti mai alguses .',
#   {'start': 27, 'end': 30, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Homo erectuse esimene leid tehti 1891. a. Jaava saare idaosas Trinili paikkonnas .',
#   {'start': 48, 'end': 53, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['« White force »  -Inimesesd - Blackmooni saarel elavad inimesed',
#   {'start': 41, 'end': 47, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Päikese kustumisel oleks siiski ka häid külgi : päikesepistet ei saaks , nahavähki ei tekiks , õlu ei läheks soojaks , siis saaks paremini Päikese ehitust uurida , ei peaks muretsema ultraviolettkiirguse pärast , ei pea puhkusemõnusid Kanaari saartele otsima minema - kõikjal on ju sama temperatuur !',
#   {'start': 243,
#    'end': 251,
#    'text': 'saartele',
#    'labels': ['v172_geo_terms']}],
#  ['Ma olin eelmises elus Borneo saarel kitsekarjus .',
#   {'start': 29, 'end': 35, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Peab ühe mõnusa pikniku ja tagasi tuleb siis , kui Abruka saare lood vaadatud ja ilu nauditud .',
#   {'start': 58, 'end': 63, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Minoilise kultuuri üks tähtsamaid mälestusmärke väljaspool Kreetat on väljakaevatud Akrotiri linn vulkaanilisel Thera ( Santorini ) saarel , mis 1450. aasta paiku e.m.a.',
#   {'start': 132, 'end': 138, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ["Laevade punkerdamisega tegelevalt NT Marinelt ostis ” Tammsaare ” eelmise aasta 28 . oktoobril Raven Servise INC , mis on registreeritud Bahama saarte ühenduses asukohaga New Providence'i saarel Nassaus .",
#   {'start': 144, 'end': 150, 'text': 'saarte', 'labels': ['v172_geo_terms']}],
#  ['Kas " Lendas üle käopesa " indiaanlane polnud hoopiski äkki Hawaii saartelt ?',
#   {'start': 67, 'end': 75, 'text': 'saartelt', 'labels': ['v172_geo_terms']}],
#  ['Nimelt sukeldusid Shotimaal 19. juulil 1913. aastal , teel koju kohalikust pubist Davonshire järve Doug McMillan ja Henry Willbury selgitamaks , kes on kangem mees hinge kinni pidama .',
#   {'start': 93, 'end': 98, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Ohhoota mere põhjaosa , Hokkaido',
#   {'start': 8, 'end': 12, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['vastavalt osutatud lisa punktile 7.2 tuleb sellised meetmed hoolikalt kohandada Kanaari saarte siseturu oludega vältimaks mis tahes kaubandushäireid ning põhimõtteliselt tuleb nende kasutamist piirata määruse ( EMÜ ) nr 1911/91 artiklis 6 sätestatud ühise tollitariifistiku astmeliseks kohaldamiseks Kanaari saartele ettenähtud üleminekuperioodiga ; seepärast tuleks üleminekuperioodi lõpus pärast kõnealuse impordi olukorraga tutvumist kehtestada sätted meetmete kasutamise võimaliku pikendamise kohta pärast osutatud perioodi lõppemist ;',
#   {'start': 308,
#    'end': 316,
#    'text': 'saartele',
#    'labels': ['v172_geo_terms']}],
#  ['Musta mere loodeosas algasid eile NATO ja rahupartnerlusprogrammi riikide mereväeõppused " Cooperative Partner " .',
#   {'start': 6, 'end': 10, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['" Rabahane arvas WI loendist välja põhjusel , et tal pole seost riskialade ehk Musta ja Egeuse mere ning Lõuna – Uuraliga .',
#   {'start': 95, 'end': 99, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['» Teisipäeval külastas president Oscar Berger õnnetuspaika , mis asub pealinnast 186 km läänes turistide seas populaarse Atitlani järve ääres .',
#   {'start': 130, 'end': 135, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Aianduskeskus Ceres avas Tallinnas Harku järve ääres esimese etapi oma uuenevast keskusest , 1000ruutmeetrise müügipinna .',
#   {'start': 41, 'end': 46, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['2001. aasta kevadel püüdis Evald Turro Pedja jõest 13kilose haugi .',
#   {'start': 45, 'end': 50, 'text': 'jõest', 'labels': ['v172_geo_terms']}],
#  ['Kalarikas Pedja jõgi',
#   {'start': 16, 'end': 20, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['Saksamaa 12. aprilli 1994. aasta taotluses esitatud teabele , mille alusel mandri ja Ida-Friisi saarte vahelised regulaarliinid vabastati komijoni otsusega  3  direktiivi 93/75/EMÜ artikli 5 lõike 4 kohaldamisest , on lisatud 23. veebruari 1996. aasta teatis regulaarliinide kohta mandri ja Põhja-Friisi saarte vahel ; selles teatises palus Saksamaa komisjonil vabastada relulaarliinid Dagebülli ja Wittgüni ( Amrumi saar ) ning Schüttsieli ja Hallig Langenessi vahel , mille ülesõiduajad on 2 tundi ;',
#   {'start': 96, 'end': 102, 'text': 'saarte', 'labels': ['v172_geo_terms']}],
#  ['« Paris Match ületas igasuguse piiri ja tuleb paika panna , » pahvatas Nicolas Sarkozy partei aseesimees Herve Mariton ja lisas , et tolle nädalalehe on juba oma eraelu avalikustamise eest kohtusse kaevanud endine peaminister Jean-Pierre Raffarin ( fotod luksuspuhkusest Kreeta saarel ) ja minister Jean-Louis Borloo ( ülesvõtted rajust nädalalõpust ilma abikaasata ) .',
#   {'start': 278, 'end': 284, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ["Ali bin Ladeni lihtne pulmatseremoonia toimus kolmapäeva õhtul Punase mere ääres Jiddah'linnas .",
#   {'start': 70, 'end': 74, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Mitu surnukeha peitis ta Green Riveri ( Rohelise jõe ) äärde .',
#   {'start': 49, 'end': 52, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Peaauhind on perereis Kanaari saartele , iga nädal loositakse välja perereis Serena veeparki , jalgratas ja rulluisud .',
#   {'start': 30, 'end': 38, 'text': 'saartele', 'labels': ['v172_geo_terms']}],
#  ['Aga nendesse voolas see Ülemiste järvest , kus ei peetud kinni mingist tänapäeva mõiste kohasest sanitaarrežiimist - ujutati ja joodeti loomi jms .',
#   {'start': 33, 'end': 40, 'text': 'järvest', 'labels': ['v172_geo_terms']}],
#  ['Öösel Ahvenamaa saartelt ida poole kiirustanud aktiivne tsüklon viib suurema saju Baltimaadelt Venemaale .',
#   {'start': 16, 'end': 24, 'text': 'saartelt', 'labels': ['v172_geo_terms']}],
#  ['Eesti kultuuri on Fääri saartel tutvustamas Eesti Nukuteater lavastusega " Pöial-Liisi " , muusikud Villu Veski ja Tiit Kalluste ning tekstiilikunstnik Liivia Leškin .',
#   {'start': 24, 'end': 31, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ["Viljandi järve rannakohvikus mängivad algusega kell 22 house'i DJ-d Rain Tolk , Eero Jakobson ja Dr . Valz .",
#   {'start': 9, 'end': 14, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Uus-Guinea saare idaosa ja lähedalasuvaid saari hõlmav Paapua Uus-Guinea sai iseseisvaks 22 aastat tagasi .',
#   {'start': 11, 'end': 16, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Õnnetus juhtus Saarde vallas Nõmme järvel .',
#   {'start': 35, 'end': 41, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Eriti eksootilise ööbimispaigana on korraldajad reklaaminud Viljandi järve .',
#   {'start': 69, 'end': 74, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Äsja Malta saarelt inglise keele õpingutelt naasnud riigikogulane Tiit Mae sõidab varsti jälle välismaale keeletundi .',
#   {'start': 11, 'end': 18, 'text': 'saarelt', 'labels': ['v172_geo_terms']}],
#  ['Bocelli ametliku kodulehe tuurikavas on peale Tallinna kontserdi kirjas veel vaid esinemised 19. juulil New Yorgi Central Parkis ja 26. juulil Capri saarel .',
#   {'start': 149, 'end': 155, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Venemaa ja Norra tuukrid jõudsid eile teha ava Barentsi mere põhjas 108 meetri sügavuses lebava aatomiallveelaeva keresse .',
#   {'start': 56, 'end': 60, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Traditsiooniks kujunenud orelikontsert Leigo järvel küünalde ja lõkete kumas lõpetas eile õhtul selleaastase Leigo järvemuusika , kus tuhandetel muusikahuvilistel oli võimalik osa saada viiest suurest kontserdist .',
#   {'start': 45, 'end': 51, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Jaltas eile ja täna toimuval Läänemere ja Musta mere äärsete riikide tippkohtumisel arutatakse nende maade koostööd ja integreerumist XXI sajandil .',
#   {'start': 48, 'end': 52, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Venemaa president Vladimir Putin suundus pärast FSB aruande saamist Moskvast ära : esimese koolipäeva üritused , visiidid Sahhalini saarele , Tokyosse ja New Yorki .',
#   {'start': 132, 'end': 139, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Sissetungi algul Tšetšeeniasse kinnitasid Vene sõjaväelased , et võtavad oma kontrolli alla vaid vabariigi tasase põhjaosa ning rajavad Tereki jõe vasakkaldale sanitaarkordoni .',
#   {'start': 143, 'end': 146, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Needsamad meremehed aga teenisid Curacao saarel , kus nende ülesanne oli Hollandi võimude abistamine nn . narkosõja pidamisel Kariibi mere regioonis .',
#   {'start': 134, 'end': 138, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Käisime kahes Hiina viiest erimajanduspiirkonnast - Xiamenis ja Lõuna-Hiina meres asuval Hainani saarel .',
#   {'start': 97, 'end': 103, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Nädalalehe Bild am Sonntag arvestuste kohaselt kallineks rohelise poliitiku ettepaneku heakskiitmisel lennureis Saksamaalt Kanaari saartele 320 marka ja Tai Kuningriiki koguni 900 marka .',
#   {'start': 131,
#    'end': 139,
#    'text': 'saartele',
#    'labels': ['v172_geo_terms']}],
#  ['Meteoroloogiapäeval , 23. märtsil murdus Antarktikas lahti kõigi aegade suuruselt teine , Jamaica saarega pindalalt võrdne jäämägi .',
#   {'start': 98, 'end': 105, 'text': 'saarega', 'labels': ['v172_geo_terms']}],
#  ['Esiteks sai Saksamaa pealinn Berliin nime meie esivanematelt , kes hüüdsid seda linna “ Pärna liiniks ” ; Niiluse jõgi sai ristitud , kui eesti meresõitjad seda nähes õhkasid : “ Nii ilus ! ” .',
#   {'start': 114, 'end': 118, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['Hondurasele kuuluvad lisaks ka Bahia saared Kariibi meres , mis maailma suuruselt teise korallrahu osana on suurepärane paik veealuse maailmaga tutvumiseks .',
#   {'start': 37, 'end': 43, 'text': 'saared', 'labels': ['v172_geo_terms']}],
#  ['Saalomoni saared 18 , 46 , 132 .',
#   {'start': 10, 'end': 16, 'text': 'saared', 'labels': ['v172_geo_terms']}],
#  ['Venemaal Pihkva järvel vajus kolmapäeval läbi jää auto koos kolme kalamehega , kellest ühel õnnestus pääseda .',
#   {'start': 16, 'end': 22, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Lennukis ajavööndeid ületades ja tuhandeid mõtteid mõlgutades ei saanud Vaino Väljasel muidugi aimugi olla , et ka kaugel kodumaal , Balti mere kaldal tõusis tema hind iga tunniga .',
#   {'start': 139, 'end': 143, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Tänaseni ei tea täpselt keegi , kui palju Nazino saarele inimesi on maetud ega nende nimesid .',
#   {'start': 49, 'end': 56, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Kõverate ninadega mägedepoegi paistab olema sootuks rohkem kui neid , kelle näojooned võiks pärineda Balti mere äärest .',
#   {'start': 107, 'end': 111, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Ka Pärnu jõkke Reiu jõe suudmealal lasti 120 000 maimu .',
#   {'start': 20, 'end': 23, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Mis see spurt enam päästab , kui enamik Kanaari saartel aset leidnud veemängudest ja ringitormamisest on maha magatud .',
#   {'start': 48, 'end': 55, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Holz jõudis Santorini saarele eile hommikul .',
#   {'start': 22, 'end': 29, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Assoori saartel paiknev väheliikuv kõrgrõhuala ulatub üle Prantsusmaa Vahemere äärde .',
#   {'start': 8, 'end': 15, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Saaremaa Karujärves ja Palojärves 23 , Elva Verevi järves ja Väinjärves 22 , Värska lahes , Viljandi järves , Anne kanalis , Emajões ja Pärnu jões 21 , Türi ja Paide tehisjärvedes , Mustvee lahes , Kubija järves ja Tamula järves 20 , Peipsis 19 , Rõuge Suurjärves ja Kaussjärves 18 , Harku järves 16 ning Lämmijärves 14 kraadi .',
#   {'start': 290, 'end': 296, 'text': 'järves', 'labels': ['v172_geo_terms']}],
#  ['Loch Nessi järve Nessist on saanud koduloom miljonitele inimestele !',
#   {'start': 11, 'end': 16, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Moldova meelitab külalisi iidsete kloostritega Bukoviinas ja on kuulus oma veinide poolest , Must meri pakub suvitajatele kuldseid randu , Transilvaania on teadagi vürst Dracula kodukant .',
#   {'start': 98, 'end': 102, 'text': 'meri', 'labels': ['v172_geo_terms']}],
#  ['Tšiilile kuuluv Robinson Crusoe saar naudib ootamatut ajakirjanduse tähelepanu , sest suure tõenäosusega on seal kindlaks tehtud maailma suurima peidetud varanduse asukoht .',
#   {'start': 32, 'end': 36, 'text': 'saar', 'labels': ['v172_geo_terms']}],
#  ['Suurbritannia eruohvitser Maurice Stradling kirjutab ajalehes Australian , et on põhjalikult uurinud 2000. aastal Barentsi meres koos meeskonnaga uppunud Kurski keret .',
#   {'start': 123, 'end': 128, 'text': 'meres', 'labels': ['v172_geo_terms']}],
#  ['Kohale tulid sõbrad Aruba saarelt',
#   {'start': 26, 'end': 33, 'text': 'saarelt', 'labels': ['v172_geo_terms']}],
#  ['Stockholmi Ingaro saare 17. sajandi kirikus olid laulatust tunnistamas ka Borgi omaaegsed vastased , kaasmaalane Mats Wilander ja rumeenlane Ilie Nastase .',
#   {'start': 18, 'end': 23, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Pärnu jõe kaldad on üsna hukas , jooks juhib tähelepanu sellele valupunktile , põhjendas Jaanson , miks sõudja korraldab üritust mitte enda alal .',
#   {'start': 6, 'end': 9, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Korsika saarelt pärit Laetitia avastasid prantsuse moeloojad 15aastaselt .',
#   {'start': 8, 'end': 15, 'text': 'saarelt', 'labels': ['v172_geo_terms']}],
#  ['Vene Riigiduuma liige Grigori Tomtšin ütles intervjuus Norra telekanalile TV2 , et läinud aasta augustis Barentsi meres uppunud tuumaallveelaeva Kursk pardal olid tuumarelvad .',
#   {'start': 114, 'end': 119, 'text': 'meres', 'labels': ['v172_geo_terms']}],
#  ['Et Fääri saartel teist puhku kollast hoiatuskaarti näinud Viktor Alonen pole mängukõlbulik ja rivistusse naaseb karistusest vabanenud Andres Oper , pidi Teitur algkoosseisu kallal pead murdma .',
#   {'start': 9, 'end': 16, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Üleeile hommikul leiti Pärnu jõe jäält surnuks külmununa 42aastane pärnakas Kaido .',
#   {'start': 29, 'end': 32, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['329 elanikuga Vormsi saarel töötab 124 tööealisest mehest 74 ja 89 naisest 45 .',
#   {'start': 21, 'end': 27, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Neeva jõel on niisuguste purjekatega võisteldud Peetri ajast saadik .',
#   {'start': 6, 'end': 10, 'text': 'jõel', 'labels': ['v172_geo_terms']}],
#  ['24 . 02 . 1996 Pyla vs Fääri saared 2 : 2',
#   {'start': 29, 'end': 35, 'text': 'saared', 'labels': ['v172_geo_terms']}],
#  ['Tartu Ülikoolis kehakultuuri õppiv noormees osaleb augustis Sitsiilia saarel toimuvatel ülemaailmsetel üliõpilaste spordimängudel .',
#   {'start': 70, 'end': 76, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Poolast mööda Oderi jõge allavoolu liikuv tulvalaine paistab olevat enne Ida-Saksamaale jõudmist vaibunud , kuid ametiisikute sõnul on veel vara lõplikku pääsemist kuulutada .',
#   {'start': 20, 'end': 24, 'text': 'jõge', 'labels': ['v172_geo_terms']}],
#  ['Venemaa ja Jaapan jätkavad kõnelusi Kuriili saarte staatuse üle , mille okupeerimine Nõukogude Liidu poolt on siiani takistanud rahulepingu sõlmimist kahe riigi vahel , et lõpetada formaalselt Teist maailmasõda , kuid lootus jõuda lepingu allkirjastamiseni selle aasta lõpuks on väga väike .',
#   {'start': 44, 'end': 50, 'text': 'saarte', 'labels': ['v172_geo_terms']}],
#  ['Nagu üks algusepanijaist on öelnud : “ 99,9 protsenti ideest sai alguse Aura jõest . ”',
#   {'start': 77, 'end': 82, 'text': 'jõest', 'labels': ['v172_geo_terms']}],
#  ["Porquerolles'i saar",
#   {'start': 15, 'end': 19, 'text': 'saar', 'labels': ['v172_geo_terms']}],
#  ['Ning Jüri Jaanson loetles talle omasel moel tugijõudude tegematajätmisi : Tatjana liigub Pärnu jõel kaatriga , mille päevinäinud mootor aeg-ajalt treeningu hukkab ; kahepaate , mida neljase vennaskond juuli teisel poolel vahelduse toomiseks ja konkurentsi kasvatamiseks vajab , ei paista veel ; hinnatud massööri käe alla saab end sättida siis , kui too aega leiab .',
#   {'start': 95, 'end': 99, 'text': 'jõel', 'labels': ['v172_geo_terms']}],
#  ['Dubrovniku ajaloolise vanalinna pommitamine ja Horvaatia Aadria mere äärse ranniku ründamine Jugoslaavia armee ja Serbia poolmilitaarsete rühmituste poolt aastatel 1991-92 tõi kaasa maailma avalikkuse terava hukkamõistu , mis sundis tollase Serbia presidendi Slobodan Milosevici rünnakud lõpetama .',
#   {'start': 64, 'end': 68, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['8. aprillil müüdi Mõisaküla kudumisvabriku hooned 50 000 krooni eest Bahama saartel registreeritud firmale Eastern European Holding Inc , mida esindab jurist Tõnu Tuulas .',
#   {'start': 76, 'end': 83, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['13. juunil lõpes Bornholmi saarel Gudhjemis kaheksas Baltikumi filmi- ja telefestival .',
#   {'start': 27, 'end': 33, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Anne kanal , Emajõgi , Võrtsjärv Trepimäe kohal , Peipsi järv Kallaste juures , samuti Pangodi järv ning Saadjärv on Tartu tervisekaitsetalituse kontrolli all .',
#   {'start': 95, 'end': 99, 'text': 'järv', 'labels': ['v172_geo_terms']}],
#  ['Ahja jõe ürgorus suvekodu eviva Ingridi ( 73 ) põues on hirm , et Lonny huvireisid meelitavad Taevaskoja looduskaitsealale inimesi , kes loodusest ei hooli .',
#   {'start': 5, 'end': 8, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['11.55 Luurerühm alustab jalgsiretke Suur-Pakri saarelt mandrile .',
#   {'start': 47, 'end': 54, 'text': 'saarelt', 'labels': ['v172_geo_terms']}],
#  ['Kaks korda Jägala jões sunnitud supluse üle elanud peaminister Mart Laar pääses seekord kanuumatkalt kuiva nahaga .',
#   {'start': 18, 'end': 22, 'text': 'jões', 'labels': ['v172_geo_terms']}],
#  ['Lugu rubriigist Rannamäe ja Roosilehe seiklused Kanaari saartel ?',
#   {'start': 56, 'end': 63, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Miks ei võiks näiteks Tšaikovski balletti " Luikede järv " Jäneda järve ehtsate luikede taustal etendada ?',
#   {'start': 66, 'end': 71, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Siiani on firma umbes 10 miljonit tonni naftat vedanud Venemaalt välja Ventspilsi , samuti Soome , Poola ning Valge mere ja Musta mere sadamate kaudu .',
#   {'start': 116, 'end': 120, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Felix Kottale tegi juba viiekümnendatel muret Vaikse järve saastumine , küllap paneks järve lagastatud kallas Kotta praegugi teravalt sõna sekka ütlema .',
#   {'start': 53, 'end': 58, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Üheks valusaks näiteks tõigi ta Verevi järve : rand kõrkjastub , atraktsioone on vähe , tulekahju järel ei suudetud tukkegi ära koristada .',
#   {'start': 39, 'end': 44, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Valga lähedalt Pedeli jõelt esmaspäeval kanuumatka alustanud poolteistsada inimest katkestasid reisi eile Tartu lähedal , riskimata tormihirmu tõttu Peipsile aerutada .',
#   {'start': 22, 'end': 27, 'text': 'jõelt', 'labels': ['v172_geo_terms']}],
#  ['( 71 ) kaevas oma nooruspäevil 1952. aastal ekspeditsioonil olles koos teiste fossiilidega Piusa jõe kaldajärsakust välja luutükikese , millele esialgu erilist tähelepanu pöörata ei osatud .',
#   {'start': 97, 'end': 100, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['See info ärgitas ema ja isa teistest otsijatest vastassuunas , Kirbu jõest Audru poole tütart hõikama .',
#   {'start': 69, 'end': 74, 'text': 'jõest', 'labels': ['v172_geo_terms']}],
#  ['6. juulil Kihnu saarel toimunud kakluse uurimiseks on politsei algatanud Rene Kuulmanni suhtes kaks kriminaalasja .',
#   {'start': 16, 'end': 22, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Prangli saarelt oli üles leitud kohalik kalastusühingu esimees , kes oli huvitav oma otseütlemise pärast .',
#   {'start': 8, 'end': 15, 'text': 'saarelt', 'labels': ['v172_geo_terms']}],
#  ['Ööpäev läbi Kloostri jõe ääres müttav poldripump lööb 500 kantmeetrit jõevett kunagi kaevatud drenaažikraavidesse .',
#   {'start': 21, 'end': 24, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Pirita jõe ääres maa ostnud autoärimehel piisas ühest päevast ja 14 000 kroonist , et lasta buldooseritega kokku lükata 46-aastase naise sünnikodu , mille rusude alla jäi ka enamik üürilise vara .',
#   {'start': 7, 'end': 10, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Eesti suursaadik Venemaal  Mart Helme  :  Praegu on täiesti unikaalne ajalooline situatsioon , esimest korda saame Balti merd ümbritsevate riikide ja lisaks Venemaaga minna edasi koos , festivaliga me mõtlesimegi selle situatsiooni fikseerida .',
#   {'start': 121, 'end': 125, 'text': 'merd', 'labels': ['v172_geo_terms']}],
#  ['Hiljaaegu kuulutas Äripäev oma esiküljel arssinapikkuste tähtedega võitu justnagu oleks punavägi või landesveer taas taganema sunnitud ehk vähemasti Ümera jõel midagi ära tehtud .',
#   {'start': 155, 'end': 159, 'text': 'jõel', 'labels': ['v172_geo_terms']}],
#  ['Aga kuna ka nõukogude inimesele on puhkus ette nähtud , siis tutvub meie naiskomnoor Musta mere rannikul klanitud meesterahvaga , kes osutub tegelikult hoopiski ühe välisriigi spiooniks ( kusjuures seda , kas too välisriik leiab kinoekraanil konkretiseerimist või jääb nö. kunstiliselt mitmetähenduslikuks , ei otsusta mitte Goskino ametnike maitse , vaid poliitbüroo poolt aetav välispoliitika ) .',
#   {'start': 91, 'end': 95, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Kavandatava paepargi alale jäävad kahe ja poole tuhande aasta vanused Proosa muinaspõllud ja kalmed , ning Peeter Suure aegsed merekindluse kaevikute liinid koos Pirita jõe äärsete vanade heinamaadega .',
#   {'start': 169, 'end': 172, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Kus juba salaplaani peetakse , seal ka salaja pealt kuulatakse - kõlab Surnukirstu saare vanasõna .',
#   {'start': 83, 'end': 88, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['“ Sellist laeva teist Balti meres ei ole .',
#   {'start': 28, 'end': 33, 'text': 'meres', 'labels': ['v172_geo_terms']}],
#  ['Seni pidas augustis ehitatud tamm Ülemiste järve vett laitmatult kinni .',
#   {'start': 43, 'end': 48, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Nagu geograafia tunnis näitavad nad maakaardi pealt , kust on pärit nende vanemad ja vanavanemad : Riia - Samara - Kaspia meri - Maardu , Aserbaidzhaan , Mordva .',
#   {'start': 122, 'end': 126, 'text': 'meri', 'labels': ['v172_geo_terms']}],
#  ['Tänapäeval viljeldakse troopika ja subtroopika vööndis Hiinas , Indoneesias , Sri Lankal , Kariibi mere saartel , Lõuna-Ameerikas ja mõnedes Aafrika maades .',
#   {'start': 99, 'end': 103, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Teadlaste ja looduskaitsjate hinnangul on Pärnu jõe tõkestamine võimalik ainult siis , kui ehitatakse funktsioneeriv kalatrepp , et kalad pääseksid jõe ülemjooksule kudema .',
#   {'start': 48, 'end': 51, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Bahama saarte lipu all sõitev Hamane Spirit võttis ASile E.O.S. kuuluvast Termoili Maardu terminaalist peale 85 000 tonni masuuti .',
#   {'start': 7, 'end': 13, 'text': 'saarte', 'labels': ['v172_geo_terms']}],
#  ['Järgmine ohver , 17-aastane neiu , langes sugukirge rahuldada püüdnud maniakkide küüsi 6. septembri hilisõhtul Narva jõe ääres .',
#   {'start': 117, 'end': 120, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Viimati tabas Vaindloo saare uus radar võõra aluse piiri ületamas Uhtju saarest 12 meremiili ( ligi 23 kilomeetri ) kaugusel kirdes üleeile hilisõhtul ning nii nagu eelmistel kordadel , aluse meeskond Eesti piirivalve kutsungile ei vastanud .',
#   {'start': 72, 'end': 79, 'text': 'saarest', 'labels': ['v172_geo_terms']}],
#  ['Siinkohal tähelepanu : Härjapea jõe alamjooksul paiknevad ka hingusele läinud Hoiupanga uhiuus maja ja takkaotsa valmiv Ühispanga pilvelõhkuja !!!',
#   {'start': 32, 'end': 35, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Mees , kelle soontes voolab kõrvuti eesti ja ühe Kariibi mere saare rahva veri , peab ennast järjekindlalt saaremaalaseks .',
#   {'start': 57, 'end': 61, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Harku järve ääres 2,3 hektari suurusele maatükile ehitusluba ootava AS Ventri juhatuse esimehe Andres Pärna sõnul on Hürden koos Haabersti linnaosa vanema Vladimir Panoviga tema ettevõtmistele juba aastaid kaikaid kodaraisse loopinud .',
#   {'start': 6, 'end': 11, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Chris De Burgh  Tamula järve ääres 21. augustil kell 19.30.',
#   {'start': 23, 'end': 28, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Samasugune ootamatus tabas üleeile hommikul ligi sadat Ida-Virumaal Peipsi järve lähedal asuva Iisaku peret , kelle kodutehnikast vooluhäire tagajärjel vaid kärsahais alles jäi .',
#   {'start': 75, 'end': 80, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['“ Teisel hommikul , kui ma Jakobsoni matusselt tagasi läksin , tuli ühel metsa vahelisel teel suur kuuehobuse postvanker järgi , seal oli küll oma tosin sõitjat peal , Jakobsoni õed Natalie ja Rosalie , doktor Veske , Hugo Treffner , Jakob Kõrv , paar üliõppijat ja paar Peeterburgi herrat , kõik ei mahtunuvad istuma , õnnis Veske seisis püsti , kübar ühes peos ja teise käega lõi takti , nad laulsivad sealsamas tehtud laulu : Vändra jõe haljal kaldal Kerkib küngas puude all , Liivasõmer teda katab , Keda leinad , Eestimaa !',
#   {'start': 436, 'end': 439, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Karm ( 29 ) leidis , et tema eestvedamisel 1997. aasta 9.-11. septembrini korraldatud õppuse “ Vilets elu ” viimase vaatuse , mis pidi lõppema neljateistkraadises vees kolmekilomeetrise veetakistuse ületamisega Suur-Pakri saare tipust mandrile , oli ta piisava hoolikusega ette valmistanud .',
#   {'start': 222, 'end': 227, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Pettusin natukene legendaarses Doonau jões , mis polnud kaugeltki nii sinine kui räägitakse , kirjutatakse ja lauldakse .',
#   {'start': 38, 'end': 42, 'text': 'jões', 'labels': ['v172_geo_terms']}],
#  ['Veel nimetas 20% vastanutest viimase aasta kurvastava asjaoluna Viljandi järve ja ranna kehva seisukorda .',
#   {'start': 73, 'end': 78, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Kuid paat , millele nad trügisid , pommitati puruks , ja nii leidis vanaema viimase puhkepaiga Balti mere põhjas .',
#   {'start': 101, 'end': 105, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['1990. aastal Pärnu jõe suudme lähedalt leitud keskaegse laeva säilmete rohkem kui viis aastat kestnud konserveerimine on lõpule jõudnud ja leid pannakse vaatamiseks välja Pärnu muuseumis .',
#   {'start': 19, 'end': 22, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Filmitud on Sosva , Ljapini ja Konda jõe ääres .',
#   {'start': 37, 'end': 40, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Võru Kalevi spordijuhi Mati Ojandu sõnul on jooksul aastatega kujunenud oma raudvara , kes on Tamula järve jooksul kohal igal kevadel .',
#   {'start': 101, 'end': 106, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Uudisteagentuur AP nimetas Fort Dixit kaasaegseks Ellise saareks , meenutades omaaegset miljonite immigrantide saabumiskohta New Yorgi sadamas .',
#   {'start': 57, 'end': 64, 'text': 'saareks', 'labels': ['v172_geo_terms']}],
#  ['Narva jõel , kahel pool Eesti-Vene piiri elavad eakad põlisvenelased saavad ühelt kaldalt teisele häält pingutades surmateateid hõikuda , kuid mitte teineteisele kätt ulatada .',
#   {'start': 6, 'end': 10, 'text': 'jõel', 'labels': ['v172_geo_terms']}],
#  ['Eesti Vabariigis saadeti riigikukutajad Kihnu saarele , sest sealsed kõrvad olid kihutuskõnedele kurdid .',
#   {'start': 46, 'end': 53, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['raport dramaatilisest kalastusretkest Valge mere äärde',
#   {'start': 44, 'end': 48, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Ja muidugi tuleb mainida ka Bali saart .',
#   {'start': 33, 'end': 38, 'text': 'saart', 'labels': ['v172_geo_terms']}],
#  ['Harrastuskalamehed koguvad allkirju pöördumisele , milles paluvad linnavalitsusel Viljandi järvel võrgupüügi keelata .',
#   {'start': 91, 'end': 97, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Koos oma väikese tütre Wilmaga (  Ebba Hultqvist  ) asub Johan uut elu sisse seadma Stockholmi arhipelaagis paikneval Saltö saarel , et võtta seal üle oma äia klientuur .',
#   {'start': 124, 'end': 130, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Marssal Jegorovi 1936. aastal antud korralduse kohaselt tuli Balti mere laevastikul olla valmis Soome , Eesti ja Läti laevastike hävitamiseks .',
#   {'start': 67, 'end': 71, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Viimase aja arengud Lõuna-Hiina meres on vaid tõestanud probleemi tundlikkust ning olnud järjekordseks tunnistuseks Hiina agressiivsest välispoliitikast , pole aga pakkunud kriisile mingit lahendust .',
#   {'start': 32, 'end': 37, 'text': 'meres', 'labels': ['v172_geo_terms']}],
#  ['Siit ka alguses vihjatud paralleelid admiral Cheng Hoga , kelle “ riigivisiidid ” India ookeanile viisid lõpuks koguni Punasele merele ning Ida-Aafrika rannikul asuvale Sansibarile .',
#   {'start': 128, 'end': 134, 'text': 'merele', 'labels': ['v172_geo_terms']}],
#  ['Taifuun Okinawa saare lähedal segas ligi 30 000 reisijat , Jaapanis tühistati üle kahesaja siselennu .',
#   {'start': 16, 'end': 21, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Mõte on selles , et pakkuda alternatiiv Võru Tamula järve kontsertidele .',
#   {'start': 52, 'end': 57, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Elva jõe ja järvede ning Kavilda jõe seisundit on jälginud ja uurinud Zooloogia ja Botaanika Instituudi töötajad .',
#   {'start': 5, 'end': 8, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Seišelli saared on tõeline looduseime tänu sealse graniidisaarte grupi ainulaadsusele .',
#   {'start': 9, 'end': 15, 'text': 'saared', 'labels': ['v172_geo_terms']}],
#  ['Koo mõtles Kommodoori saartest .',
#   {'start': 22, 'end': 30, 'text': 'saartest', 'labels': ['v172_geo_terms']}],
#  ['Võidab EM-ralli Assoori saartel .',
#   {'start': 24, 'end': 31, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Leib ju teadis , et Eidelkind senior pidi saama peatselt seitsmekümne seitsmeseks — iga , mil Kõigevägevam pühakirja järgi meid juba enda juurde ootavat — , kuid vanahärra Joshua särasilmist kiirgus veel küllaga erilist lummavat vaimujõudu ; kui tarvis , võiks ta juba homme — nagu tema nimekaim , Moosese järelkäija — oma valitud rahva läbi Jordani jõe viia , pillutada laiali viie vaenulise kuninga väed ja Jeeriku linna maatasa teha.',
#   {'start': 350, 'end': 353, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Kui buss aga üle Luuga jõe viimaks Ivangorod-Narva piiripunkti jõudis , lõi omanik mind Eesti piirivalvuritele letti .',
#   {'start': 23, 'end': 26, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Ajakirjandus on teinud märtri 21aastasest Meelisest , kes väidetavalt politsei süül jäi ilma oma võidureisist Kanaari saartele .',
#   {'start': 118,
#    'end': 126,
#    'text': 'saartele',
#    'labels': ['v172_geo_terms']}],
#  ['Ta pühendab oma elu hindude jaoks püha Gangese jõe säästmisele .',
#   {'start': 47, 'end': 50, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Ta korraldas Niitväljal VISA golfiturniire ning viis Eesti golfisõpru talviti soojale Tobago saarele mängima .',
#   {'start': 93, 'end': 100, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Ta oli parasjagu ankrus Punasel merel Suessi lahes , kui kaks Saksa luurelennukit viskasid sellele neli pommi .',
#   {'start': 32, 'end': 37, 'text': 'merel', 'labels': ['v172_geo_terms']}],
#  ['Õhtul kella 21 ajal süüdatakse Sooru järve ääres võidutulest kõrgele loitev jaanituli .',
#   {'start': 37, 'end': 42, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Kaspia meri on koht , kust on pärit suur osa üle maailma pakutavate pidulaudade kalahõrgutistest .',
#   {'start': 7, 'end': 11, 'text': 'meri', 'labels': ['v172_geo_terms']}],
#  ['Esialgsetel andmetel kasutas Kariibi mere saartel Turksil ja Caicos registreeritud fondi teeneid alates 1995. aastast kuni viimase ajani umbes 80 Eesti ärimeestega seotud maksuvaba firmat .',
#   {'start': 37, 'end': 41, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Siis rakendaski Nõukogude Liit oma õigust seoses Tartu rahulepinguga ja võttis tagasi kõik oma põlised maad Narva jõe tagant ja Petserimaa .',
#   {'start': 114, 'end': 117, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Sumatra saare lähedal asuva USA lennukikandja USS Abraham Lincoli kapten Kendall L. Card teatas , et kuus kopteris olnud meeskonnaliiget sai raskelt viga , neli kergemalt .',
#   {'start': 8, 'end': 13, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['25.07.2003 kella 21.40 ajal uppus Lääne-Viru maakonnas Tamsalu vallas Porkuni järves Arvo ( s. 1935 ) .',
#   {'start': 78, 'end': 84, 'text': 'järves', 'labels': ['v172_geo_terms']}],
#  ['Koipsi saare juhtumist rääkides on Kristiina Ojuland kidakeelne .',
#   {'start': 7, 'end': 12, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Haugipüük on siseveekogudel keelatud 10. maini ning Peipsi ja Pihkva järvel 15. maini .',
#   {'start': 69, 'end': 75, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Egiptusesse lendab 4,5 -5 tundi , Kanaari saartele 6 tundi , " selgitab Horizon Traveli tootejuht Tiina Peterson .',
#   {'start': 42, 'end': 50, 'text': 'saartele', 'labels': ['v172_geo_terms']}],
#  ['Reede päeval Läänemere , Musta mere ja Kaspia mere piirkonna riigipeade foorumil peetud kõnes tõdes Rüütel , et riigi ülim eesmärk peaks olema oma rahva huvide kaitse ja heaolu .',
#   {'start': 31, 'end': 35, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Briti kuningliku mereväe Balti mere laevastiku eskaader jõudis Tallinna reidile 12. detsembril 1918. aastal .',
#   {'start': 31, 'end': 35, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['" Progressi " Narva jõe veerde võib kerkida klaasilinnak .',
#   {'start': 20, 'end': 23, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Kanaari saartel asuvas Barlovento linnas saavutati saastet mittetekitavate valgustite paigaldamisega öise tänavavalgustuse pealt 65 % energia kokkuhoidu . "',
#   {'start': 8, 'end': 15, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Peipsi järve kalurite mõrdades hukkub tuhandeid kiisku , kelle hapnikupuudus on kalda lähedale ajanud .',
#   {'start': 7, 'end': 12, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Mootorpaat nelja mehega pardal väljus ööl vastu teisipäeva kella kahe ajal Ruhnu saarelt merele , et söita Pärnusse .',
#   {'start': 81, 'end': 88, 'text': 'saarelt', 'labels': ['v172_geo_terms']}],
#  ['Alates 1920. aasta Tartu rahulepingust on Soome riik arvanud , et Espoo ligidal asuv Kytö saar kuulub riigile , kuid riigi ja Espoo linna kohtuvaidluses kohaliku suguvõsaga jäid kõik kolm kaotajaks .',
#   {'start': 90, 'end': 94, 'text': 'saar', 'labels': ['v172_geo_terms']}],
#  ['Me oleme arutanud küsimust Narva uue silla ehitamisest kahepoolsete jõududega ja ilmselt üks olulisi küsimusi on ka Narva jõel asuva Vene hüdroelektrijaama nr 13 ühiskasutamine , sest seda punkti käsitletakse samas lepingus , millest jutt oli .',
#   {'start': 122, 'end': 126, 'text': 'jõel', 'labels': ['v172_geo_terms']}],
#  ['Aja selg sirgu , liiguta natuke õlgu ja puusi - ära ole staatiline nagu Lindakivi , mis on aastasadu Ülemiste järves sammalt kogunud .',
#   {'start': 110, 'end': 116, 'text': 'järves', 'labels': ['v172_geo_terms']}],
#  ['" Sueebi ( Balti ) mere idakaldal on Aestii ( Eesti ) .',
#   {'start': 19, 'end': 23, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Keila jõe suudmesse hakati riigiametnike puhkekodu rajama aastatel 1934-35.',
#   {'start': 6, 'end': 9, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['USA luurelennuki EP-3E Aries II kokkupõrge Hiina F-8 hävituslennukiga pühapäeva varahommikul Hainan saare lõunaosas on tekitanud kahe riigi suhetesse teravaid pingeid .',
#   {'start': 100, 'end': 105, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Tuumajaam kütab Družkšiai järve normaalsega võrreldes kolm-neli kraadi soojemaks .',
#   {'start': 26, 'end': 31, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Venemaal , Leena jõel liikuma hakanud jäämassid tekitasid mitmes kohas tõsiseid ummistusi , mille tagajärjel veepind tõusis ning uputas Lenski linnas 540 maja .',
#   {'start': 17, 'end': 21, 'text': 'jõel', 'labels': ['v172_geo_terms']}],
#  ['Kui eelmine kindralkuberner oli eeskujuks eeskätt hiinlastele ja üldse asiaatidele , siis uuest peaksid innustust leidma Kanadas elavad haitilased ja teised Kariibi mere maadest pärit inimesed .',
#   {'start': 165, 'end': 169, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Tokyo teadusmuuseumi teadlase Tsunemi Kubodera juhitud meeskond sai 8meetrise hiidkalmaari fotole ajal , kui see ründas oma saaki ligi 915 meetri sügavusel merepõhjas Jaapani Bonini saarte lähistel .',
#   {'start': 182, 'end': 188, 'text': 'saarte', 'labels': ['v172_geo_terms']}],
#  ['Grupeering alustab legendi kohaselt põgenemist Peipsi järvel suunaga lõunasse .',
#   {'start': 54, 'end': 60, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Tallinna Botaanikaaed taasavab täna üle Pirita jõe kulgeva Tallinna ainsa rippsilla , mille eelmine botaanikaaia juhtkond kaks aastat tagasi läbi saagis .',
#   {'start': 47, 'end': 50, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Iljumžinov pakkus , et Lenini võiks panna alalisele väljapanekule Kaspia mere äärse Kalmõkkia pealinna Elistasse .',
#   {'start': 73, 'end': 77, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['" Raamatu lõpus saavad kokku kõik tegelased , kelle eluteed esimeses osas lahku läksid - nii need , kes Kohatu saarelt Rootsi läksid , kui ka need , kes Eestisse maha jäid .',
#   {'start': 111, 'end': 118, 'text': 'saarelt', 'labels': ['v172_geo_terms']}],
#  ['Kohatu saare rannarootslase Erik Norrmani päevikuna alustatud lugu viib lugejad kolmandas osas Siberisse , tagasi Eesti NSV-sse ja uude Eesti Vabariiki .',
#   {'start': 7, 'end': 12, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Ümber maailma sõitev Lennuk on jõudnud Assoori saartele .',
#   {'start': 47, 'end': 55, 'text': 'saartele', 'labels': ['v172_geo_terms']}],
#  ['Eesti sotsiaalministeerium on Taani tööministeeriumi juhitavas Balti mere regiooni tööturupoliitika arendamise sektorprogrammis osalenud alates selle käivitamisest 1999. aasta alguses .',
#   {'start': 69, 'end': 73, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Abu Sayyafi esindaja Abu Sabaya ütles eile telefonikõnes kohalikule raadiole , et Filipiinide lõunaosas Dos Palmase kuurordis pantvangi võetud inimesed on jagatud kahte gruppi ja peidetud Basilani ja Jolo saarele .',
#   {'start': 205, 'end': 212, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Uus-Meremaa lõunatipus , Campbelli saarel algab maailma suurim rotijaht , teatasid kohalikud võimud .',
#   {'start': 35, 'end': 41, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
# ...
#  ['Peterburi linnakohus mõistis Vaindloo saare lähedal uppunud Runner 4 reostuse likvideerimise kulude eest riigile välja 5,9 miljonit krooni .',
#   {'start': 38, 'end': 43, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['" Võtame näiteks Pirita jõe .',
#   {'start': 24, 'end': 27, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Venemaa peaprokuröri Vladimir Ustinovi käe all sündinud aruanne Kurski huku kohta nendib , et kaks aastat tagasi aset leidnud tragöödia Barentsi merel põhjustas torpeedost lekkinud äärmiselt kergestisüttiva vesinikperoksiid-kütuse plahvatus .',
#   {'start': 145, 'end': 150, 'text': 'merel', 'labels': ['v172_geo_terms']}],
#  ['Peipsi järvel loata nakkevõrkudega kalastanud Jevgenile määrati karistuseks 5400kroonine trahv , Ennole 1200 krooni ja Maidole 3000 krooni trahvi .',
#   {'start': 7, 'end': 13, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['07.07.2002 kella 22.45 ajal võtsid Tallinnas Paldiski maanteel Harku järve juures kaks tundmatut noormeest noa ähvardusel ära Aleksei ( s. 1989 ) jalgratta .',
#   {'start': 69, 'end': 74, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Stroomi rannas ning Harku ja Tamula järves oli vesi 17 , Kakumäel , Pärnu rannas ja Emajões 16 ning Pirital 15 kraadi .',
#   {'start': 36, 'end': 42, 'text': 'järves', 'labels': ['v172_geo_terms']}],
#  ['Kanadasse jõudmise järel on ta peaaegu kuni nädala lõpuni Torontost umbes saja kilomeetri kaugusel katoliiklikus pansionaadis Simcoe järvel Strawberry saarel .',
#   {'start': 133, 'end': 139, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Briti keskkonnaametnike sõ-nul oli tegemist selle sajandi suurima üleujutusega Briti saartel .',
#   {'start': 85, 'end': 92, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Peipsi järve kallas oli eile Omedust kuni Varnjani täis randa uhutud kalaraipeid , mis kohati vänget lehka levitasid .',
#   {'start': 7, 'end': 12, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Harku järve jää paksus on 25-30 cm , kaldas jää üsna lahti ja jääle minek eluohtlik .',
#   {'start': 6, 'end': 11, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Cooki saared ( Uus-Meremaa valdus )',
#   {'start': 6, 'end': 12, 'text': 'saared', 'labels': ['v172_geo_terms']}],
#  ['Ajalooliseks nimetatud rahuplaani üle on kavas mai lõpus pidada rahvahääletus , millest võtavad osa kogu Iirimaa saare elanikud .',
#   {'start': 113, 'end': 118, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Lennureisil Madeira saarele stjuardessiga tülli läinud purjus Eesti turistidele kutsuti lennujaama vastu politsei .',
#   {'start': 20, 'end': 27, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Eestlased saabusid Soome Kariibi meres paiknevate Hollandi Antillide Curacao saarelt ning soovisid sõita Tallinna .',
#   {'start': 77, 'end': 84, 'text': 'saarelt', 'labels': ['v172_geo_terms']}],
#  ['Kohalike elanike sõnul on Pärnu jõe lisajõgi Vihtra külas kiirevooluline ja väga madal , kus lapsed on harjunud suvel jalgupidi mängima .',
#   {'start': 32, 'end': 35, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Laupäeval , 18. juulil oli Harku järvel Euroopa meistrivõistluste käigus hukkunud skuutrisõitja Rivo Jõõras .',
#   {'start': 33, 'end': 39, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Piirivalvurid päästsid koos kohaliku elanikuga neljapäeva pärastlõunal Peipsi järvel uppumissurmast kaks paadisõitjat .',
#   {'start': 78, 'end': 84, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Lisaks fotodele on näha ka tänavu Kaukaasia ekspeditsioonilt Musta mere rannikult kaasatoodud kivikollektsioon , mis tähistab erinevate territooriumide ühenduslüli .',
#   {'start': 67, 'end': 71, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Barcelona krahvinna Maria de las Mercedes de Bourbon suri Kanaari saartel Lanzarote residentsis , kus kuningapere uut aastat vastu võttis .',
#   {'start': 66, 'end': 73, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Samas on teada , et alates novembrist muutuvad tingimused Barentsi merel niivõrd karmiks , et tuukritöid teha pole võimalik .',
#   {'start': 67, 'end': 72, 'text': 'merel', 'labels': ['v172_geo_terms']}],
#  ['Tuumaallveelaev Kursk uppus 12. augustil Barentsi meres Vene Põhjalaevastikus toimunud õppuste ajal.',
#   {'start': 50, 'end': 55, 'text': 'meres', 'labels': ['v172_geo_terms']}],
#  ['Ise nii õbluke ja klibune , aga oma paigast hoiab meelekindlalt kinni nagu Kassari Hiiu saarest .',
#   {'start': 88, 'end': 95, 'text': 'saarest', 'labels': ['v172_geo_terms']}],
#  ['" Kalad tunnevad end Narva jões üle ootuste hästi , " ütleb Tuvikene , " kuid siiski tuleks neid vähem süüa . "',
#   {'start': 27, 'end': 31, 'text': 'jões', 'labels': ['v172_geo_terms']}],
#  ['Peamiseks tüliobjektiks on endine Nõukogude Liidu Musta mere laevastik ja kontroll valdavalt venelastega asustatud krimmi poolsaare üle .',
#   {'start': 56, 'end': 60, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Eesti , Läti , Leedu ja Ameerika Ühendriikide kaitseväelastel on õppuse raames kavas remontida Tallinna Kristliku Hooldekodu supiköök , ehitada välja Viljandimaal Väikemõisa väikelastekodu mänguväljak ja ehitada üle Põltsamaa jõe sild .',
#   {'start': 226, 'end': 229, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Barentsi mere põhjas lebav allveelaev " Kursk " on jätkuvalt vaikne .',
#   {'start': 9, 'end': 13, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Borneo saare Kuchingi linnas saavad edaspidi rangelt karistada ka koeraomanikud , kellel pole koerapidamise luba , ütles linnapea Chan Seng Khai uudisteagentuurile Bernama .',
#   {'start': 7, 'end': 12, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Shetlandi ponid on arenenud Shetlandi saarel põhiliselt *otimaa väikesekasvulistest tööhobustest karmide ilmastikuolude käes - süüa napib , ent puhuvad tugevad tuuled ja möllavad rajud .',
#   {'start': 38, 'end': 44, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Iisrael loobus ka otsusest karmistada jõuvõtteid Jordani jõe läänekaldal ja Gaza sektoris .',
#   {'start': 57, 'end': 60, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Samas on selge , et aja jooksul teeb vesi põhjas lebava tuumaallveelaeva vraki kallal oma töö , mis on suureks ohuks Barentsi mere elukeskkonnale .',
#   {'start': 126, 'end': 130, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['" Tegelikult tõuseb see maapinnale muidugi palju varem - Ölandi saare juures ja lõpeb Venemaa avarustes , aga seal tuntakse seda Balti klindi nime all , " lisas Suuroja .',
#   {'start': 64, 'end': 69, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Piirivalvurid tabasid nädalavahetusel piiririkkumiselt neli lätlast , kellest kaks jäid vahele Valgas ja kaks Peipsi järvel .',
#   {'start': 117, 'end': 123, 'text': 'järvel', 'labels': ['v172_geo_terms']}],
#  ['Seejärel ületati Jordani jõgi ja jõuti Kaananimaale ja taas ei kehtinud tapmiskeeld sealsete kuningate ja rahvaste kohta .',
#   {'start': 25, 'end': 29, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['Kaliforniast pärit Schilling ning veel 16 inimest on vangis rühmituse Abu Sayyaf jõukude käes Jolo saarel , Manilast 960 km lõunas .',
#   {'start': 99, 'end': 105, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Indoneesias Amboni saare rannikul hukkus eile toimunud praamiavariis vähemalt 37 inimest , õnnetuse põhjustas aluse ülekoormatus .',
#   {'start': 19, 'end': 24, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Venemaa suurim naftafirma Lukoil leidis Venemaaale kuuluvast Kaspia mere osast suure naftavälja , sel puhul õnnitles firmat ka Venemaa presidendi kohusetäitja Vladimir Putin .',
#   {'start': 68, 'end': 72, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Maarjamäe kohal läheneb Lasnamäe paekallas merele ning osaliselt merelt võidetud maad mööda piki rannikut edasi sõites tuleb ette Pirita jõgi .',
#   {'start': 137, 'end': 141, 'text': 'jõgi', 'labels': ['v172_geo_terms']}],
#  ['Just selleks oligi vaja Altori omanikud Bahama saarele peita .',
#   {'start': 47, 'end': 54, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Abu Sayyafi liikmed röövisid oma vangid Malaisias üheksa päeva tagasi ja tõid nad Filipiinide lõunaosas asuvale Jolo saarele .',
#   {'start': 117, 'end': 124, 'text': 'saarele', 'labels': ['v172_geo_terms']}],
#  ['Filipiinide sõjaväelased peatasid rünnakud Jolo saarel ümber piiratud islamisisside baasile , et pidada kõnelusi ameeriklasest pantvangi vabastamise üle , mässajad aga keeldusid meest loovutamast , teatas Filipiini ametiisik laupäeval .',
#   {'start': 48, 'end': 54, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['1. veebruaril lekkis Rumeenia ühest kullakaevandusest Tisza jõkke suur hulk tsüaniidi lahjendamiseks kasutatud naatriumhüpokloriidi , mis on hävitanud elu Tiszas ja osaliselt ka Doonau jões .',
#   {'start': 185, 'end': 189, 'text': 'jões', 'labels': ['v172_geo_terms']}],
#  ['Samal ajal on Madagaskari saare üleujutustes hukkunute arvuks teatatud 130.',
#   {'start': 26, 'end': 31, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Oma abi on venelastele pakkunud ka Norra , kes jälgib Vene laevade liikumist Barentsi meres .',
#   {'start': 86, 'end': 91, 'text': 'meres', 'labels': ['v172_geo_terms']}],
#  ['Manija saarel toimub homme laulupidu , kuhu on oodatud ligi poolsada lauljat-tantsijat Viljandist , Tõstamaalt , Audrust ja mujalt .',
#   {'start': 7, 'end': 13, 'text': 'saarel', 'labels': ['v172_geo_terms']}],
#  ['Aegna saare lähedal 1944. aastal uppunud laeva vraki juurest on sukeldujad mõningail andmeil pidevalt leidnud mürske , kuid eksperdi hinnangul lained neid saarele tuua ei tohiks .',
#   {'start': 6, 'end': 11, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Uue metoodika kallal töötasid 11 rahandusministeeriumi ametnikku ja kaks Rootsi eksperti , kes käisid kaks aastat tagasi eksootilisel reisil Seishellide saartel .',
#   {'start': 153, 'end': 160, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Uudisteagentuur Itar-Tass teatas , et Baikali järve toodi elama kümme aafrika krokodilli , et mitmekesistada veekogu loomariiki .',
#   {'start': 46, 'end': 51, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Saksa armeegrupp Nord taganeb Narva jõe - Peipsi järve jooneni .',
#   {'start': 49, 'end': 54, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Ülevõllikiikumise idee autori , Pärnu klubi Vabariigi Võllimees juhatuse liikme Ado Kose hinnangul segas eilset kiikinguvõistlust suppsooja Harku järve ääres vihisev tuul , mis puudeladvad kohati üsna tormiselt õõtsuma pani .',
#   {'start': 146, 'end': 151, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Nii näiteks räägivad galaktikatevahelise kaubandusföderatsiooni juhid jaapani aktsendiga ja Naboo saare primitiivsed pikakõrvalised hõimud meenutavad Kariibi mere saarte elanikke .',
#   {'start': 98, 'end': 103, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Vastuseks Milosevici kangekaelsusele otsustas NATO saata ühe väekoondise Itaalia sadamalinna Brindisisse ja teine liigub Egeuselt Aadria merele piki endise Jugoslaavia rannikut .',
#   {'start': 137, 'end': 143, 'text': 'merele', 'labels': ['v172_geo_terms']}],
#  ['Seoses Rootsi erafirma poolt eesti rahandusametnikele korraldatud koolitusega Seishelli saartel kärgatas ametkondlik äike nii Eestis kui Rootsis .',
#   {'start': 88, 'end': 95, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Kõigi aegade kõrgeim veetase mõõdeti Narva jões 1924. aastal , mil see oli 202 sentimeetrit üle nullpunkti .',
#   {'start': 43, 'end': 47, 'text': 'jões', 'labels': ['v172_geo_terms']}],
#  ['Vormsi saare juures triivis ööl vastu teisipäeva suure tuulega madalikule Tallinnasse teel olnud ujuvkraana , mida puksiir ei suutnud tormiga paigal hoida ; meeskonnaliikmed ei saanud vahejuhtumis vigastada .',
#   {'start': 7, 'end': 12, 'text': 'saare', 'labels': ['v172_geo_terms']}],
#  ['Pärastlõunal käiakse vaatamas Saaremaa dolomiidikaevandust , Kaali järve ja Angla tuulikuid .',
#   {'start': 67, 'end': 72, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['Andres Oper treenib Kehtnas koos Eesti jalgpallikoondisega , kes valmistub EM-valikmänguks võõrsil Fääri saarte vastu , kuigi Aalborgi ründaja peab seda kohtumist laupäeva õhtul kodus telerist vaatama .',
#   {'start': 105, 'end': 111, 'text': 'saarte', 'labels': ['v172_geo_terms']}],
#  ['Tuge-vaim pööristorm tabas 6. juulil Luunjat ja Pangodi järve äärseid maid , tuulepuhangud üle 15 meetri sekundis murdsid puid ka Tõravere lähedal metsades .',
#   {'start': 56, 'end': 61, 'text': 'järve', 'labels': ['v172_geo_terms']}],
#  ['" Kõik teevad näo , et usuvad , ja ronivad üle Lokuta jõele langenud puutüve metsa .',
#   {'start': 54, 'end': 59, 'text': 'jõele', 'labels': ['v172_geo_terms']}],
#  ['27. oktoobril 1969 tabas Ruhnu saart tuulepuhang 48 meetrit sekundis .',
#   {'start': 31, 'end': 36, 'text': 'saart', 'labels': ['v172_geo_terms']}],
#  ['Ühelt poolt jäi Kariibi mere maade suhkrutööstus kängu , teisalt aga suurenes USA vajadus vastava tööjõu järele .',
#   {'start': 24, 'end': 28, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Veiste käsnjat ajuhaigust ehk veistehullust diagnoositi esimest korda Suurbritannias aastal 1986 , kevadeks 2000 ulatus haigestunud lehmade arv Briti saartel aga juba ligi 180 000-ni .',
#   {'start': 150, 'end': 157, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Veelgi enam , kuivõrd populaarset mänksi kassi seostatakse traditsiooniliselt Mani saarega , on temast saanud saare üks olulisemaid sümboleid .',
#   {'start': 83, 'end': 90, 'text': 'saarega', 'labels': ['v172_geo_terms']}],
#  ['Saksa väed olid juba 1915 okupeerinud Läti lõunaosa kuni Daugava jõeni ja umbkaudu kolmveerand miljonit Läti elanikku evakueerus tagalasse .',
#   {'start': 65, 'end': 70, 'text': 'jõeni', 'labels': ['v172_geo_terms']}],
#  ['Lisaks puudub Armeenial väljapääs merele , nende põlised maad Musta mere ja Vahemere ääres on juba hulk sajandeid okupeeritud türklaste poolt .',
#   {'start': 68, 'end': 72, 'text': 'mere', 'labels': ['v172_geo_terms']}],
#  ['Juulis algasid ehitustööd ka Aasia suuruselt teise , 3,2 miljardi USA dollarilise tammi kallal Hongshuihe jõel riigi lõunaosas Guanxi regioonis .',
#   {'start': 106, 'end': 110, 'text': 'jõel', 'labels': ['v172_geo_terms']}],
#  ['Paraku jookseb halastamatus Külvetil liiva : mahedasse jutuvestja tooni , pikkadesse aruteludesse ning “ kunstilisse ” lõpplahendusse , mis tavaliselt saabub mingi kulissidetaguse detaili läbi ( punane buss : “ Kuhu kuulud , Kristjan ? ” ; tolmunud frakk : “ Hommikust kirjakandja tulekuni ” ; urineeriv hiinlane : “ Sellist inimest ei ole ” ; loteriipilet : “ Märgutuli eksinud lindudele ” ; Deelose saar : “ Epidauruse vastus ” ; sombreero : “ Müüriladuja ” ; santsukott : “ Gulliveri käekõrval ” ; saatmata jäänud postkaart : “ Merehaigus ” ) .',
#   {'start': 401, 'end': 405, 'text': 'saar', 'labels': ['v172_geo_terms']}],
#  ['Võib öelda , et uus ajastu maalähedaste objektide otsinguis algas 1995. aasta detsembris , kui läks käiku NASA kordineeritav kaamera NEAT ( Near-Earth Asteroid Tracking system ) , mis töötab USA õhujõudude teleskoobi taga Havai saartel Halcakala kustunud vulkaani tipul .',
#   {'start': 228, 'end': 235, 'text': 'saartel', 'labels': ['v172_geo_terms']}],
#  ['Kuid mind küll ei huvita , kas kirjanduslik Kohatu saar kõigis üksikasjades ikka kattub oma protomaastiku , Ruhnu saarega , kas ajalooliselt asus teatud hetkel peale Erik Norrmanni saarel juhuslikult kusagil veel keegi või oli ta üksinda jne.',
#   {'start': 51, 'end': 55, 'text': 'saar', 'labels': ['v172_geo_terms']}],
#  ['Imekauni Daugava jõe kaldal tundub , et sotsialistlik suurtootmine lõppes alles täna .',
#   {'start': 17, 'end': 20, 'text': 'jõe', 'labels': ['v172_geo_terms']}],
#  ['Kui sakslased Teises maailmasõjas Taani vallutasid , hõivasid inglased Fääri saared .',
#   {'start': 77, 'end': 83, 'text': 'saared', 'labels': ['v172_geo_terms']}],
#  ['Püsivama asulakohana tuntakse Eestis 1960-ndate lõpul avastatud Pulli asulat Pärnu jõe alamjooksul Sindi kohal .',
#   {'start': 83, 'end': 86, 'text': 'jõe', 'labels': ['v172_geo_terms']}]]

# %%
len(recall_set)
# Out:
# 353

# %%
import json

with open('labelled_data/substringtagger_labels/koond_1000_mitmetahenduslikud_labelled.json','r',encoding='UTF-8') as f:
    data = json.load(f)

# %%
recall_set_2 = []

for txt in data:
    if txt['annotations'][0]['result'][-1]['value']['choices'][0] == 'yes':
        #recall set contains of the raw sentence and the tagged span
        recall_set_2.append([txt['data']['text'],txt['annotations'][0]['result'][0]['value']])

# %%
collection[3505]
# Out:
# Text(text='Mulle ei meeldi mingid kallite restoranidega meelitajad , võin kodus ka kõhu täis süüa .')

# %%
len(recall_set_2)
# Out:
# 13

# %%
recall_set_2
# Out:
# ["Me teame , et juutidel on nii Euroopas kui ka Põhja-Ameerikas , isegi Vaikse ookeani ääres kõikides tähtsamates linnades n-ö prestiižsel kohal  holocaust  'i muuseumid .",
#  'Praegu on neil vastavalt 1994. aasta seadusele Liivi lahel kehtestatud ühine sisemeri .',
#  'Seaduse lisas on öeldud , et kuna Eesti Vabariigi ning Läti Vabariigi vahelistel läbirääkimistel ei ole territoriaalmere piir Irbe väinas ja Liivi lahes veel fikseeritud , siis võib Eesti Vabariigi territoriaalmere piir läbirääkimiste tulemusena teatud punktides muutuda .',
#  'Ees ootas Gobi kõrb .',
#  '“ Mäletan Erikat väärika ja rühika naisena , ” meenutab Eva Lille raamatu “ Soome lahe kahel kaldal ” saatesõnas .',
#  'India ookeani lääneosa jagatakse järgmiselt :',
#  'E lisas on näidatud India ookeani lääneosa ( püügipiirkonna 51 ) piirid ja alarajoonid .',
#  'Vääna- Jõesuu mäest olen 55 välja kütnud .',
#  'Niagara joast New Yorgini',
#  'Vähemalt on keskfraktsiooni parandusettepanekus Jürgensoni-Hanseni eelnõule selline punkt : " Arengukava väljatöötamisel kaaluda võimalust lõpetada Kopli poolsaare sadamate tegevus ja kasutada vabanenud maa-alasid keskklassile sobivate korterelamute rajamiseks .',
#  'Eesti on jäänud Atlandi ookeani põhjaosast itta liikuvate madalrõhkkondade teele .',
#  'Kuus minutit hiljem oli Lakersis jätkava Bryanti kord rõõmustada vaikse ookeani aja järgi kell 2.03 öösel sündis California osariigi Orange County haiglas tema teine järeltulija Gianna maria-Onore , kahe ajavööndi vahe on kolm tundi .',
#  'Järgmiseks laupäevaks peab Paralepa rand olema hooajaks valmis , Aafrika ja Vasikaholmi rand tahetakse korda saada mai lõpuks .',
#  'Olen mõelnud , et kui meil poleks Maalehte , võrduks olukord Varnja sooga , kust laialdane põleng tänavu kõik elava hävitas .',
#  'Iraagi vägede oodatust tugevam vastupanu sunnib Ameerika Ühendriike saatma Pärsia lahe piirkonda uusi väeüksusi .',
#  'Päästeamet sai laupäeval kell 6.08 teate , et Harjumaal Kõue vallas Ardu külas kukkus Paunküla veehoidlasse 37aastane mees .',
#  'Turu saarestikus kavandatakse Parainese ja Nauvo vahelise püsiühenduse rajamist .',
#  'Tallinn EK ralli õnnetusepaigas Pirita kiiruskatsel Lükati silla juures jälgis publik kiiruskatset kohas , kuhu jõudes autod olid just Ambrose mäelt laskunud , Lükati sillal pidurdanud ja siis liivase asfaldiga kaetud järsku kurvi sisenenud .',
#  'Lääne Elu leidis eile Paralepa rannast ühe päevitaja , kes oli nõus põlvini vette minema , et veetemperatuuri mõõta .',
#  'Kümneid turiste viidi haiglasse ja vähemalt üks hukkus Kreekas Chalkidiki poolsaare kuurortide ümbruses möllavas hiigelmetsapõlengus .',
#  '- 8. detsembril 1984 alla kirjutatud uus kokkulepe ühenduse ning Aafrika , Kariibi mere ja Vaikse ookeani piirkonna riikide vahel .',
#  'Ühendused Pürenee poolsaarega :',
#  'Kujutame ette , et näiteks Mustamäe katlamajal lõpeb raske kütteõli , kuid varu asub Soome lahe taga .',
#  'Võin isiklikest kogemustest kinnitada : 29. juulil käisin päikesepaistel mööda Nigula raba laudteed .',
#  '« Kodus on Tehvandi mägi ikka lumeta , » teab Aluvee .',
#  'Veidi üle 50 meetri pikkune Leedu kaubalaev uppus keset Tallinna lahte 6 . juuni pärastlõunal .',
#  'Ringid : Tooma Männikjärve raba Tooma , Tooma Männikjärve raba Mustjõgi Männikjärv Tooma , Tooma Kaasikjärve raba Endla järv Männikjärve raba Tooma , Kärde Endla järv Männikjärve raba Tooma .',
#  'Island on 103 000 km² suurune saar Atlandi ookeani põhjaosas .',
#  '5. juunil võrkpalliturniir « Suvehani » Paralepa rannas',
#  'ÕÕM ON OLLA BRASIILLANE : Noorsugu Rio de Janeiros Ipanema rannas .',
#  'Eestis oli tänavu kõige soojem merevesi - 25 kraadi -juuli algul ja juuli lõpus Saaremaal Järve rannas , Pärnu rannas ja Paralepas .',
#  'Viieaastase uurimisprojekti tulemusena selgus , et Liivi laht on täiesti normaalse puhtusastmega Läänemere piirkond , tõdeti Jurmalas toimunud Liivi lahe projekti lõpusümpoosionil .',
#  '" See sai alguse vist sellest , et Sulev kutsus mind Paukjärve rabasse .',
#  'Troparjovo tiik on üks 11 veekogust , kus Moskva piires sanitaarnormide kohaselt ujuda võib .',
#  '" Paigutame sulelised piirivalvurid oma piirile Saskatchewanist Atlandi ookeanini , " ütles Harvey Artsob Kanada Laboratoorsest Haiguskontrolli Keskusest Ottawas .',
#  'Augustis Jägala joal toimuva ilutulestikupeo " Suur pauk " peakorraldaja , Pürotehnikute Liidu esimees Eduard Tani käis Hiinas võistluste tarvis atraktiivset tehnikat valimas , uurimas , kuidas valmistatakse pürotehnikat ja kuidas rakettide õhku laskmine õieti käib .',
#  'Lisaks rahvusvahelisele ilutulestikuvõistlusele võib Paralepa randa sattuda ka üks maailmakuulus artist , kellega läbirääkimised on korraldaja sõnul jõudnud lõppfaasi .',
#  'Vette on asju ennegi ehitatud - lava Tamula järve ning Kadrioru tiigile , kuid sild on meelelahutusürituste ajaloos esmakordne .',
#  'Nende aastate jooksul , kui vald võttis koos Endla looduskaitseala juhtkonnaga Norra-Oostriku allikate piirkonda puhkekohti rajada , pole varem midagi lõhutud ega ära viidud , lausus Kuriks .',
#  'Branson , 49 , kes ületas Atlandi ookeani 1987 . aastal esimesena õhupalliga , ei pea prantslaste rekordi löömist kuigi kergeks .',
#  '" Kui vajutan nupule , jääb skuuter seisma , " märkis ainsana Pärnu rannas skuutriteenuseid pakkuva firma projektijuht .',
#  'See Eesti malekuulsusele kuuluv pooleliolev " loss " Vaigu rannas pidi keskkonnaamtnike sõnul algselt tulema väike tagasihoidlik suvemajake .',
#  'Leningradi oblasti valitsuse komitee esimees Grigori Dvas väitis Tallinnas transiidiseminari ajal peetud pressikonverentsil , et majanduslikust seisukohast on Venemaa soov rajada Soome lahe äärde oma sadamad igati arusaadav .',
#  'Tumedatriibulises kampsunis , vuntsidega keskeas mees jätkab sigaretti tõmmates õhulosside ehitamist , joonistab Saaremaa pikima poolsaare , Sõrve sääre rannikule lennuvälja , kümneid meelelahutuskohti , raudtee ning uue sadama .',
#  'Kolmapäeval kell 21.15 Riia mäe ärihoovist väljunud Nissan Sunny sõitis külge jalgratturile .',
#  'Tema võetud videolindil on näha Jolo saare Talipao mägedes bambusonni põrandal kobaras koos istuvaid õnnetute nägudega kurnatud turiste , kes rääkisid katkeva häälega oma olukorrast .',
#  'Neemest läbi sõites peatub jaht aprillis Tshiili sadamalinnas Valparaisos ning võtab seejärel kursi Vaikse ookeani saartele .',
#  'x FI-Riia ring-Nooruse-Ravila-Kannikese-LKV-Näituse-Tervishoiu-Maarjamõisa-Kaare-Kastani-Riia mägi-Kesklinn-Pärmivabrik-Kanali-Emajõe-Kalda tee-Kaunase pst-Mõisavahe-Nõlvaku .',
#  'AS Pirita Rannahoone on kavandanud 20. juuniks piduliku rannasuve avamise , 21. juunil on lastesuve avamine , 22. juunil on rannamängude päev , 23. juunil on Pirita rannas jaanilaupäev , ning 24. juunil sümboolne tervise taastamise päev .',
#  'Eesti Põllumajandusülikooli peahoone on juba üle poole aasta mitte Riia mäel , vaid Tallinna maantee kõrval linna ääres .',
#  'Pärnu rannas',
#  '“ Otse vastupidi , ” sõnas Schrempp , “ me loome uusi töökohti mõlemale poole Atlandi ookeani , et veelgi kasvada . ”',
#  'Inglismaalt levis moodne vabamüürlus Prantsusmaale ( 1725 ) ja teistesse Euroopa riikidesse ning leidis kiiresti tee Ameerika mandrile .',
#  'Kas ei vääriks see järgimist ka siinpool Soome lahte , et hoida rahvuslikku kultuuripärandit ikka elava ja tuntuna ?',
#  'Kella kolmeks on Kõu jõudnud Sõrve poolsaare tipu lähedale Mõntu sadama kohale ning jääb seal tormivarju ankrusse .',
#  'Käo-Kingsepa ojal käib aga maaparandus , kopp suundub otsustavalt kopratammi poole .',
#  'Parimateks jõhvika kasvukohtadeks loetakse Emajõe suursood , Laeva ja Muraka raba ning Agusalu sood .',
#  'Pikki tunde ei olnud meil kindlaid tõendeid , et Pärnu lahes pole jääpangal enam ühtegi inimest .',
#  'Idee korraldada suvepäev Pakri poolsaarel kuulub SALi presidendile Ivi-Els Schneiderile , kes ise Klooga kandi elanikuna on jõudnud Pakri poolsaare risti ja põiki läbi uurida .',
#  '8. mail otsustas Tallinna linnavolikogu opositsiooni vastuseisule vaatamata , et Tallinnas Kopli neeme tipus asuva Bekkeri sadama kaudu tohib vedada ka naftasaadusi .',
#  'Viimane neist kasvab ainult Iisraelis , Jordaanias ja Egiptuses Siinai kõrbes .',
#  'Kurkse väinas oli tormiolukord , kui Eesti rahuvalvajad neljapäeva lõuna ajal Suur-Pakrilt Kurkse sadama suunas teele asusid .',
#  'Kurkse väina ületanud rahuvalvaja Lauri Puss oli eile õhtul kadunute hulgas .',
#  'Nüüdseks on järg jõudnud Aafrika ja Aasia mandri kätte , samuti ollakse valmis vastu võtma endistest sotsialismimaadest pärit sportlasi .',
#  'Tallinna linn maksab ESS Tallinnale Pirita ranna valvamise eest tänavu 287 000 krooni .',
#  'Tallinna lahe meresõiduteedelt leiti 51 meremiini .',
#  '“ Sõduri kutse tõi Kuramaa randa , häälitsev mälestus Eestisse jäi ..  .',
#  'Stroomi rand oli kunagi tallinlaste armastatuimaid ajaviitepaiku .',
#  'Pikemas perspektiivis võib meeleheiteriik Põhja-Korea saada partneriks mõnele teisele riigile , mis soovib pingestada olukorda Vaikse ookeani piirkonnas .',
#  'Viljalaadungiga kaubalaev oli teel Riiast Peterburi ja sattus õnnetusse Vaindloo saarest kümme miili kagus ning Letipea neemest kümme miili põhjas .',
#  'Ametlikult väljendudes - strateegilisel võtmepositsioonil Araabia poolsaare kaguosas , omades seeläbi kontrolli Omaani lahte ning Araabia merd läbivate tähtsate kaubateede üle .',
#  'Sõjaväebaaside lähedal asuvatel õnnepaleedel on kibedad tööpäevad , sest sõdurid tahavad veel enne Pärsia lahe poole teele asumist oma pruudid altari ette viia .',
#  'Ma ei hakanud seal trassil kõnelema Arrase nõust , sellest , et Arras üsna pea tahab Ukuaru oja kallale ekskavaatorid tuua .',
#  'Stroomi rand , mis oli Kopli lahe idaosa saastatuse tõttu üle kahekümne aasta suletud , taasavati suplejatele tänavu 10. juulil .',
#  'Kriitika Ühendriikide kohtusüsteemi pihta oli kohe neutraliseeritud järgmise lõiguga , kus Pärsia lahe teema oli lahendatud tüüpilises sõja ( väe ) propaganda stiilis .',
#  '" Mis oleks , kui täidaks selle muna maasikate ja šokolaadi ning pähklitega , " ütles Varblane just sellise poeedi kombel , kes Saharas janusse surres riimib värsse Atlandi ookeanist .',
#  'Saabumine Rio de Janeirosse oli kui kevadiselt Soomaalt juulikuisesse Pärnu randa sattumine .',
#  'Aga Eloan ei läinud hoopiski Korgorathi mägedesse Getmanne tippu .',
#  'Jah , jaapanlased plaanisid luua hullumeelset riiki , mis ulatuks Vaiksest ookeanist Atlandi ookeanini .',
#  'Ürümchit piiravad kolmest küljest , idast , läänest ja lõunast , Tian Shani mäestiku mitmed ahelikud , põhjast aga Junggari ( Džungaaria ) nõgu , mida omakorda ümbritsevad Alatau ja Altai mäestik .',
#  'Sven Hedinile heidab varju asjaolu , et temast jäid Taklimakani kõrbesse piinlema uiguurid ja kirgiisid , keda ta oli palganud teejuhtideks ja kaameliajajateks ning keda ta valgest eurooplasest tahtejõu ja eneseteostuseiha poolest nõrgemaks pidas .',
#  'Ka linnaosa vanad kohanimed , nagu näiteks Haljasorg või Angerja oja pakuvad huvitavaid niidiotsi uurimiseks .',
#  'Linnuklubi soovitab Paljassaare poolsaare tippu rajada linnuhoiuala .',
#  'Nuba mägedes tegutsevate lõuna-mässuliste ühe rühmitusega õnnestuski valitsusel hiljuti pikendada vaherahu kuni käesoleva aasta keskpaigani ning veebruari alguses jõuti nendega kokkuleppele ka rahukõneluste lõpetamise tingimustes .',
#  'Ta on teeninud Jaapanis paiknevate USA relvajõudude ülemana , Vaikse ookeani õhujõudude ülemana Havail .',
#  "Perthi Fremantle'i sadamast lähtunud laev Cormo Express , mille 11 tekil lambad olid , jõu-dis pärast Jiddah' sadama keeldumist seigelda ligi kaks kuud Araabia poolsaare rannikutel , tehes vahepeatuse Kuveidis ja jõudes tagasi Punasesse merre , kus lambad Eritreas maha laaditi .",
#  'TALLINN , 23. mai ( EPLO ) - Reedel päästsid piirivalvurid Tallinna lahel ujunud kingi ja kodukitlit kandnud alajahtunud naisterahva .',
#  'Viimase kohaselt jõudsid Vaikse ookeani lõunapoolsetele saartele esimestena Aasia meresõitjad , sest indiaanlased polevat olnud suutelised primitiivsete paatidega läbima nii pikki vahemaid .',
#  'Vanglaametnikud ütlesid , et Williams sai San Quentini vanglas mürgisüsti ning ta suri umbes kell 12.35 USA Vaikse ookeani aja järgi ehk kell 10.35 Eesti aja järgi .',
#  'Arafati mäelt liikusid palve-rändurid Muzdalifasse , kust nad peaks täna siirduma edasi Minasse , et loopida kividega sambaid , mille saatan olevat püstitanud Ibrahimi ( piibli Aabra- ham ) peibutamiseks .',
#  'Kesklinna haljastajad korjavad iga päev Snelli tiigist kärutäite kaupa rämpsu , mida inimesed on vette loopinud .',
#  'Pealegi iga tööstusrajatis Tallinna rannal on märksa kenam ja otstarbekam kui riburada Pirita tee äärde või Rocca al Maresse kerkinud kortermajade näotud betoontahukad .',
#  'Süvasadama ehitus lükkus edasi pärast Pärnu halduskohtu hiljutist otsust tühistada Lümanda valla üldplaneering , mis lubas süvasadama rajada Küdema lahe kaldale Tamme väikesadama asemele .',
#  'Lõuna-Aafrika Kalahari kõrbes kasvav kaktus võib osutuda abivahendiks rasvumise vastu .',
#  'Eelmisel nädalal käisid Vaikse ookeani saareriigi Tonga kodanikud uut parlamenti valimas .',
#  'Zawahiri ütles samuti , et Bin Laden ja teised Al-Qaeda juhid ei peitunud Tora Bora koobastesse , vaid võitlesid eesliinil .',
#  'Hirmsaid uudiseid jõuab meieni viimasel ajal suurelt Atlandi ookeanilt .',
#  'Tegelikult kavatseb Asta haruldased sarvedega lambad Kihnu väina merepargile müüa ja tulevikus hakkavad nad Läänemaa rannikuala roost puhtaks sööma .',
#  'Nii 1996. aastal kui ka tänavu lendasid loendajad lennukil läbi sama territooriumi , Riia lahe .',
#  'Ka Väinamerel , Liivi lahel põhjaosas ning Soome lahe ida- ja lääneosas ulatus laine kõrgus 3-7 meetrini .',
#  'Nädala eest seiklesid kaks meest Muuga lahel isetehtud alusega ning sattusid merehätta .',
#  'Nende kodukohad moodustasid hõreda aheliku Ruhnust Riia lahes kuni Tallinnani , mõninga koondumisega Noarootsi ja Vormsi kihelkonda Eesti looderannikul .',
#  'Miri rusud peaksid kell 9.30 Moskva aja järgi kukkuma Vaiksesse ookeani Austraalia ja Lõuna-Ameerika vahelisele alale , mille keskpunkti kooridnaatideks on 44,2 kraadi lõunalaiust ja 150,4 kraadi läänepikkust .',
#  'Tallinnas Kakumäe poolsaare metsas mootorsaagidega ringi liikuvad töömehed langetavad pea tuhat leht- ja okaspuud , et teha ruumi 2000-3000 ruutmeetri suurustele kruntidele , kirjutab Postimees .',
#  'Et Ülemiste järv ei võta enam kanalite kaudu vett vastu , on see kõrgeks paisutanud nii Soodla kui ka Paunküla veehoidlate vesikonna jõed .',
#  '13 Pirital , Stroomi rannas ja Kunda lahes .',
#  'Atlantise stardi ajal asus orbitaaljaam koos kolmeliikmelise meeskonnaga rohkem kui 355 kilomeetri kõrgusel Atlandi ookeani põhjaosa kohal , Newfoundlandist ida pool .',
#  'Täna viibib USA kaitseminister Võidu pargis Poklonnaja mäe jalamil toimuval tseremoonial ja tutvub Moskva linna vaatamisväärsustega .',
#  'Kohila lähistel Rabivere raba serval näitas poiss kätte eelmisel päeval kadunud Nordeni torke ja lõikehaavadega surnukeha .',
#  'Sillamäe jäätmehoidla , mis on aastakümneid ähvardanud Soome lahte , tekkis nõukogude ajal , mil Silmetis toodeti uraani .',
#  'Päästeameti juhtimiskeskuse korrapidaja sõnul oleks täna Järva-Jaani tehisjärve peaaegu uppunud nelja-aastane tüdruk .',
#  'Nadežda saab presidendi käsundusohvitserilt tunnistuse , mille kohaselt president annab talle kolme läbi Kadrioru tiigi jää vajunud poisi päästmise eest Eesti Punase Risti neljanda klassi teenetemärgi .',
#  'Tallinna lahel puhub tuul üle 20 meetri sekundis , laine kõrgus on üle nelja meetri .',
#  'Lääne-Virumaa talumees Toivo väidab , et tema maadel asuva Põlula allika vesi on parem kui maailmakuulus Evian .',
#  'Stroomi rand saab rannahoone',
#  'Viitega Lääne ja Vene allikatele teatas päevaleht , et salajane projekt näeb ette tohutu sõjalise kompleksi rajamist Jamantau mäe alla Beloretski rajoonis Uuralides .',
#  'Linnavalitsuse lubadus avada eeloleval suvel Paljassaare poolsaarel Katariina kai juures avalik supelrand on tegelikult alles idee tasemel .',
#  'Üldplaneeringus sisaldub ka sadamaalade tsoneering , mille järgi on ette nähtud kaubasadamate koondamine Kopli ja Paljassaare poolsaarele .',
#  'Musumuäel süttis 108 , Tornide Väljakul 68 ja Schnelli tiigi pargis 42 uut pargivalgustit .',
#  '19 kraadi on soe Stroomi , Võsu , Kunda ja Vasknarva randade vesi .',
#  'Eesmärgi saavutamiseks on kohalikud turismiettevõtjad investeerinud uue golfikeskuse ehitamisse , vald korrastab Pühajärve randa ja suurenev turistide hulk innustab ettevõtjaid rajama ka uusi hotellikohti .',
#  'Kui olete tuletorni kürgetest trepiastmetest üles turninud , siis paistab ära ka Ristna neem .',
#  'Novembri lõpus kavatsevad 60 eestlast ühel ajal jõuda ligi 6000-meetrise Kilimanjaro mäe tippu Aafrikas .',
#  'Ruhnus viib kohaliku külapoe omanik Vitali meid kohe Limo randa karu jälgi vaatama .',
#  'Maastikuring , mille pikkus on 12,1 kilomeetrit ja mis kulgeb Rakke Linnamäel ning Edru mägedes , nõuab sõitjalt head treenitust ja oskust ratast valitseda , kuid rada on siiski oluliselt kergem kui maratonidel .',
#  'Eile varahommikul Paide tehisjärve äärde kalale läinud Krassil ei olnud alguses püügiõnne .',
#  'Kakumäe randa plaanitakse järgmiseks suveks rannahoonet , palliplatse ja vabaõhulava .',
#  '1682 - Prantsuse maadeuurija La Salle jõudis mööda Mississippi jõge Mehhiko laheni .',
#  'Äkki peaksime kala adopteerima ja India ookeanist Soome lahte ümber kolima ?',
#  'Kaks aastat pärast seda alustas Hawaiil tööd USA Vaikse ookeani hoiatuskeskus .',
#  'Hommikujooksu tegijaid võttis kuulsal Bondi rannal vastu põlevate eukalüptide kirbe lõhn .',
#  'Vaadata ja pildistada on aga võimalik 100-kilomeetrise läbimõõduga Popikai kraatrit , mis asub Leena suudmes Taimõri poolsaare taga .',
#  'Kuid niisugune uus keskendumine Pärsia lahe piirkonnale on siiski laiema tähtsusega : hoolimata kõigist suurtest probleemidest Venemaa , NATO laienemise ja Hiinaga , asuvad kõige suuremad koheste poliitiliste ja diplomaatiliste raskuste piirkonnad Pärsia lahe ja Vahemere regioonis , Kesk-Aasias , Balkanil , Aafrikas - ehk " Lõunas " , nagu prantslased ütlevad .',
#  'Sel kevadel kalasõja alana tuntuks saanud Liivi lahe osa on Saaremaa piirkonna piirivalvurite valvata .',
#  'Lihulas avati eile reoveepuhasti , mis on Haapsalu-Matsalu lahe keskkonnaprojekti esimene osa .',
#  'Leisi vallas on Pihla laid erakätes , aga Kihelkonna vallas , Vilsandi rahvuspargi ümber olevad väikelaiud kuuluvad riigile .',
#  'Igas eas loodushuvilisi peaksid köitma ka lood Põhja-Ameerika piisoni ellujäämise saladusest , samuti Põhjaranniku äärses Soome lahes talvituvatest lindudest , virmalistest ja kaugetest reisidest .',
#  'Põhja-Tallinnas on tähtsaimaks Stroomi ranna väljaehitamine ja korrastamine - Stroomi rannast peab saama üle Eesti tunnustatud puhkekoht , ütles Järve .',
#  'Inimohvritega suuri õnnetusi juhtus sealseis vetes eelmisel sajandil kolm : peale Estonia uppus saare külje all 1947. aasta jõulu-õhtul Ameerika kaubalaev Park Victory kümne madrusega par-dal ning 1929. aastal jäid veelgi lähemal , 300 meetrit Utö rannast merre kolmemastilisel purjekal Drake olnud kuus madrust .',
#  'Ainsana pealinna randadest on puhas ja ujumiskõlblik vesi Kakumäe rannas .',
#  'Paldiski piirivalvurid märkasid eile kell 3.53 radarit jälgides , et juba kümne minuti jagu seisab Suur-Pakri saare põhjatipust kolme miili kaugusel läänes Krassi madalikul tundmatu laev , mis ei vasta kutsungile .',
#  'Harju mäe aluste tunnelite korrastamine ja turismiobjektina avamine on kirjas ka linnavõimu koalitsioonileppes .',
#  'Musumäele ( Viruvärava mägi ) valati skulptuuride tarbeks eelmisel nädalal kaks alust , 1,5 -2 meetri kõrguste kujude paigaldamine peaks esialgsete kavade kohaselt algama täna .',
#  '" Harku ja Pääsküla raba kaitseala moodustamine on oluline etapp Tallinna rahvuspargi rajamisel , " ütles Ratas .',
#  'Tänavu paisatakse Salmistu-Valkla rannas meredessandiga rannale 31 neljaliikmelist võistkonda , nende seas 14 välisvõistkonda 11 riigist .',
#  'Teine pomm plahvatas pisut hiljem Bosporuse väina kaldal Ceylan Intercontinental hotelli juures .',
#  'Venemaa president Vladimir Putin peatas laupäeval ametlikult Venemaa osaluse tähtsas Külma sõja järgses tavarelvastusleppes , mille eesmärgiks oli piirata raskerelvade arvu Atlandi ookeani ja Uuralite vahelisel alal , põhjendades seda erakorraliste turvalisust puudutavate asjaoludega .',
#  'Viimsi vald muutis eelmise aasta jaanipäeva paiku kaheksa päevaga kurikuulsa nn Antenniväljaku detailplaneeringut , mille tõttu saab Viimsi poolsaare keskel asuvale krundile ehitada 80 elamuühiku asemel 320 elamuühikut .',
#  'USA kaitseministeerium kavatseb vabastada mõned terrorismis kahtlustatavad vangid , keda hoitakse Kuubal Guantanamo lahe laagris , kuna nad ei ole enam ohtlikud ning neil pole pakkuda ka enamat luureinfot .',
#  'Kopamehe sõnul moodustavad Triigi poolsaarel kasvavad puu ja põõsaliigid kolmandiku kogu Eesti puudest ja põõsastest .',
#  "Piirivalvurid , Nordic Jet Line'i katamaraani meeskond ja veeteede ameti töötajad harjutavad kolmapäeval Tallinna lahel päästetegevust .",
#  'Iisrael tõi väed Egiptusele kuuluvalt Siinai poolsaarelt välja ja riigid sõlmisid diplomaatilised suhted .',
#  'Kuigi eeliseks oli see , et naftatankerid ei koorma Bosporuse väina , näitasid arvestused , et Iraani või Venemaa kaudu on toru ehitada palju odavam .',
#  'Vene Kaug-Idas Vitjazhi lahes paiknenud mereväebaasis õpetati kashelotte vaenlase sukeldujaid otsima , laevu ründama , pommid keha külge kinnitatud , ja teisi lahinguülesandeid täitma .',
#  '" Atlandi ookean on siiski avatud ookean ja seal on tankeriõnnetuse tagajärjed tunduvalt väiksemad kui Läänemerel , kus sellest tuleks ökokatastroof . "',
#  'Tenson peab Pärnu lahe vee suuremaks puuduseks seda , et bakteriaalsed näitajad pole ühtlased ja veeproov võib nädalaga oluliselt muutuda .',
#  'Tartu linnavalitsus soovib viie miljoni kroonise alghinnaga maha müüa südalinnas Lille mäel asuva mitu aastat ilmastikuoludele räsida olnud poolelioleva haldushoone .',
#  'Lisaks staabis ringivaatamisele sõidab seltskond miinitraaleril Sulev Tallinna lahel ringi .',
#  'Õhupall sõidab ligikaudu sajakilomeetrise tunnikiirusega enam kui 9000 meetri kõrgusel kirde suunas ja peaks senist kurssi jätkates ületama Põhja-Hiina ranniku , Korea poolsaare ja Jaapani .',
#  'Läbi Iraani kulgevad uimastite salakaubaveo trassid Afganistanist ja Pakistanist Pärsia lahele , Euroopasse ja Kesk-Aasiasse ning seal toimub sageli kokkupõrkeid uimastikaupmeeste ja julgeoleku vahel .',
#  'Tallinna Pirita rannas avatakse esmaspäeval rannahooaeg , ülejäänud kolm Tallinna avalikku randa - Kakumäe , Harku ja Stroomi rand avatakse ametlikult 3. juunil .',
#  'USA ja Ladina-Ameerika suurte banaanitootjariikide nn. banaanisõda Euroopa Liidu vastu kestab juba mitu aastat , sest Euroopa Liit on andnud eelisseisundi banaanikaubanduses endistele Kariibi mere , Vaikse ookeani ja Aafrika kolooniatele .',
#  'Lähima 50 aasta jooksul kolmekordistub ka Aasiast ja Vaikse ookeani saartelt pärit ameeriklaste arv , ulatudes 38 miljoni ehk üheksa protsendini .',
#  'Keskkonnainspektsiooni Pärnu osakonna vaneminspektori Aavo Sempelsoni andmeil on Pärnu lahelt tabatud ka suurema kalakogusega röövpüüdjaid , kuid keskkonnale tekitatud kahju eest nõutav hüvitis kujunes rekordiliseks seetõttu , et keelualal püüdmise eest on seadusega ette nähtud tavalisest kolm korda suurem summa .',
#  'Tallinna Kesklinna tuletõrjekomando sai Kadrioru tiigi juurde väljakutse kell 14.16.',
#  'Sihtpunktini , Salmistu rannani , on jäänud veel palju kilomeetreid .',
#  'Piirivalveameti pressiesindaja Urmo Kohv ütles ETAle , et laev jõudis kell 14.45 Kolka poolsaare juures madalikule .',
#  'Austraalia huvi sõnastas aga üks saareametnik : " Omada keset India ookeani sellist lennukikandjat - selle eest võib ju igal aastal mõnedkümned miljonid maksta .',
#  'Siis jõuavad kätte Brasiilia ja Kariibi mere saared , läbi Panama kanali sõidetakse Vaiksele ookeanile , kus on palju peatuskohti .',
#  'Viiendaks : vaadata Copacabana või Ipanema rannal tüdrukuid .',
#  'Samas tõdes Ojava , et reostus paistis olevat Tallinna lahel ja selle ümbruses triivinud juba mitu päeva , mistõttu on selle tekitajat väga raske tabada .',
#  'Vaikse ookeani äärsete riikide juhid otsustasid Ühendriikide presidendi Bill Clintoni survel nõuda uut ülemaailmset vabakaubanduskõneluste vooru järgmisel aastal .',
#  'Vaikse ookeani äärest Kaukaasiani ja kaugemale on Moskva uus juhtkond võtmas kasutusele aina agressiivsemat välispoliitikat , mis on rajatud pigem vastasseisule Läänega kui partnerlusele .',
#  'Bernard Buigues plaanib seda eksponeerida Hatanga koobastes , kuhu lisaks mammutile hakatakse tooma teisi väljasurnud loomade jäänuseid .',
#  'Maailma esimese triivjaama rajajaid ; tema nime kannab Banksi maal ( saar Kanada Arktika saarestiku lääneosas ) voolav jõgi ( Masik River ) .',
#  'Keskaegkonna lõpul kriidi ajastul alanud ning uusaegkonnas jätkunud Alpi kurrutus on loonud Alpid , Apenniinid , Karpaadid , Krimmi ja Kaukaasia mäed , Atlase mäed ja enamiku Väike-Aasiast kuni Malaka poolsaareni kulgevatest mäestikest .',
#  'Ometi ei osanud daam , kes tööalaselt linna juhtidega pidevalt lävib ( Kink on Eesti juhtiva hüdrogeoloogina aastaid jälginud Pakri poolsaare vete puhtust ) , kuidagi arvata , et tema huvidest nii mööda vaadatakse .']

# %%
import json

with open('labelled_data/substringtagger_labels/koond_1000_ulejaanud.json','r',encoding='UTF-8') as f:
    data = json.load(f)

# %%
recall_set_3 = []

for txt in data:
    if txt['annotations'][0]['result'][-1]['value']['choices'][0] == 'yes':
        #recall set contains of the raw sentence and the tagged span
        recall_set_3.append([txt['data']['text'],txt['annotations'][0]['result'][0]['value']])

# %%
len(recall_set_3)
# Out:
# 177

# %%
recall_set_3
# Out:
# [["Me teame , et juutidel on nii Euroopas kui ka Põhja-Ameerikas , isegi Vaikse ookeani ääres kõikides tähtsamates linnades n-ö prestiižsel kohal  holocaust  'i muuseumid .",
#   {'start': 77, 'end': 84, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Praegu on neil vastavalt 1994. aasta seadusele Liivi lahel kehtestatud ühine sisemeri .',
#   {'start': 53, 'end': 58, 'text': 'lahel', 'labels': ['v172_geo_terms']}],
#  ['Seaduse lisas on öeldud , et kuna Eesti Vabariigi ning Läti Vabariigi vahelistel läbirääkimistel ei ole territoriaalmere piir Irbe väinas ja Liivi lahes veel fikseeritud , siis võib Eesti Vabariigi territoriaalmere piir läbirääkimiste tulemusena teatud punktides muutuda .',
#   {'start': 131, 'end': 137, 'text': 'väinas', 'labels': ['v172_geo_terms']}],
#  ['Ees ootas Gobi kõrb .',
#   {'start': 15, 'end': 19, 'text': 'kõrb', 'labels': ['v172_geo_terms']}],
#  ['“ Mäletan Erikat väärika ja rühika naisena , ” meenutab Eva Lille raamatu “ Soome lahe kahel kaldal ” saatesõnas .',
#   {'start': 82, 'end': 86, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['India ookeani lääneosa jagatakse järgmiselt :',
#   {'start': 6, 'end': 13, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['E lisas on näidatud India ookeani lääneosa ( püügipiirkonna 51 ) piirid ja alarajoonid .',
#   {'start': 26, 'end': 33, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Vääna- Jõesuu mäest olen 55 välja kütnud .',
#   {'start': 14, 'end': 19, 'text': 'mäest', 'labels': ['v172_geo_terms']}],
#  ['Niagara joast New Yorgini',
#   {'start': 8, 'end': 13, 'text': 'joast', 'labels': ['v172_geo_terms']}],
#  ['Vähemalt on keskfraktsiooni parandusettepanekus Jürgensoni-Hanseni eelnõule selline punkt : " Arengukava väljatöötamisel kaaluda võimalust lõpetada Kopli poolsaare sadamate tegevus ja kasutada vabanenud maa-alasid keskklassile sobivate korterelamute rajamiseks .',
#   {'start': 154,
#    'end': 163,
#    'text': 'poolsaare',
#    'labels': ['v172_geo_terms']}],
#  ['Eesti on jäänud Atlandi ookeani põhjaosast itta liikuvate madalrõhkkondade teele .',
#   {'start': 24, 'end': 31, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Kuus minutit hiljem oli Lakersis jätkava Bryanti kord rõõmustada vaikse ookeani aja järgi kell 2.03 öösel sündis California osariigi Orange County haiglas tema teine järeltulija Gianna maria-Onore , kahe ajavööndi vahe on kolm tundi .',
#   {'start': 72, 'end': 79, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Järgmiseks laupäevaks peab Paralepa rand olema hooajaks valmis , Aafrika ja Vasikaholmi rand tahetakse korda saada mai lõpuks .',
#   {'start': 36, 'end': 40, 'text': 'rand', 'labels': ['v172_geo_terms']}],
#  ['Olen mõelnud , et kui meil poleks Maalehte , võrduks olukord Varnja sooga , kust laialdane põleng tänavu kõik elava hävitas .',
#   {'start': 68, 'end': 73, 'text': 'sooga', 'labels': ['v172_geo_terms']}],
#  ['Iraagi vägede oodatust tugevam vastupanu sunnib Ameerika Ühendriike saatma Pärsia lahe piirkonda uusi väeüksusi .',
#   {'start': 82, 'end': 86, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Päästeamet sai laupäeval kell 6.08 teate , et Harjumaal Kõue vallas Ardu külas kukkus Paunküla veehoidlasse 37aastane mees .',
#   {'start': 95,
#    'end': 107,
#    'text': 'veehoidlasse',
#    'labels': ['v172_geo_terms']}],
#  ['Turu saarestikus kavandatakse Parainese ja Nauvo vahelise püsiühenduse rajamist .',
#   {'start': 5,
#    'end': 16,
#    'text': 'saarestikus',
#    'labels': ['v172_geo_terms']}],
#  ['Tallinn EK ralli õnnetusepaigas Pirita kiiruskatsel Lükati silla juures jälgis publik kiiruskatset kohas , kuhu jõudes autod olid just Ambrose mäelt laskunud , Lükati sillal pidurdanud ja siis liivase asfaldiga kaetud järsku kurvi sisenenud .',
#   {'start': 143, 'end': 148, 'text': 'mäelt', 'labels': ['v172_geo_terms']}],
#  ['Lääne Elu leidis eile Paralepa rannast ühe päevitaja , kes oli nõus põlvini vette minema , et veetemperatuuri mõõta .',
#   {'start': 31, 'end': 38, 'text': 'rannast', 'labels': ['v172_geo_terms']}],
#  ['Kümneid turiste viidi haiglasse ja vähemalt üks hukkus Kreekas Chalkidiki poolsaare kuurortide ümbruses möllavas hiigelmetsapõlengus .',
#   {'start': 74, 'end': 83, 'text': 'poolsaare', 'labels': ['v172_geo_terms']}],
#  ['- 8. detsembril 1984 alla kirjutatud uus kokkulepe ühenduse ning Aafrika , Kariibi mere ja Vaikse ookeani piirkonna riikide vahel .',
#   {'start': 98, 'end': 105, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Ühendused Pürenee poolsaarega :',
#   {'start': 18,
#    'end': 29,
#    'text': 'poolsaarega',
#    'labels': ['v172_geo_terms']}],
#  ['Kujutame ette , et näiteks Mustamäe katlamajal lõpeb raske kütteõli , kuid varu asub Soome lahe taga .',
#   {'start': 91, 'end': 95, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Võin isiklikest kogemustest kinnitada : 29. juulil käisin päikesepaistel mööda Nigula raba laudteed .',
#   {'start': 86, 'end': 90, 'text': 'raba', 'labels': ['v172_geo_terms']}],
#  ['« Kodus on Tehvandi mägi ikka lumeta , » teab Aluvee .',
#   {'start': 20, 'end': 24, 'text': 'mägi', 'labels': ['v172_geo_terms']}],
#  ['Veidi üle 50 meetri pikkune Leedu kaubalaev uppus keset Tallinna lahte 6 . juuni pärastlõunal .',
#   {'start': 65, 'end': 70, 'text': 'lahte', 'labels': ['v172_geo_terms']}],
#  ['Ringid : Tooma Männikjärve raba Tooma , Tooma Männikjärve raba Mustjõgi Männikjärv Tooma , Tooma Kaasikjärve raba Endla järv Männikjärve raba Tooma , Kärde Endla järv Männikjärve raba Tooma .',
#   {'start': 179, 'end': 183, 'text': 'raba', 'labels': ['v172_geo_terms']}],
#  ['Island on 103 000 km² suurune saar Atlandi ookeani põhjaosas .',
#   {'start': 43, 'end': 50, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['5. juunil võrkpalliturniir « Suvehani » Paralepa rannas',
#   {'start': 49, 'end': 55, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['ÕÕM ON OLLA BRASIILLANE : Noorsugu Rio de Janeiros Ipanema rannas .',
#   {'start': 59, 'end': 65, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['Eestis oli tänavu kõige soojem merevesi - 25 kraadi -juuli algul ja juuli lõpus Saaremaal Järve rannas , Pärnu rannas ja Paralepas .',
#   {'start': 111, 'end': 117, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['Viieaastase uurimisprojekti tulemusena selgus , et Liivi laht on täiesti normaalse puhtusastmega Läänemere piirkond , tõdeti Jurmalas toimunud Liivi lahe projekti lõpusümpoosionil .',
#   {'start': 149, 'end': 153, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['" See sai alguse vist sellest , et Sulev kutsus mind Paukjärve rabasse .',
#   {'start': 63, 'end': 70, 'text': 'rabasse', 'labels': ['v172_geo_terms']}],
#  ['Troparjovo tiik on üks 11 veekogust , kus Moskva piires sanitaarnormide kohaselt ujuda võib .',
#   {'start': 11, 'end': 15, 'text': 'tiik', 'labels': ['v172_geo_terms']}],
#  ['" Paigutame sulelised piirivalvurid oma piirile Saskatchewanist Atlandi ookeanini , " ütles Harvey Artsob Kanada Laboratoorsest Haiguskontrolli Keskusest Ottawas .',
#   {'start': 72, 'end': 81, 'text': 'ookeanini', 'labels': ['v172_geo_terms']}],
#  ['Augustis Jägala joal toimuva ilutulestikupeo " Suur pauk " peakorraldaja , Pürotehnikute Liidu esimees Eduard Tani käis Hiinas võistluste tarvis atraktiivset tehnikat valimas , uurimas , kuidas valmistatakse pürotehnikat ja kuidas rakettide õhku laskmine õieti käib .',
#   {'start': 16, 'end': 20, 'text': 'joal', 'labels': ['v172_geo_terms']}],
#  ['Lisaks rahvusvahelisele ilutulestikuvõistlusele võib Paralepa randa sattuda ka üks maailmakuulus artist , kellega läbirääkimised on korraldaja sõnul jõudnud lõppfaasi .',
#   {'start': 62, 'end': 67, 'text': 'randa', 'labels': ['v172_geo_terms']}],
#  ['Vette on asju ennegi ehitatud - lava Tamula järve ning Kadrioru tiigile , kuid sild on meelelahutusürituste ajaloos esmakordne .',
#   {'start': 64, 'end': 71, 'text': 'tiigile', 'labels': ['v172_geo_terms']}],
#  ['Nende aastate jooksul , kui vald võttis koos Endla looduskaitseala juhtkonnaga Norra-Oostriku allikate piirkonda puhkekohti rajada , pole varem midagi lõhutud ega ära viidud , lausus Kuriks .',
#   {'start': 94, 'end': 102, 'text': 'allikate', 'labels': ['v172_geo_terms']}],
#  ['Branson , 49 , kes ületas Atlandi ookeani 1987 . aastal esimesena õhupalliga , ei pea prantslaste rekordi löömist kuigi kergeks .',
#   {'start': 34, 'end': 41, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['" Kui vajutan nupule , jääb skuuter seisma , " märkis ainsana Pärnu rannas skuutriteenuseid pakkuva firma projektijuht .',
#   {'start': 68, 'end': 74, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['See Eesti malekuulsusele kuuluv pooleliolev " loss " Vaigu rannas pidi keskkonnaamtnike sõnul algselt tulema väike tagasihoidlik suvemajake .',
#   {'start': 59, 'end': 65, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['Leningradi oblasti valitsuse komitee esimees Grigori Dvas väitis Tallinnas transiidiseminari ajal peetud pressikonverentsil , et majanduslikust seisukohast on Venemaa soov rajada Soome lahe äärde oma sadamad igati arusaadav .',
#   {'start': 185, 'end': 189, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Tumedatriibulises kampsunis , vuntsidega keskeas mees jätkab sigaretti tõmmates õhulosside ehitamist , joonistab Saaremaa pikima poolsaare , Sõrve sääre rannikule lennuvälja , kümneid meelelahutuskohti , raudtee ning uue sadama .',
#   {'start': 147, 'end': 152, 'text': 'sääre', 'labels': ['v172_geo_terms']}],
#  ['Kolmapäeval kell 21.15 Riia mäe ärihoovist väljunud Nissan Sunny sõitis külge jalgratturile .',
#   {'start': 28, 'end': 31, 'text': 'mäe', 'labels': ['v172_geo_terms']}],
#  ['Tema võetud videolindil on näha Jolo saare Talipao mägedes bambusonni põrandal kobaras koos istuvaid õnnetute nägudega kurnatud turiste , kes rääkisid katkeva häälega oma olukorrast .',
#   {'start': 51, 'end': 58, 'text': 'mägedes', 'labels': ['v172_geo_terms']}],
#  ['Neemest läbi sõites peatub jaht aprillis Tshiili sadamalinnas Valparaisos ning võtab seejärel kursi Vaikse ookeani saartele .',
#   {'start': 107, 'end': 114, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['x FI-Riia ring-Nooruse-Ravila-Kannikese-LKV-Näituse-Tervishoiu-Maarjamõisa-Kaare-Kastani-Riia mägi-Kesklinn-Pärmivabrik-Kanali-Emajõe-Kalda tee-Kaunase pst-Mõisavahe-Nõlvaku .',
#   {'start': 94, 'end': 98, 'text': 'mägi', 'labels': ['v172_geo_terms']}],
#  ['AS Pirita Rannahoone on kavandanud 20. juuniks piduliku rannasuve avamise , 21. juunil on lastesuve avamine , 22. juunil on rannamängude päev , 23. juunil on Pirita rannas jaanilaupäev , ning 24. juunil sümboolne tervise taastamise päev .',
#   {'start': 165, 'end': 171, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['Eesti Põllumajandusülikooli peahoone on juba üle poole aasta mitte Riia mäel , vaid Tallinna maantee kõrval linna ääres .',
#   {'start': 72, 'end': 76, 'text': 'mäel', 'labels': ['v172_geo_terms']}],
#  ['Pärnu rannas',
#   {'start': 6, 'end': 12, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['“ Otse vastupidi , ” sõnas Schrempp , “ me loome uusi töökohti mõlemale poole Atlandi ookeani , et veelgi kasvada . ”',
#   {'start': 86, 'end': 93, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Inglismaalt levis moodne vabamüürlus Prantsusmaale ( 1725 ) ja teistesse Euroopa riikidesse ning leidis kiiresti tee Ameerika mandrile .',
#   {'start': 126,
#    'end': 134,
#    'text': 'mandrile',
#    'labels': ['v172_geo_terms']}],
#  ['Kas ei vääriks see järgimist ka siinpool Soome lahte , et hoida rahvuslikku kultuuripärandit ikka elava ja tuntuna ?',
#   {'start': 47, 'end': 52, 'text': 'lahte', 'labels': ['v172_geo_terms']}],
#  ['Kella kolmeks on Kõu jõudnud Sõrve poolsaare tipu lähedale Mõntu sadama kohale ning jääb seal tormivarju ankrusse .',
#   {'start': 35, 'end': 44, 'text': 'poolsaare', 'labels': ['v172_geo_terms']}],
#  ['Käo-Kingsepa ojal käib aga maaparandus , kopp suundub otsustavalt kopratammi poole .',
#   {'start': 13, 'end': 17, 'text': 'ojal', 'labels': ['v172_geo_terms']}],
#  ['Parimateks jõhvika kasvukohtadeks loetakse Emajõe suursood , Laeva ja Muraka raba ning Agusalu sood .',
#   {'start': 77, 'end': 81, 'text': 'raba', 'labels': ['v172_geo_terms']}],
#  ['Pikki tunde ei olnud meil kindlaid tõendeid , et Pärnu lahes pole jääpangal enam ühtegi inimest .',
#   {'start': 55, 'end': 60, 'text': 'lahes', 'labels': ['v172_geo_terms']}],
#  ['Idee korraldada suvepäev Pakri poolsaarel kuulub SALi presidendile Ivi-Els Schneiderile , kes ise Klooga kandi elanikuna on jõudnud Pakri poolsaare risti ja põiki läbi uurida .',
#   {'start': 31,
#    'end': 41,
#    'text': 'poolsaarel',
#    'labels': ['v172_geo_terms']}],
#  ['8. mail otsustas Tallinna linnavolikogu opositsiooni vastuseisule vaatamata , et Tallinnas Kopli neeme tipus asuva Bekkeri sadama kaudu tohib vedada ka naftasaadusi .',
#   {'start': 97, 'end': 102, 'text': 'neeme', 'labels': ['v172_geo_terms']}],
#  ['Viimane neist kasvab ainult Iisraelis , Jordaanias ja Egiptuses Siinai kõrbes .',
#   {'start': 71, 'end': 77, 'text': 'kõrbes', 'labels': ['v172_geo_terms']}],
#  ['Kurkse väinas oli tormiolukord , kui Eesti rahuvalvajad neljapäeva lõuna ajal Suur-Pakrilt Kurkse sadama suunas teele asusid .',
#   {'start': 7, 'end': 13, 'text': 'väinas', 'labels': ['v172_geo_terms']}],
#  ['Kurkse väina ületanud rahuvalvaja Lauri Puss oli eile õhtul kadunute hulgas .',
#   {'start': 7, 'end': 12, 'text': 'väina', 'labels': ['v172_geo_terms']}],
#  ['Nüüdseks on järg jõudnud Aafrika ja Aasia mandri kätte , samuti ollakse valmis vastu võtma endistest sotsialismimaadest pärit sportlasi .',
#   {'start': 42, 'end': 48, 'text': 'mandri', 'labels': ['v172_geo_terms']}],
#  ['Tallinna linn maksab ESS Tallinnale Pirita ranna valvamise eest tänavu 287 000 krooni .',
#   {'start': 43, 'end': 48, 'text': 'ranna', 'labels': ['v172_geo_terms']}],
#  ['Tallinna lahe meresõiduteedelt leiti 51 meremiini .',
#   {'start': 9, 'end': 13, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['“ Sõduri kutse tõi Kuramaa randa , häälitsev mälestus Eestisse jäi ..  .',
#   {'start': 27, 'end': 32, 'text': 'randa', 'labels': ['v172_geo_terms']}],
#  ['Stroomi rand oli kunagi tallinlaste armastatuimaid ajaviitepaiku .',
#   {'start': 8, 'end': 12, 'text': 'rand', 'labels': ['v172_geo_terms']}],
#  ['Pikemas perspektiivis võib meeleheiteriik Põhja-Korea saada partneriks mõnele teisele riigile , mis soovib pingestada olukorda Vaikse ookeani piirkonnas .',
#   {'start': 134, 'end': 141, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Viljalaadungiga kaubalaev oli teel Riiast Peterburi ja sattus õnnetusse Vaindloo saarest kümme miili kagus ning Letipea neemest kümme miili põhjas .',
#   {'start': 120, 'end': 127, 'text': 'neemest', 'labels': ['v172_geo_terms']}],
#  ['Ametlikult väljendudes - strateegilisel võtmepositsioonil Araabia poolsaare kaguosas , omades seeläbi kontrolli Omaani lahte ning Araabia merd läbivate tähtsate kaubateede üle .',
#   {'start': 66, 'end': 75, 'text': 'poolsaare', 'labels': ['v172_geo_terms']}],
#  ['Sõjaväebaaside lähedal asuvatel õnnepaleedel on kibedad tööpäevad , sest sõdurid tahavad veel enne Pärsia lahe poole teele asumist oma pruudid altari ette viia .',
#   {'start': 106, 'end': 110, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Ma ei hakanud seal trassil kõnelema Arrase nõust , sellest , et Arras üsna pea tahab Ukuaru oja kallale ekskavaatorid tuua .',
#   {'start': 92, 'end': 95, 'text': 'oja', 'labels': ['v172_geo_terms']}],
#  ['Stroomi rand , mis oli Kopli lahe idaosa saastatuse tõttu üle kahekümne aasta suletud , taasavati suplejatele tänavu 10. juulil .',
#   {'start': 8, 'end': 12, 'text': 'rand', 'labels': ['v172_geo_terms']}],
#  ['Kriitika Ühendriikide kohtusüsteemi pihta oli kohe neutraliseeritud järgmise lõiguga , kus Pärsia lahe teema oli lahendatud tüüpilises sõja ( väe ) propaganda stiilis .',
#   {'start': 98, 'end': 102, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['" Mis oleks , kui täidaks selle muna maasikate ja šokolaadi ning pähklitega , " ütles Varblane just sellise poeedi kombel , kes Saharas janusse surres riimib värsse Atlandi ookeanist .',
#   {'start': 173,
#    'end': 182,
#    'text': 'ookeanist',
#    'labels': ['v172_geo_terms']}],
#  ['Saabumine Rio de Janeirosse oli kui kevadiselt Soomaalt juulikuisesse Pärnu randa sattumine .',
#   {'start': 76, 'end': 81, 'text': 'randa', 'labels': ['v172_geo_terms']}],
#  ['Aga Eloan ei läinud hoopiski Korgorathi mägedesse Getmanne tippu .',
#   {'start': 40, 'end': 49, 'text': 'mägedesse', 'labels': ['v172_geo_terms']}],
#  ['Jah , jaapanlased plaanisid luua hullumeelset riiki , mis ulatuks Vaiksest ookeanist Atlandi ookeanini .',
#   {'start': 75, 'end': 84, 'text': 'ookeanist', 'labels': ['v172_geo_terms']}],
#  ['Ürümchit piiravad kolmest küljest , idast , läänest ja lõunast , Tian Shani mäestiku mitmed ahelikud , põhjast aga Junggari ( Džungaaria ) nõgu , mida omakorda ümbritsevad Alatau ja Altai mäestik .',
#   {'start': 76, 'end': 84, 'text': 'mäestiku', 'labels': ['v172_geo_terms']}],
#  ['Sven Hedinile heidab varju asjaolu , et temast jäid Taklimakani kõrbesse piinlema uiguurid ja kirgiisid , keda ta oli palganud teejuhtideks ja kaameliajajateks ning keda ta valgest eurooplasest tahtejõu ja eneseteostuseiha poolest nõrgemaks pidas .',
#   {'start': 64, 'end': 72, 'text': 'kõrbesse', 'labels': ['v172_geo_terms']}],
#  ['Ka linnaosa vanad kohanimed , nagu näiteks Haljasorg või Angerja oja pakuvad huvitavaid niidiotsi uurimiseks .',
#   {'start': 65, 'end': 68, 'text': 'oja', 'labels': ['v172_geo_terms']}],
#  ['Linnuklubi soovitab Paljassaare poolsaare tippu rajada linnuhoiuala .',
#   {'start': 32, 'end': 41, 'text': 'poolsaare', 'labels': ['v172_geo_terms']}],
#  ['Nuba mägedes tegutsevate lõuna-mässuliste ühe rühmitusega õnnestuski valitsusel hiljuti pikendada vaherahu kuni käesoleva aasta keskpaigani ning veebruari alguses jõuti nendega kokkuleppele ka rahukõneluste lõpetamise tingimustes .',
#   {'start': 5, 'end': 12, 'text': 'mägedes', 'labels': ['v172_geo_terms']}],
#  ['Ta on teeninud Jaapanis paiknevate USA relvajõudude ülemana , Vaikse ookeani õhujõudude ülemana Havail .',
#   {'start': 69, 'end': 76, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ["Perthi Fremantle'i sadamast lähtunud laev Cormo Express , mille 11 tekil lambad olid , jõu-dis pärast Jiddah' sadama keeldumist seigelda ligi kaks kuud Araabia poolsaare rannikutel , tehes vahepeatuse Kuveidis ja jõudes tagasi Punasesse merre , kus lambad Eritreas maha laaditi .",
#   {'start': 160,
#    'end': 169,
#    'text': 'poolsaare',
#    'labels': ['v172_geo_terms']}],
#  ['TALLINN , 23. mai ( EPLO ) - Reedel päästsid piirivalvurid Tallinna lahel ujunud kingi ja kodukitlit kandnud alajahtunud naisterahva .',
#   {'start': 68, 'end': 73, 'text': 'lahel', 'labels': ['v172_geo_terms']}],
#  ['Viimase kohaselt jõudsid Vaikse ookeani lõunapoolsetele saartele esimestena Aasia meresõitjad , sest indiaanlased polevat olnud suutelised primitiivsete paatidega läbima nii pikki vahemaid .',
#   {'start': 32, 'end': 39, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Vanglaametnikud ütlesid , et Williams sai San Quentini vanglas mürgisüsti ning ta suri umbes kell 12.35 USA Vaikse ookeani aja järgi ehk kell 10.35 Eesti aja järgi .',
#   {'start': 115, 'end': 122, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Arafati mäelt liikusid palve-rändurid Muzdalifasse , kust nad peaks täna siirduma edasi Minasse , et loopida kividega sambaid , mille saatan olevat püstitanud Ibrahimi ( piibli Aabra- ham ) peibutamiseks .',
#   {'start': 8, 'end': 13, 'text': 'mäelt', 'labels': ['v172_geo_terms']}],
#  ['Kesklinna haljastajad korjavad iga päev Snelli tiigist kärutäite kaupa rämpsu , mida inimesed on vette loopinud .',
#   {'start': 47, 'end': 54, 'text': 'tiigist', 'labels': ['v172_geo_terms']}],
#  ['Pealegi iga tööstusrajatis Tallinna rannal on märksa kenam ja otstarbekam kui riburada Pirita tee äärde või Rocca al Maresse kerkinud kortermajade näotud betoontahukad .',
#   {'start': 36, 'end': 42, 'text': 'rannal', 'labels': ['v172_geo_terms']}],
#  ['Süvasadama ehitus lükkus edasi pärast Pärnu halduskohtu hiljutist otsust tühistada Lümanda valla üldplaneering , mis lubas süvasadama rajada Küdema lahe kaldale Tamme väikesadama asemele .',
#   {'start': 148, 'end': 152, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Lõuna-Aafrika Kalahari kõrbes kasvav kaktus võib osutuda abivahendiks rasvumise vastu .',
#   {'start': 23, 'end': 29, 'text': 'kõrbes', 'labels': ['v172_geo_terms']}],
#  ['Eelmisel nädalal käisid Vaikse ookeani saareriigi Tonga kodanikud uut parlamenti valimas .',
#   {'start': 31, 'end': 38, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Zawahiri ütles samuti , et Bin Laden ja teised Al-Qaeda juhid ei peitunud Tora Bora koobastesse , vaid võitlesid eesliinil .',
#   {'start': 84,
#    'end': 95,
#    'text': 'koobastesse',
#    'labels': ['v172_geo_terms']}],
#  ['Hirmsaid uudiseid jõuab meieni viimasel ajal suurelt Atlandi ookeanilt .',
#   {'start': 61, 'end': 70, 'text': 'ookeanilt', 'labels': ['v172_geo_terms']}],
#  ['Tegelikult kavatseb Asta haruldased sarvedega lambad Kihnu väina merepargile müüa ja tulevikus hakkavad nad Läänemaa rannikuala roost puhtaks sööma .',
#   {'start': 59, 'end': 64, 'text': 'väina', 'labels': ['v172_geo_terms']}],
#  ['Nii 1996. aastal kui ka tänavu lendasid loendajad lennukil läbi sama territooriumi , Riia lahe .',
#   {'start': 90, 'end': 94, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Ka Väinamerel , Liivi lahel põhjaosas ning Soome lahe ida- ja lääneosas ulatus laine kõrgus 3-7 meetrini .',
#   {'start': 49, 'end': 53, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Nädala eest seiklesid kaks meest Muuga lahel isetehtud alusega ning sattusid merehätta .',
#   {'start': 39, 'end': 44, 'text': 'lahel', 'labels': ['v172_geo_terms']}],
#  ['Nende kodukohad moodustasid hõreda aheliku Ruhnust Riia lahes kuni Tallinnani , mõninga koondumisega Noarootsi ja Vormsi kihelkonda Eesti looderannikul .',
#   {'start': 56, 'end': 61, 'text': 'lahes', 'labels': ['v172_geo_terms']}],
#  ['Miri rusud peaksid kell 9.30 Moskva aja järgi kukkuma Vaiksesse ookeani Austraalia ja Lõuna-Ameerika vahelisele alale , mille keskpunkti kooridnaatideks on 44,2 kraadi lõunalaiust ja 150,4 kraadi läänepikkust .',
#   {'start': 64, 'end': 71, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Tallinnas Kakumäe poolsaare metsas mootorsaagidega ringi liikuvad töömehed langetavad pea tuhat leht- ja okaspuud , et teha ruumi 2000-3000 ruutmeetri suurustele kruntidele , kirjutab Postimees .',
#   {'start': 18, 'end': 27, 'text': 'poolsaare', 'labels': ['v172_geo_terms']}],
#  ['Et Ülemiste järv ei võta enam kanalite kaudu vett vastu , on see kõrgeks paisutanud nii Soodla kui ka Paunküla veehoidlate vesikonna jõed .',
#   {'start': 111,
#    'end': 122,
#    'text': 'veehoidlate',
#    'labels': ['v172_geo_terms']}],
#  ['13 Pirital , Stroomi rannas ja Kunda lahes .',
#   {'start': 37, 'end': 42, 'text': 'lahes', 'labels': ['v172_geo_terms']}],
#  ['Atlantise stardi ajal asus orbitaaljaam koos kolmeliikmelise meeskonnaga rohkem kui 355 kilomeetri kõrgusel Atlandi ookeani põhjaosa kohal , Newfoundlandist ida pool .',
#   {'start': 116, 'end': 123, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Täna viibib USA kaitseminister Võidu pargis Poklonnaja mäe jalamil toimuval tseremoonial ja tutvub Moskva linna vaatamisväärsustega .',
#   {'start': 55, 'end': 58, 'text': 'mäe', 'labels': ['v172_geo_terms']}],
#  ['Kohila lähistel Rabivere raba serval näitas poiss kätte eelmisel päeval kadunud Nordeni torke ja lõikehaavadega surnukeha .',
#   {'start': 25, 'end': 29, 'text': 'raba', 'labels': ['v172_geo_terms']}],
#  ['Sillamäe jäätmehoidla , mis on aastakümneid ähvardanud Soome lahte , tekkis nõukogude ajal , mil Silmetis toodeti uraani .',
#   {'start': 61, 'end': 66, 'text': 'lahte', 'labels': ['v172_geo_terms']}],
#  ['Päästeameti juhtimiskeskuse korrapidaja sõnul oleks täna Järva-Jaani tehisjärve peaaegu uppunud nelja-aastane tüdruk .',
#   {'start': 69,
#    'end': 79,
#    'text': 'tehisjärve',
#    'labels': ['v172_geo_terms']}],
#  ['Nadežda saab presidendi käsundusohvitserilt tunnistuse , mille kohaselt president annab talle kolme läbi Kadrioru tiigi jää vajunud poisi päästmise eest Eesti Punase Risti neljanda klassi teenetemärgi .',
#   {'start': 114, 'end': 119, 'text': 'tiigi', 'labels': ['v172_geo_terms']}],
#  ['Tallinna lahel puhub tuul üle 20 meetri sekundis , laine kõrgus on üle nelja meetri .',
#   {'start': 9, 'end': 14, 'text': 'lahel', 'labels': ['v172_geo_terms']}],
#  ['Lääne-Virumaa talumees Toivo väidab , et tema maadel asuva Põlula allika vesi on parem kui maailmakuulus Evian .',
#   {'start': 66, 'end': 72, 'text': 'allika', 'labels': ['v172_geo_terms']}],
#  ['Stroomi rand saab rannahoone',
#   {'start': 8, 'end': 12, 'text': 'rand', 'labels': ['v172_geo_terms']}],
#  ['Viitega Lääne ja Vene allikatele teatas päevaleht , et salajane projekt näeb ette tohutu sõjalise kompleksi rajamist Jamantau mäe alla Beloretski rajoonis Uuralides .',
#   {'start': 126, 'end': 129, 'text': 'mäe', 'labels': ['v172_geo_terms']}],
#  ['Linnavalitsuse lubadus avada eeloleval suvel Paljassaare poolsaarel Katariina kai juures avalik supelrand on tegelikult alles idee tasemel .',
#   {'start': 57,
#    'end': 67,
#    'text': 'poolsaarel',
#    'labels': ['v172_geo_terms']}],
#  ['Üldplaneeringus sisaldub ka sadamaalade tsoneering , mille järgi on ette nähtud kaubasadamate koondamine Kopli ja Paljassaare poolsaarele .',
#   {'start': 126,
#    'end': 137,
#    'text': 'poolsaarele',
#    'labels': ['v172_geo_terms']}],
#  ['Musumuäel süttis 108 , Tornide Väljakul 68 ja Schnelli tiigi pargis 42 uut pargivalgustit .',
#   {'start': 55, 'end': 60, 'text': 'tiigi', 'labels': ['v172_geo_terms']}],
#  ['19 kraadi on soe Stroomi , Võsu , Kunda ja Vasknarva randade vesi .',
#   {'start': 53, 'end': 60, 'text': 'randade', 'labels': ['v172_geo_terms']}],
#  ['Eesmärgi saavutamiseks on kohalikud turismiettevõtjad investeerinud uue golfikeskuse ehitamisse , vald korrastab Pühajärve randa ja suurenev turistide hulk innustab ettevõtjaid rajama ka uusi hotellikohti .',
#   {'start': 123, 'end': 128, 'text': 'randa', 'labels': ['v172_geo_terms']}],
#  ['Kui olete tuletorni kürgetest trepiastmetest üles turninud , siis paistab ära ka Ristna neem .',
#   {'start': 88, 'end': 92, 'text': 'neem', 'labels': ['v172_geo_terms']}],
#  ['Novembri lõpus kavatsevad 60 eestlast ühel ajal jõuda ligi 6000-meetrise Kilimanjaro mäe tippu Aafrikas .',
#   {'start': 85, 'end': 88, 'text': 'mäe', 'labels': ['v172_geo_terms']}],
#  ['Ruhnus viib kohaliku külapoe omanik Vitali meid kohe Limo randa karu jälgi vaatama .',
#   {'start': 58, 'end': 63, 'text': 'randa', 'labels': ['v172_geo_terms']}],
#  ['Maastikuring , mille pikkus on 12,1 kilomeetrit ja mis kulgeb Rakke Linnamäel ning Edru mägedes , nõuab sõitjalt head treenitust ja oskust ratast valitseda , kuid rada on siiski oluliselt kergem kui maratonidel .',
#   {'start': 88, 'end': 95, 'text': 'mägedes', 'labels': ['v172_geo_terms']}],
#  ['Eile varahommikul Paide tehisjärve äärde kalale läinud Krassil ei olnud alguses püügiõnne .',
#   {'start': 24,
#    'end': 34,
#    'text': 'tehisjärve',
#    'labels': ['v172_geo_terms']}],
#  ['Kakumäe randa plaanitakse järgmiseks suveks rannahoonet , palliplatse ja vabaõhulava .',
#   {'start': 8, 'end': 13, 'text': 'randa', 'labels': ['v172_geo_terms']}],
#  ['1682 - Prantsuse maadeuurija La Salle jõudis mööda Mississippi jõge Mehhiko laheni .',
#   {'start': 76, 'end': 82, 'text': 'laheni', 'labels': ['v172_geo_terms']}],
#  ['Äkki peaksime kala adopteerima ja India ookeanist Soome lahte ümber kolima ?',
#   {'start': 40, 'end': 49, 'text': 'ookeanist', 'labels': ['v172_geo_terms']}],
#  ['Kaks aastat pärast seda alustas Hawaiil tööd USA Vaikse ookeani hoiatuskeskus .',
#   {'start': 56, 'end': 63, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Hommikujooksu tegijaid võttis kuulsal Bondi rannal vastu põlevate eukalüptide kirbe lõhn .',
#   {'start': 44, 'end': 50, 'text': 'rannal', 'labels': ['v172_geo_terms']}],
#  ['Vaadata ja pildistada on aga võimalik 100-kilomeetrise läbimõõduga Popikai kraatrit , mis asub Leena suudmes Taimõri poolsaare taga .',
#   {'start': 117,
#    'end': 126,
#    'text': 'poolsaare',
#    'labels': ['v172_geo_terms']}],
#  ['Kuid niisugune uus keskendumine Pärsia lahe piirkonnale on siiski laiema tähtsusega : hoolimata kõigist suurtest probleemidest Venemaa , NATO laienemise ja Hiinaga , asuvad kõige suuremad koheste poliitiliste ja diplomaatiliste raskuste piirkonnad Pärsia lahe ja Vahemere regioonis , Kesk-Aasias , Balkanil , Aafrikas - ehk " Lõunas " , nagu prantslased ütlevad .',
#   {'start': 255, 'end': 259, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Sel kevadel kalasõja alana tuntuks saanud Liivi lahe osa on Saaremaa piirkonna piirivalvurite valvata .',
#   {'start': 48, 'end': 52, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Lihulas avati eile reoveepuhasti , mis on Haapsalu-Matsalu lahe keskkonnaprojekti esimene osa .',
#   {'start': 59, 'end': 63, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Leisi vallas on Pihla laid erakätes , aga Kihelkonna vallas , Vilsandi rahvuspargi ümber olevad väikelaiud kuuluvad riigile .',
#   {'start': 22, 'end': 26, 'text': 'laid', 'labels': ['v172_geo_terms']}],
#  ['Igas eas loodushuvilisi peaksid köitma ka lood Põhja-Ameerika piisoni ellujäämise saladusest , samuti Põhjaranniku äärses Soome lahes talvituvatest lindudest , virmalistest ja kaugetest reisidest .',
#   {'start': 128, 'end': 133, 'text': 'lahes', 'labels': ['v172_geo_terms']}],
#  ['Põhja-Tallinnas on tähtsaimaks Stroomi ranna väljaehitamine ja korrastamine - Stroomi rannast peab saama üle Eesti tunnustatud puhkekoht , ütles Järve .',
#   {'start': 39, 'end': 44, 'text': 'ranna', 'labels': ['v172_geo_terms']}],
#  ['Inimohvritega suuri õnnetusi juhtus sealseis vetes eelmisel sajandil kolm : peale Estonia uppus saare külje all 1947. aasta jõulu-õhtul Ameerika kaubalaev Park Victory kümne madrusega par-dal ning 1929. aastal jäid veelgi lähemal , 300 meetrit Utö rannast merre kolmemastilisel purjekal Drake olnud kuus madrust .',
#   {'start': 248, 'end': 255, 'text': 'rannast', 'labels': ['v172_geo_terms']}],
#  ['Ainsana pealinna randadest on puhas ja ujumiskõlblik vesi Kakumäe rannas .',
#   {'start': 66, 'end': 72, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['Paldiski piirivalvurid märkasid eile kell 3.53 radarit jälgides , et juba kümne minuti jagu seisab Suur-Pakri saare põhjatipust kolme miili kaugusel läänes Krassi madalikul tundmatu laev , mis ei vasta kutsungile .',
#   {'start': 163,
#    'end': 172,
#    'text': 'madalikul',
#    'labels': ['v172_geo_terms']}],
#  ['Harju mäe aluste tunnelite korrastamine ja turismiobjektina avamine on kirjas ka linnavõimu koalitsioonileppes .',
#   {'start': 6, 'end': 9, 'text': 'mäe', 'labels': ['v172_geo_terms']}],
#  ['Musumäele ( Viruvärava mägi ) valati skulptuuride tarbeks eelmisel nädalal kaks alust , 1,5 -2 meetri kõrguste kujude paigaldamine peaks esialgsete kavade kohaselt algama täna .',
#   {'start': 23, 'end': 27, 'text': 'mägi', 'labels': ['v172_geo_terms']}],
#  ['" Harku ja Pääsküla raba kaitseala moodustamine on oluline etapp Tallinna rahvuspargi rajamisel , " ütles Ratas .',
#   {'start': 20, 'end': 24, 'text': 'raba', 'labels': ['v172_geo_terms']}],
#  ['Tänavu paisatakse Salmistu-Valkla rannas meredessandiga rannale 31 neljaliikmelist võistkonda , nende seas 14 välisvõistkonda 11 riigist .',
#   {'start': 34, 'end': 40, 'text': 'rannas', 'labels': ['v172_geo_terms']}],
#  ['Teine pomm plahvatas pisut hiljem Bosporuse väina kaldal Ceylan Intercontinental hotelli juures .',
#   {'start': 44, 'end': 49, 'text': 'väina', 'labels': ['v172_geo_terms']}],
#  ['Venemaa president Vladimir Putin peatas laupäeval ametlikult Venemaa osaluse tähtsas Külma sõja järgses tavarelvastusleppes , mille eesmärgiks oli piirata raskerelvade arvu Atlandi ookeani ja Uuralite vahelisel alal , põhjendades seda erakorraliste turvalisust puudutavate asjaoludega .',
#   {'start': 181, 'end': 188, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Viimsi vald muutis eelmise aasta jaanipäeva paiku kaheksa päevaga kurikuulsa nn Antenniväljaku detailplaneeringut , mille tõttu saab Viimsi poolsaare keskel asuvale krundile ehitada 80 elamuühiku asemel 320 elamuühikut .',
#   {'start': 140,
#    'end': 149,
#    'text': 'poolsaare',
#    'labels': ['v172_geo_terms']}],
#  ['USA kaitseministeerium kavatseb vabastada mõned terrorismis kahtlustatavad vangid , keda hoitakse Kuubal Guantanamo lahe laagris , kuna nad ei ole enam ohtlikud ning neil pole pakkuda ka enamat luureinfot .',
#   {'start': 116, 'end': 120, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Kopamehe sõnul moodustavad Triigi poolsaarel kasvavad puu ja põõsaliigid kolmandiku kogu Eesti puudest ja põõsastest .',
#   {'start': 34,
#    'end': 44,
#    'text': 'poolsaarel',
#    'labels': ['v172_geo_terms']}],
#  ["Piirivalvurid , Nordic Jet Line'i katamaraani meeskond ja veeteede ameti töötajad harjutavad kolmapäeval Tallinna lahel päästetegevust .",
#   {'start': 114, 'end': 119, 'text': 'lahel', 'labels': ['v172_geo_terms']}],
#  ['Iisrael tõi väed Egiptusele kuuluvalt Siinai poolsaarelt välja ja riigid sõlmisid diplomaatilised suhted .',
#   {'start': 45,
#    'end': 56,
#    'text': 'poolsaarelt',
#    'labels': ['v172_geo_terms']}],
#  ['Kuigi eeliseks oli see , et naftatankerid ei koorma Bosporuse väina , näitasid arvestused , et Iraani või Venemaa kaudu on toru ehitada palju odavam .',
#   {'start': 62, 'end': 67, 'text': 'väina', 'labels': ['v172_geo_terms']}],
#  ['Vene Kaug-Idas Vitjazhi lahes paiknenud mereväebaasis õpetati kashelotte vaenlase sukeldujaid otsima , laevu ründama , pommid keha külge kinnitatud , ja teisi lahinguülesandeid täitma .',
#   {'start': 24, 'end': 29, 'text': 'lahes', 'labels': ['v172_geo_terms']}],
#  ['" Atlandi ookean on siiski avatud ookean ja seal on tankeriõnnetuse tagajärjed tunduvalt väiksemad kui Läänemerel , kus sellest tuleks ökokatastroof . "',
#   {'start': 10, 'end': 16, 'text': 'ookean', 'labels': ['v172_geo_terms']}],
#  ['Tenson peab Pärnu lahe vee suuremaks puuduseks seda , et bakteriaalsed näitajad pole ühtlased ja veeproov võib nädalaga oluliselt muutuda .',
#   {'start': 18, 'end': 22, 'text': 'lahe', 'labels': ['v172_geo_terms']}],
#  ['Tartu linnavalitsus soovib viie miljoni kroonise alghinnaga maha müüa südalinnas Lille mäel asuva mitu aastat ilmastikuoludele räsida olnud poolelioleva haldushoone .',
#   {'start': 87, 'end': 91, 'text': 'mäel', 'labels': ['v172_geo_terms']}],
#  ['Lisaks staabis ringivaatamisele sõidab seltskond miinitraaleril Sulev Tallinna lahel ringi .',
#   {'start': 79, 'end': 84, 'text': 'lahel', 'labels': ['v172_geo_terms']}],
#  ['Õhupall sõidab ligikaudu sajakilomeetrise tunnikiirusega enam kui 9000 meetri kõrgusel kirde suunas ja peaks senist kurssi jätkates ületama Põhja-Hiina ranniku , Korea poolsaare ja Jaapani .',
#   {'start': 168,
#    'end': 177,
#    'text': 'poolsaare',
#    'labels': ['v172_geo_terms']}],
#  ['Läbi Iraani kulgevad uimastite salakaubaveo trassid Afganistanist ja Pakistanist Pärsia lahele , Euroopasse ja Kesk-Aasiasse ning seal toimub sageli kokkupõrkeid uimastikaupmeeste ja julgeoleku vahel .',
#   {'start': 88, 'end': 94, 'text': 'lahele', 'labels': ['v172_geo_terms']}],
#  ['Tallinna Pirita rannas avatakse esmaspäeval rannahooaeg , ülejäänud kolm Tallinna avalikku randa - Kakumäe , Harku ja Stroomi rand avatakse ametlikult 3. juunil .',
#   {'start': 126, 'end': 130, 'text': 'rand', 'labels': ['v172_geo_terms']}],
#  ['USA ja Ladina-Ameerika suurte banaanitootjariikide nn. banaanisõda Euroopa Liidu vastu kestab juba mitu aastat , sest Euroopa Liit on andnud eelisseisundi banaanikaubanduses endistele Kariibi mere , Vaikse ookeani ja Aafrika kolooniatele .',
#   {'start': 206, 'end': 213, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Lähima 50 aasta jooksul kolmekordistub ka Aasiast ja Vaikse ookeani saartelt pärit ameeriklaste arv , ulatudes 38 miljoni ehk üheksa protsendini .',
#   {'start': 60, 'end': 67, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Keskkonnainspektsiooni Pärnu osakonna vaneminspektori Aavo Sempelsoni andmeil on Pärnu lahelt tabatud ka suurema kalakogusega röövpüüdjaid , kuid keskkonnale tekitatud kahju eest nõutav hüvitis kujunes rekordiliseks seetõttu , et keelualal püüdmise eest on seadusega ette nähtud tavalisest kolm korda suurem summa .',
#   {'start': 87, 'end': 93, 'text': 'lahelt', 'labels': ['v172_geo_terms']}],
#  ['Tallinna Kesklinna tuletõrjekomando sai Kadrioru tiigi juurde väljakutse kell 14.16.',
#   {'start': 49, 'end': 54, 'text': 'tiigi', 'labels': ['v172_geo_terms']}],
#  ['Sihtpunktini , Salmistu rannani , on jäänud veel palju kilomeetreid .',
#   {'start': 24, 'end': 31, 'text': 'rannani', 'labels': ['v172_geo_terms']}],
#  ['Piirivalveameti pressiesindaja Urmo Kohv ütles ETAle , et laev jõudis kell 14.45 Kolka poolsaare juures madalikule .',
#   {'start': 87, 'end': 96, 'text': 'poolsaare', 'labels': ['v172_geo_terms']}],
#  ['Austraalia huvi sõnastas aga üks saareametnik : " Omada keset India ookeani sellist lennukikandjat - selle eest võib ju igal aastal mõnedkümned miljonid maksta .',
#   {'start': 68, 'end': 75, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Siis jõuavad kätte Brasiilia ja Kariibi mere saared , läbi Panama kanali sõidetakse Vaiksele ookeanile , kus on palju peatuskohti .',
#   {'start': 93,
#    'end': 102,
#    'text': 'ookeanile',
#    'labels': ['v172_geo_terms']}],
#  ['Viiendaks : vaadata Copacabana või Ipanema rannal tüdrukuid .',
#   {'start': 43, 'end': 49, 'text': 'rannal', 'labels': ['v172_geo_terms']}],
#  ['Samas tõdes Ojava , et reostus paistis olevat Tallinna lahel ja selle ümbruses triivinud juba mitu päeva , mistõttu on selle tekitajat väga raske tabada .',
#   {'start': 55, 'end': 60, 'text': 'lahel', 'labels': ['v172_geo_terms']}],
#  ['Vaikse ookeani äärsete riikide juhid otsustasid Ühendriikide presidendi Bill Clintoni survel nõuda uut ülemaailmset vabakaubanduskõneluste vooru järgmisel aastal .',
#   {'start': 7, 'end': 14, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Vaikse ookeani äärest Kaukaasiani ja kaugemale on Moskva uus juhtkond võtmas kasutusele aina agressiivsemat välispoliitikat , mis on rajatud pigem vastasseisule Läänega kui partnerlusele .',
#   {'start': 7, 'end': 14, 'text': 'ookeani', 'labels': ['v172_geo_terms']}],
#  ['Bernard Buigues plaanib seda eksponeerida Hatanga koobastes , kuhu lisaks mammutile hakatakse tooma teisi väljasurnud loomade jäänuseid .',
#   {'start': 50, 'end': 59, 'text': 'koobastes', 'labels': ['v172_geo_terms']}],
#  ['Maailma esimese triivjaama rajajaid ; tema nime kannab Banksi maal ( saar Kanada Arktika saarestiku lääneosas ) voolav jõgi ( Masik River ) .',
#   {'start': 89,
#    'end': 99,
#    'text': 'saarestiku',
#    'labels': ['v172_geo_terms']}],
#  ['Keskaegkonna lõpul kriidi ajastul alanud ning uusaegkonnas jätkunud Alpi kurrutus on loonud Alpid , Apenniinid , Karpaadid , Krimmi ja Kaukaasia mäed , Atlase mäed ja enamiku Väike-Aasiast kuni Malaka poolsaareni kulgevatest mäestikest .',
#   {'start': 145, 'end': 149, 'text': 'mäed', 'labels': ['v172_geo_terms']}],
#  ['Ometi ei osanud daam , kes tööalaselt linna juhtidega pidevalt lävib ( Kink on Eesti juhtiva hüdrogeoloogina aastaid jälginud Pakri poolsaare vete puhtust ) , kuidagi arvata , et tema huvidest nii mööda vaadatakse .',
#   {'start': 132,
#    'end': 141,
#    'text': 'poolsaare',
#    'labels': ['v172_geo_terms']}]]

# %% [markdown]
# #### Second round of labelling

# %% [markdown]
# After filtering out the texts that contains the desired entities, a second round of tagging in Labelstudio should be done to mark the correct NER span on the text and also mark whether the current tagger found the correct span. This part here exports the texts to Labelstudio again.

# %%
from estnltk.taggers import NerTagger
from estnltk import Text
ner = NerTagger()
recall_set_texts = []
for snt in recall_set:
    text = Text(snt)
    text.tag_layer()
    ner.tag(text)
    recall_set_texts.append(text)

# %%
from estnltk.converters.label_studio.label_studio import LabelStudioExporter
exporter = LabelStudioExporter("koond_1000_levinumad_true.json",['ner'],checkbox=True,attribute='nertag',attribute_values=['PER','ORG','LOC'])

# %%
exporter.convert(recall_set_texts,append=False)

# %%
print(exporter.labeling_interface)
# Out:
#         <View>
#             <Labels name="label" toName="text">
# 	<Label value="PER" background="#8AE768"/>
# 	<Label value="ORG" background="#93236A"/>
# 	<Label value="LOC" background="#8CE11B"/>
#
#             </Labels>
#         <Text name="text" value="$text"/>
#             <Header value="Are the annotations correct?"/>
#                 <Choices name="review" toName="text">
#                     <Choice value="yes"/>
#                     <Choice value="no"/>
#                 </Choices>
#             </View>

# %% [markdown]
# Then the tagged file can again be imported here, just like seen above.

# %%
import json

def checkbox_statistics(filename, choices = ['yes','no']):
    
    with open(filename,'r',encoding='UTF-8') as f:
        data = json.load(f)
        
    counts = {}
    for txt in data:
        choice = txt['annotations'][0]['result'][-1]['value']['choices'][0]
        counts[choice] = counts.get(choice,0) + 1
    
    return counts

# %%
checkbox_statistics('labelled_data/substringtagger_labels/koond_1000_levinumad_labelled.json')
# Out:
# {'no': 644, 'yes': 353}

# %% [markdown]
# # Post-process annotation results and update benchmark
#
# ## I. Post-process manual annotation results
#
# Postprocessing:
# * Remove duplicates
# * Take out positive cases
# * Merge phase 1 & phase 2 annotations
# * Save recall_sets into CSV files

# %% [markdown]
# ### The large dataset

# %%
import json
import os
import os.path
import pandas as pd

# %%
input_dir = "labelled/extended_1000"
assert os.path.exists(input_dir), \
    f'(!) Missing input dir {input_dir!r}. Complete the second annotation phase and download annotated data.'

# %%
def read_json_file(filename):    
    f = open(filename, encoding="utf-8")
    data = json.load(f)
    f.close()
    return data

# %%
annotated = []
for file in os.listdir(input_dir):
    pos = read_json_file(os.path.join(input_dir, file))
    cat = file.split(".")[0].split("_")[1].strip()
    try:
        for elem in pos:
            #print(elem["annotations"][0], "\n")
            start = elem["annotations"][0]["result"][0]["value"]["start"]
            end = elem["annotations"][0]["result"][0]["value"]["end"]
            phrase =  elem["annotations"][0]["result"][0]["value"]["text"]
            text = elem["data"]["text"]
            if len( elem["annotations"][0]["result"]) > 1:
                choice = elem["annotations"][0]["result"][1]["value"]["choices"][0]
                annotated.append((file, cat, phrase, choice, text, start, end))
            else:
                print('erroneous annotation:', elem["id"])

    except Exception as e:
        print(str(e))
        print(elem)
        break
        #continue

annotated_df = pd.DataFrame(annotated, columns=["file","category", "phrase", "choice","text", "start", "end"])
# Out:
# erroneous annotation: 8091

# %%
annotated_df = annotated_df.drop_duplicates()

# %%
annotated_df
# Out:
#             file category                        phrase choice  \
# 0     pos_A.json        A                    sooja merd     no
# 1     pos_A.json        A               pruunide säärte     no
# 2     pos_A.json        A       kaheksatuhandelist mäge     no
# 3     pos_A.json        A               kohalikke panku     no
# 4     pos_A.json        A                 ainsa pangana     no
# ...          ...      ...                           ...    ...
# 7737  pos_Z.json        Z                   lupo: kurgi     no
# 7738  pos_Z.json        Z                  emili: kurgi     no
# 7739  pos_Z.json        Z  PIPI-vs-banaanikalajutt: oja     no
# 7740  pos_Z.json        Z              kiisumiisu: raba     no
# 7741  pos_Z.json        Z                          raba     no
#
#                                                    text  start  end
# 0     “ Me armastame sooja merd ning ilusaid ja vana...     15   25
# 1     Kepka viltu peas , sööstab Ülle pruunide säärt...     32   47
# 2     Teisegi tipptulemuse tegi ta läinud aastal , v...     77  100
# 3     Valitsus mõjutas kohalikke panku ja kindlustus...     17   32
# 4     Näiteks ERA Pank maksab ( ainsa pangana ) oma ...     26   39
# ...                                                 ...    ...  ...
# 7737                                        lupo: kurgi      0   11
# 7738                                    emili: kurgi ka      0   12
# 7739     PIPI-vs-banaanikalajutt: oja käskis lugeda ...      0   28
# 7740                       kiisumiisu: raba on sinilill      0   16
# 7741  raba: räägid sa põnevalt siis , kuulame huviga...      0    4
#
# [7671 rows x 7 columns]

# %%
# Manual annotations about NE match
annotated_df["choice"].value_counts()
# Out:
# choice
# no               6210
# full match       1440
# partial match      21
# Name: count, dtype: int64

# %%
annotated_df[annotated_df['choice']=='full match']
# Out:
#             file category             phrase      choice  \
# 22    pos_A.json        A    Vaikset ookeani  full match
# 24    pos_A.json        A     Vaikse ookeani  full match
# 25    pos_A.json        A     Mustast merest  full match
# 32    pos_A.json        A  Vaiksesse ookeani  full match
# 53    pos_A.json        A   Vaikses ookeanis  full match
# ...          ...      ...                ...         ...
# 6794  pos_Y.json        Y        Lai'a jõest  full match
# 6822  pos_Y.json        Y          RZB panga  full match
# 7187  pos_Z.json        Z     Calais' väinas  full match
# 7306  pos_Z.json        Z     Croix' saarelt  full match
# 7423  pos_Z.json        Z          Fear' jõe  full match
#
#                                                    text  start  end
# 22    Ainult inimjõul liikuvate sõiduvahenditega ümb...    121  136
# 24    Saades teada , et tegemist on USA Vaikse ookea...     34   48
# 25    See-eest saab iga põhjakaukaasia keelkonda kuu...    149  163
# 32    13,3 meetri pikkuse laevaga sõidetakse üle Atl...     80   97
# 53    Juuni keskel läks USA ranniku-vetes Vaikses oo...     36   52
# ...                                                 ...    ...  ...
# 6794  No kui eesti on põlis veneala , mis kuradi pär...    123  134
# 6822  RZB prognoos Ühispanga 1997 . aasta kasumi suh...    139  148
# 7187  Mullu detsembris Calais' väinas koos 3000 luks...     17   31
# 7306                                   Croix' saarelt .      0   14
# 7423  Cape Fear' jõe teisel kaldal New Hanoveri maak...      5   14
#
# [1440 rows x 7 columns]

# %%
annotated_df[annotated_df['choice']=='partial match']
# Out:
#             file category              phrase         choice  \
# 3276  pos_G.json        G         sõrve sääre  partial match
# 3591  pos_H.json        H         Rocki panga  partial match
# 3640  pos_H.json        H      Changi saarele  partial match
# 3666  pos_H.json        H     Francisco lahes  partial match
# 3737  pos_H.json        H       Migueli saart  partial match
# 3816  pos_H.json        H           Mare ojas  partial match
# 4098  pos_H.json        H      Weighti saarel  partial match
# 4110  pos_H.json        H     Zedongi mägedes  partial match
# 4177  pos_H.json        H      innipegi järve  partial match
# 5364  pos_S.json        S       Lootuse neeme  partial match
# 5449  pos_S.json        S    Vanamõisa järves  partial match
# 5506  pos_S.json        S  botaanikaaia tiiki  partial match
# 6282  pos_Y.json        Y            25 mäelt  partial match
# 6284  pos_Y.json        Y            25 mäelt  partial match
# 6361  pos_Y.json        Y          Le kallast  partial match
# 6444  pos_Y.json        Y               2 mäe  partial match
# 6654  pos_Y.json        Y            UBB pank  partial match
# 6777  pos_Y.json        Y             90 mäge  partial match
# 6806  pos_Y.json        Y          re neemest  partial match
# 7183  pos_Z.json        Z         Blas' neeme  partial match
# 7424  pos_Z.json        Z             ” mäele  partial match
#
#                                                    text  start  end
# 3276          Või sõrve sääre tipus olevadi tuulikuid ?      4   15
# 3591  Paari nädala eest Inglismaal toimunud Northern...     47   58
# 3640  Reisi lõpp viib meid Koh Changi saarele , kus ...     25   39
# 3666  Meelelahutuse alal tegutseb ka kuulus Alcatraz...     51   66
# 3737  Ta istub väikebussi roolis , sest teisel päeva...     97  110
# 3816  Samas on linnas ka jäävabasid veesilmu , näite...     58   67
# 4098  Buldooserid olid juba varem saadetud kindlusta...     85   99
# 4110  Hiina keskpank andis armee aastapäeva puhul vä...    110  125
# 4177   28 meetrit on  Winnipegi  järve suurim sügavus .     16   31
# 5364  Nii lai , et see ei pääse läbi Panama kanali ,...     80   93
# 5449  Verevi ja Tõrva Vanamõisa järves oli vesi 20 k...     16   32
# 5506  Laanetu sõnul tuli kobras ka näiteks Tartu bot...     43   61
# 6282       10.00 kahevõistluse hüpped K18 ja K 25 mäelt     36   44
# 6284                11.00 suusahüpped K18 ja K 25 mäelt     27   35
# 6361  Paat ründab ninaga Phi Phi Le kallast , see on...     27   37
# 6444  Eile jäi Internetiportaali EverestNews andmete...     76   81
# 6654  Aktsionäride koosolek , kuhu olid kutsutud enn...    124  132
# 6777  Õhus on küsimused : miks läks hind plaanitust ...    168  175
# 6806  Väike-Belti ning Sundi vetes Hasenø re neemest...     36   46
# 7183  Hai ründas poissi San Blas' neeme juures , mis...     22   33
# 7424  Merepinnast 1909 meetri kõrgusel asuva Ventoux...    141  148

# %% [markdown]
# Discard 'partial match' (too few items). Focus on the full match.

# %%
full_match_df = annotated_df[annotated_df["choice"]=="full match"]
full_match_df
full_match_df["category"].value_counts()
# Out:
# category
# H    669
# G    500
# S     85
# A     81
# Y     78
# I     14
# D      5
# N      5
# Z      3
# Name: count, dtype: int64

# %%
# Extract sentences and annotations. 
# Group by postags
annotations_by_pos = {}
for i in full_match_df.index:
    postag = full_match_df['category'][i]
    if postag not in annotations_by_pos:
        annotations_by_pos[postag] = []
    start = full_match_df['start'][i]
    end = full_match_df['end'][i]
    phrase = full_match_df['phrase'][i]
    sentence = full_match_df['text'][i]
    span = {'start': start, 'end': end, 'text': phrase, 'labels': ['LOC']}
    annotations_by_pos[postag].append( (sentence, span) )

# %% [markdown]
# ### The small dataset
#
# Repeat the same procedure for the small dataset.

# %%
input_dir = "labelled/extended_100"
assert os.path.exists(input_dir), \
    f'(!) Missing input dir {input_dir!r}. Complete the first annotation phase and download annotated data.'

# %%
annotated = []
for file in os.listdir(input_dir):
    pos = read_json_file(os.path.join(input_dir, file))
    cat = file.split(".")[0].split("_")[1].strip()
    try:
        for elem in pos:
            #print(elem["annotations"][0], "\n")
            start = elem["annotations"][0]["result"][0]["value"]["start"]
            end = elem["annotations"][0]["result"][0]["value"]["end"]
            phrase =  elem["annotations"][0]["result"][0]["value"]["text"]
            text = elem["data"]["text"]
            if len( elem["annotations"][0]["result"]) > 1:
                choice = elem["annotations"][0]["result"][1]["value"]["choices"][0]
                annotated.append((file, cat, phrase, choice, text, start, end))
            else:
                print(elem["id"])

    except Exception as e:
        print(str(e))
        print(elem)
        break
        #continue

annotated_df = pd.DataFrame(annotated, columns=["file","category", "phrase", "choice","text", "start", "end"])

# %%
# Manual annotations about NE match
annotated_df["choice"].value_counts()
# Out:
# choice
# no               1799
# full match        245
# partial match      18
# Name: count, dtype: int64

# %%
annotated_df[annotated_df['choice']=='full match']
# Out:
#             file category            phrase      choice  \
# 14    pos_A.json        A     Väikese väina  full match
# 16    pos_A.json        A      Mustas meres  full match
# 60    pos_A.json        A    ülemiste järve  full match
# 79    pos_A.json        A    Vaikse ookeani  full match
# 343   pos_D.json        D         Lahti jõe  full match
# ...          ...      ...               ...         ...
# 1940  pos_Y.json        Y        SEBi panga  full match
# 1941  pos_Y.json        Y        MAPO panga  full match
# 1942  pos_Y.json        Y       ETV kanalil  full match
# 1943  pos_Y.json        Y        EVEA panka  full match
# 1980  pos_Z.json        Z  Wicklow' mägedes  full match
#
#                                                    text  start  end
# 14    Kokkukasvamine on toimunud pidevalt , sest saa...    181  194
# 16    Kuuekümnendail aastail asustati Läänemerre ka ...     89  101
# 60    AS Tallinna Vesi peadirektor Enno Pere ütles ,...    143  157
# 79    Atmosfääri liikumishulga moment on eriti suur ...     46   60
# 343   Dali oli Vovaga sageli Lahti jõe ääres mängima...     23   32
# ...                                                 ...    ...  ...
# 1940  TALLINN , 9. september ( EPLO ) - Ajakirja Aff...     98  108
# 1941  Tallinna Äripanga peaomaniku , Moskvas asuva M...     45   55
# 1942  Peale tähtede mängu saavad korvpallihuvilised ...     54   65
# 1943  Sellele vaatamata , et on unine ja turistideva...     78   88
# 1980  " Wicklow' mägedes oli vaid üks tõsine tõus , ...      2   18
#
# [245 rows x 7 columns]

# %%
annotated_df[annotated_df['choice']=='partial match']
# Out:
#             file category                     phrase         choice  \
# 70    pos_A.json        A   elektrooniliste kanalite  partial match
# 81    pos_A.json        A                  püha jõgi  partial match
# 90    pos_A.json        A          järskude kallaste  partial match
# 109   pos_A.json        A  Ameerika-poolsele kaldale  partial match
# 125   pos_A.json        A          paiksete allikate  partial match
# 147   pos_C.json        C             paremal kaldal  partial match
# 167   pos_C.json        C          suuremalt pangalt  partial match
# 184   pos_C.json        C             ilusama fjordi  partial match
# 234   pos_C.json        C             paremal kaldal  partial match
# 457   pos_G.json        G           Prantsuse saarel  partial match
# 570   pos_H.json        H            Sadamale saarte  partial match
# 1078  pos_N.json        N                kolme järve  partial match
# 1149  pos_N.json        N                 kahe saare  partial match
# 1153  pos_N.json        N         kahesajast saarest  partial match
# 1225  pos_O.json        O                 VIII lahes  partial match
# 1517  pos_S.json        S                mõisa järve  partial match
# 1532  pos_S.json        S               küla rannast  partial match
# 1883  pos_Y.json        Y                 TV kanalit  partial match
#
#                                                    text  start  end
# 70    Hansapanga elektrooniliste kanalite töös võib ...     11   35
# 81    Selgub , et tegemist on restorani ühe omaniku ...    123  132
# 90    Jõesängi järskude kallaste sisse on uuristatud...      9   26
# 109   Venemaa tuntud polaaruurija Dmitri Šparo jõudi...    133  158
# 125   Eesti paiksete allikate saaste on mõne aastaga...      6   23
# 147   Pirita jõe paremal kaldal olevalt kailt võetak...     11   25
# 167   Vene gaasikontsernile Gazprom kuuluv AS Nitrof...     77   94
# 184   Kohe , kui me otsa ühe Norra ilusama fjordi Ly...     29   43
# 234   Ka elavad Tereki paremal kaldal tšetšeeni taib...     17   31
# 457   AJACCIO , 25. august ( Reuters-EPLO ) - Prants...     40   56
# 570   Majandusministeerium taotleb järgmiseks hooaja...     73   88
# 1078  Tõrva kolme järve jooks on kogupereüritus sõna...      6   17
# 1149  Ettevõtte alustab laevaga Aegna kahe saare vah...     32   42
# 1153  Piret ise viibis eile fotovõtetel ühel Bahama ...     46   64
# 1225  Külastatakse mandrilähedast Proclamationi saar...     85   95
# 1517  See lastakse pidulikult Grossi Päide mõisa jär...     37   48
# 1532  Soome linnuvaatlejad leidsid Lahemaalt Natturi...     47   59
# 1883            Fashion TV kanalit siis veel ei olnud ?      8   18

# %%
full_match_df = annotated_df[annotated_df["choice"]=="full match"]
full_match_df
full_match_df["category"].value_counts()
# Out:
# category
# H    104
# G     76
# Y     38
# S     12
# I      9
# A      4
# D      1
# Z      1
# Name: count, dtype: int64

# %% [markdown]
# Merge two datasets:

# %%
for i in full_match_df.index:
    postag = full_match_df['category'][i]
    if postag not in annotations_by_pos:
        annotations_by_pos[postag] = []
    start = full_match_df['start'][i]
    end = full_match_df['end'][i]
    phrase = full_match_df['phrase'][i]
    sentence = full_match_df['text'][i]
    span = {'start': start, 'end': end, 'text': phrase, 'labels': ['LOC']}
    annotations_by_pos[postag].append( (sentence, span) )

# %% [markdown]
# Save/export annotations into files:

# %%
import csv

output_dir = 'labelled/recall_sets'
os.makedirs(output_dir, exist_ok=True)

# Write into recall_sets
for postag in annotations_by_pos.keys():
    output_path = os.path.join(output_dir, f'pos_terms_1000_{postag}.csv')
    with open(output_path, 'w', encoding='utf-8', newline='') as out_f:
        fieldnames = ['id', 'text', 'span']
        writer = csv.DictWriter(out_f, fieldnames=fieldnames, delimiter=',')
        writer.writeheader()
        for i, (sentence, span) in enumerate( annotations_by_pos[postag] ):
             writer.writerow({'id': i, 'text': sentence, 'span': str(span)})

# %% [markdown]
# ## II. Update the benchmark data
#
# ### Gather necessary counts
#
# Next, we need to obtain total term counts in each subpopulation. This information is available in the local database file created by the SpanSampler. Reload the database and get the information:

# %%
from helper_functions import load_configuration, connect_to_database
from helper_functions import count_terms_by_postags
from span_sampler_sqlite3 import SpanSampler

config = load_configuration('config\example_configuration.ini')
storage = connect_to_database(config)
collection = config['source_database']['collection']
collection = storage[collection]

sampler = SpanSampler(collection=collection, 
                      layer='v172_geo_terms', 
                      attribute='lemma', 
                      termsfile='geo_terms.txt', 
                      db_file_name=config['local_database']['sqlite_file'], 
                      verbose=True)
# Out:
# INFO:storage.py:57: connecting to host: 'postgres.keeleressursid.ee', port: 5432, dbname: 'estonian-text-corpora', user: 'soras'
# INFO:storage.py:108: schema: 'estonian_text_corpora', temporary: False, role: 'estonian_text_corpora_read'
# Loaded 63 terms from geo_terms.txt.

# %%
# Load total counts of each partofspeech subpopulation
subpopulation_totals = count_terms_by_postags(sampler)
print(subpopulation_totals)
# Out:
# {'A': 30190, 'C': 2663, 'D': 17890, 'G': 3611, 'H': 72084, 'I': 314, 'J': 20878, 'K': 7786, 'N': 3949, 'O': 911, 'P': 20508, 'S': 47721, 'U': 1329, 'V': 42315, 'X': 36, 'Y': 2163, 'Z': 10901}

# %% [markdown]
# Next, get numbers of positive cases (correct entities) for each subpopulation.

# %%
# Collect numbers of positive cases.
# Use CSV files as a basis to test that they are in a valid format
from pandas import read_csv

positives = {}
for subpopulation in annotations_by_pos.keys():
    positives[subpopulation] = 0
    filename = f'labelled/recall_sets/pos_terms_1000_{subpopulation}.csv'
    try:
        data = read_csv(filename)
    except Exception as csv_parsing_err:
        raise ValueError(f'(!) Bad input file format: unable to open {filename!r} as a CSV file: ') from csv_parsing_err
    positives[subpopulation] += len(data.text)

# %% [markdown]
# ### Create dataset description CSV file

# %%
import numpy as np 
from pandas import DataFrame

# %%
# Add initial statistics about sub populations
sorted_populations = sorted(annotations_by_pos.keys())
df = DataFrame({
    'population': sorted_populations,
    'occurences': [subpopulation_totals[s_pop] for s_pop in sorted_populations],
    'labelled': [1000 for s_pop in sorted_populations],
    'positive': [positives[s_pop] for s_pop in sorted_populations]
})
# Compute some additional statistics
df['occurence_ratio'] = df['occurences']/sum(df['occurences'])
df['detection_ratio'] = df['positive']/df['labelled']
df['relative_frequency'] = df['occurence_ratio'] * df['positive']/sum(df['occurence_ratio'] * df['positive'])
df
# Out:
#   population  occurences  labelled  positive  occurence_ratio  \
# 0          A       30190      1000        85         0.159885
# 1          D       17890      1000         6         0.094745
# 2          G        3611      1000       576         0.019124
# 3          H       72084      1000       773         0.381754
# 4          I         314      1000        23         0.001663
# 5          N        3949      1000         5         0.020914
# 6          S       47721      1000        97         0.252729
# 7          Y        2163      1000       116         0.011455
# 8          Z       10901      1000         4         0.057731
#
#    detection_ratio  relative_frequency
# 0            0.085            0.039223
# 1            0.006            0.001641
# 2            0.576            0.031791
# 3            0.773            0.851679
# 4            0.023            0.000110
# 5            0.005            0.000302
# 6            0.097            0.070752
# 7            0.116            0.003835
# 8            0.004            0.000666

# %%
# add file names (full paths)
df['file'] = [f'amundsen_02/data/recall_sets/pos_terms_1000_{s_pop}.csv' for s_pop in sorted_populations]

# %%
# export as csv
df.to_csv('data_description.csv')
